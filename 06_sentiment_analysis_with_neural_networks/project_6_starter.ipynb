# %% [markdown]
# # Project 6: Analyzing Stock Sentiment from Twits
# ## Instructions
# Each problem consists of a function to implement and instructions on how to implement the function.  The parts of the function that need to be implemented are marked with a `# TODO` comment.
#
# ## Packages
# When you implement the functions, you'll only need to you use the packages you've used in the classroom, like [Pandas](https://pandas.pydata.org/) and [Numpy](http://www.numpy.org/). These packages will be imported for you. We recommend you don't add any import statements, otherwise the grader might not be able to run your code.
#
# ### Load Packages

# %%
import json
import nltk
import os
import random
import re
import torch

from torch import nn, optim
import torch.nn.functional as F

# %% [markdown]
# ## Introduction
# When deciding the value of a company, it's important to follow the news. For example, a product recall or natural disaster in a company's product chain. You want to be able to turn this information into a signal. Currently, the best tool for the job is a Neural Network.
#
# For this project, you'll use posts from the social media site [StockTwits](https://en.wikipedia.org/wiki/StockTwits). The community on StockTwits is full of investors, traders, and entrepreneurs. Each message posted is called a Twit. This is similar to Twitter's version of a post, called a Tweet. You'll build a model around these twits that generate a sentiment score.
#
# We've collected a bunch of twits, then hand labeled the sentiment of each. To capture the degree of sentiment, we'll use a five-point scale: very negative, negative, neutral, positive, very positive. Each twit is labeled -2 to 2 in steps of 1, from very negative to very positive respectively. You'll build a sentiment analysis model that will learn to assign sentiment to twits on its own, using this labeled data.
#
# The first thing we should to do, is load the data.
#
# ## Import Twits
# ### Load Twits Data
# This JSON file contains a list of objects for each twit in the `'data'` field:
#
# ```
# {'data':
#   {'message_body': 'Neutral twit body text here',
#    'sentiment': 0},
#   {'message_body': 'Happy twit body text here',
#    'sentiment': 1},
#    ...
# }
# ```
#
# The fields represent the following:
#
# * `'message_body'`: The text of the twit.
# * `'sentiment'`: Sentiment score for the twit, ranges from -2 to 2 in steps of 1, with 0 being neutral.
#
#
# To see what the data look like by printing the first 10 twits from the list.

# %%
path = os.path.join('..', '..', 'data', 'project_6_stocktwits', 'twits.json')
with open(path, 'r') as f:
    twits = json.load(f)

print(twits['data'][:10])
# Out:
# [{'message_body': '$FITB great buy at 26.00...ill wait', 'sentiment': 2, 'timestamp': '2018-07-01T00:00:09Z'}, {'message_body': '@StockTwits $MSFT', 'sentiment': 1, 'timestamp': '2018-07-01T00:00:42Z'}, {'message_body': '#STAAnalystAlert for $TDG : Jefferies Maintains with a rating of Hold setting target price at USD 350.00. Our own verdict is Buy  http://www.stocktargetadvisor.com/toprating', 'sentiment': 2, 'timestamp': '2018-07-01T00:01:24Z'}, {'message_body': '$AMD I heard there’s a guy who knows someone who thinks somebody knows something - on StockTwits.', 'sentiment': 1, 'timestamp': '2018-07-01T00:01:47Z'}, {'message_body': '$AMD reveal yourself!', 'sentiment': 0, 'timestamp': '2018-07-01T00:02:13Z'}, {'message_body': '$AAPL Why the drop? I warren Buffet taking out his position?', 'sentiment': 1, 'timestamp': '2018-07-01T00:03:10Z'}, {'message_body': '$BA bears have 1 reason on 06-29 to pay more attention https://dividendbot.com?s=BA', 'sentiment': -2, 'timestamp': '2018-07-01T00:04:09Z'}, {'message_body': '$BAC ok good we&#39;re not dropping in price over the weekend, lol', 'sentiment': 1, 'timestamp': '2018-07-01T00:04:17Z'}, {'message_body': '$AMAT - Daily Chart, we need to get back to above 50.', 'sentiment': 2, 'timestamp': '2018-07-01T00:08:01Z'}, {'message_body': '$GME 3% drop per week after spike... if no news in 3 months, back to 12s... if BO, then bingo... what is the odds?', 'sentiment': -2, 'timestamp': '2018-07-01T00:09:03Z'}]

# %% [markdown]
# ### Length of Data
# Now let's look at the number of twits in dataset. Print the number of twits below.

# %%
"""print out the number of twits"""

# TODO Implement
#
print("Number of twits: {}".format(len(twits['data'])))
# Out:
# Number of twits: 1548010

# %% [markdown]
# ### Split Message Body and Sentiment Score

# %%
messages = [twit['message_body'] for twit in twits['data']]
# Since the sentiment scores are discrete, we'll scale the sentiments to 0 to 4 for use in our network
sentiments = [twit['sentiment'] + 2 for twit in twits['data']]

# %% [markdown]
# ## Preprocessing the Data
# With our data in hand we need to preprocess our text. These twits are collected by filtering on ticker symbols where these are denoted with a leader $ symbol in the twit itself. For example,
#
# `{'message_body': 'RT @google Our annual look at the year in Google blogging (and beyond) http://t.co/sptHOAh8 $GOOG',
#  'sentiment': 0}`
#
# The ticker symbols don't provide information on the sentiment, and they are in every twit, so we should remove them. This twit also has the `@google` username, again not providing sentiment information, so we should also remove it. We also see a URL `http://t.co/sptHOAh8`. Let's remove these too.
#
# The easiest way to remove specific words or phrases is with regex using the `re` module. You can sub out specific patterns with a space:
#
# ```python
# re.sub(pattern, ' ', text)
# ```
# This will substitute a space with anywhere the pattern matches in the text. Later when we tokenize the text, we'll split appropriately on those spaces.

# %% [markdown]
# ### Pre-Processing

# %%
nltk.download('wordnet')


def preprocess(message):
    """
    This function takes a string as input, then performs these operations: 
        - lowercase
        - remove URLs
        - remove ticker symbols 
        - removes punctuation
        - tokenize by splitting the string on whitespace 
        - removes any single character tokens
    
    Parameters
    ----------
        message : The text message to be preprocessed.
        
    Returns
    -------
        tokens: The preprocessed text into tokens.
    """ 
    #TODO: Implement 
    
    # Lowercase the twit message
    text = message.lower()
    
    # Replace URLs with a space in the message
    text = re.sub(r'(http|https):\/\/(www)?[^\s]+\b', ' ', text)
    
    # Replace ticker symbols with a space. The ticker symbols are any stock symbol that starts with $.
    text = re.sub(r'\$[a-zA-Z]+\b', ' ', text)
    
    # Replace StockTwits usernames with a space. The usernames are any word that starts with @.
    text = re.sub(r'@[a-zA-Z0-9_]+\b', ' ', text)

    # Replace everything not a letter with a space
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    
    # Tokenize by splitting the string on whitespace into a list of words
    tokens = text.split()

    # Lemmatize words using the WordNetLemmatizer. You can ignore any word that is not longer than one character.
    wnl = nltk.stem.WordNetLemmatizer()
    tokens = [wnl.lemmatize(w) for w in tokens if len(wnl.lemmatize(w)) > 1]

    
    assert type(tokens) == list, 'Tokens should be list'
    return tokens

print(preprocess(messages[0]))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# ['great', 'buy', 'at', 'ill', 'wait']

# %% [markdown]
# >Note: You must ensure that after preprocessing the text should NOT include:
# - Numbers
# - URLs
# - Single character tokens
# - Ticker symbols (these should be removed even if they don't appear at the beginning)

# %% [markdown]
# ### Preprocess All the Twits
# Now we can preprocess each of the twits in our dataset. Apply the function `preprocess` to all the twit messages.

# %%
# TODO Implement

tokenized = [preprocess(message) for message in messages]
tokenized
# Out:
# [['great', 'buy', 'at', 'ill', 'wait'],
#  [],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'maintains',
#   'with',
#   'rating',
#   'of',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['heard',
#   'there',
#   'guy',
#   'who',
#   'know',
#   'someone',
#   'who',
#   'think',
#   'somebody',
#   'know',
#   'something',
#   'on',
#   'stocktwits'],
#  ['reveal', 'yourself'],
#  ['why',
#   'the',
#   'drop',
#   'warren',
#   'buffet',
#   'taking',
#   'out',
#   'his',
#   'position'],
#  ['bear', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['ok',
#   'good',
#   'we',
#   're',
#   'not',
#   'dropping',
#   'in',
#   'price',
#   'over',
#   'the',
#   'weekend',
#   'lol'],
#  ['daily', 'chart', 'we', 'need', 'to', 'get', 'back', 'to', 'above'],
#  ['drop',
#   'per',
#   'week',
#   'after',
#   'spike',
#   'if',
#   'no',
#   'news',
#   'in',
#   'month',
#   'back',
#   'to',
#   'if',
#   'bo',
#   'then',
#   'bingo',
#   'what',
#   'is',
#   'the',
#   'odds'],
#  ['strong', 'buy'],
#  ['short', 'ratio', 'is', 'at', 'and', 'short', 'to', 'float', 'is', 'via'],
#  ['price',
#   'squeezing',
#   'perfect',
#   'place',
#   'for',
#   'an',
#   'option',
#   'straddle',
#   'near',
#   'the',
#   'supporting',
#   'trend'],
#  ['start',
#   'of',
#   'new',
#   'on',
#   'monday',
#   'expect',
#   'strong',
#   'buy',
#   'volume',
#   'across',
#   'key',
#   'company',
#   'of',
#   'various',
#   'sector'],
#  ['breakout', 'strategy', 'current', 'portfolio'],
#  ['bull', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['catalyst',
#   'continuing',
#   'this',
#   'new',
#   'uptrend',
#   'pill',
#   'pack',
#   'buy',
#   'out',
#   'amazon',
#   'prime',
#   'day',
#   'earnings',
#   'test',
#   'break',
#   'of',
#   'soon'],
#  ['ha', 'moved', 'on', 'check', 'out', 'the', 'movement', 'and', 'peer', 'at'],
#  ['staanalystalert',
#   'for',
#   'mkm',
#   'partner',
#   'set',
#   'price',
#   'target',
#   'with',
#   'rating',
#   'of',
#   'buy',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['think',
#   'it',
#   'is',
#   'too',
#   'early',
#   'to',
#   'tell',
#   'what',
#   'going',
#   'to',
#   'happen',
#   'monday',
#   'even',
#   'with',
#   'the',
#   'current',
#   'news',
#   'about',
#   'raisinf',
#   'output',
#   'there',
#   'is',
#   'still',
#   'so',
#   'many'],
#  ['ha',
#   'current',
#   'ratio',
#   'of',
#   'so',
#   'it',
#   'is',
#   'financially',
#   'healthy',
#   'and',
#   'ha',
#   'no',
#   'problem',
#   'in',
#   'meeting',
#   'it',
#   'obligation'],
#  ['bullish', 'stock', 'to', 'watch', 'setup', 'timeframes', 'blog', 'by'],
#  ['just', 'short', 'it'],
#  ['high', 'alert', 'for', 'next', 'week', 'gt', 'breakdown'],
#  ['the',
#   'current',
#   'ratio',
#   'of',
#   'is',
#   'much',
#   'better',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of'],
#  ['miss', 'these', 'day'],
#  ['if',
#   'break',
#   'and',
#   'confirms',
#   'next',
#   'week',
#   'you',
#   'will',
#   'see',
#   'violent',
#   'move',
#   'downward',
#   'to',
#   'my',
#   'buy',
#   'price'],
#  ['bear', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['breakout',
#   'base',
#   'gap',
#   'and',
#   'day',
#   'ma',
#   'gap',
#   'gap',
#   'gap',
#   'and',
#   'day',
#   'ma'],
#  ['cabot',
#   'weekly',
#   'video',
#   'quot',
#   'resilient',
#   'growth',
#   'stock',
#   'to',
#   'watch',
#   'quot'],
#  ['when',
#   'wa',
#   'kid',
#   'my',
#   'froend',
#   'told',
#   'me',
#   'the',
#   'moon',
#   'wa',
#   'made',
#   'out',
#   'of',
#   'cheese'],
#  ['short',
#   'volume',
#   'percent',
#   'for',
#   'wa',
#   'on',
#   'and',
#   'day',
#   'rank',
#   'wa',
#   'th',
#   'percentile'],
#  ['thank',
#   'you',
#   'don',
#   'feel',
#   'the',
#   'need',
#   'to',
#   'tell',
#   'or',
#   'to',
#   'do',
#   'well',
#   'for',
#   'me',
#   'they',
#   'already',
#   'have'],
#  ['during',
#   'the',
#   'youtube',
#   'interview',
#   'mitch',
#   'couldn',
#   'remember',
#   'single',
#   'movie',
#   'he',
#   'watched',
#   'all',
#   'year',
#   'except',
#   'star',
#   'war',
#   'black',
#   'panther',
#   'clothes'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'downgrade',
#   'with',
#   'rating',
#   'of',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'hold'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['ha',
#   'better',
#   'return',
#   'on',
#   'equity',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of'],
#  ['although',
#   'the',
#   'market',
#   'is',
#   'up',
#   'is',
#   'doing',
#   'even',
#   'better',
#   'it',
#   'ha',
#   'advanced',
#   'of',
#   'more',
#   'info',
#   'peer',
#   'at'],
#  ['july',
#   'will',
#   'be',
#   'the',
#   'most',
#   'bullish',
#   'day',
#   'of',
#   'the',
#   'year',
#   'for',
#   'stock'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['third', 'design', 'win', 'the', 'timing', 'match', 'it', 'probably', 'arm'],
#  ['alcohol',
#   'stock',
#   'tobacco',
#   'stock',
#   'and',
#   'firearm',
#   'stock',
#   'to',
#   'buy'],
#  ['president',
#   'trump',
#   'tweet',
#   'just',
#   'spoke',
#   'to',
#   'king',
#   'salman',
#   'of',
#   'saudi',
#   'arabia',
#   'and',
#   'explained',
#   'to',
#   'him',
#   'that',
#   'because',
#   'of',
#   'the',
#   'turmoil',
#   'amp'],
#  ['today', 'insight', 'on'],
#  ['intc',
#   'mama',
#   'said',
#   'get',
#   'ice',
#   'cream',
#   'if',
#   'finish',
#   'my',
#   'due',
#   'dil'],
#  ['just',
#   'noticed',
#   'they',
#   'have',
#   'the',
#   'last',
#   'jedi',
#   'on',
#   'stream',
#   'love',
#   'this',
#   'stock'],
#  ['here', 'you', 'go', 'will', 'just', 'leave', 'this', 'here'],
#  ['good',
#   'view',
#   'daily',
#   'still',
#   'look',
#   'good',
#   'ema',
#   'held',
#   'above',
#   'ema',
#   'and',
#   'stochastics',
#   'turning',
#   'healthy',
#   'spy',
#   'qqq',
#   'opposite'],
#  ['with',
#   'forward',
#   'pe',
#   'of',
#   'the',
#   'valuation',
#   'of',
#   'can',
#   'be',
#   'described',
#   'cheap'],
#  ['saber',
#   'capital',
#   'presentation',
#   'common',
#   'denominator',
#   'of',
#   'tencent',
#   'facebook',
#   'and',
#   'google'],
#  ['how', 'expect', 'the', 'earnings'],
#  ['is',
#   'one',
#   'of',
#   'the',
#   'better',
#   'performing',
#   'stock',
#   'in',
#   'the',
#   'crude',
#   'petroleum',
#   'and',
#   'natural',
#   'gas',
#   'industry'],
#  ['pu',
#   'it',
#   'simply',
#   'havent',
#   'lost',
#   'on',
#   'any',
#   'brown',
#   'guy',
#   'run',
#   'tech',
#   'company',
#   'mf',
#   'are',
#   'well',
#   'educated',
#   'know',
#   'their',
#   'shit',
#   'more',
#   'more',
#   'every',
#   'year'],
#  ['former',
#   'president',
#   'of',
#   'global',
#   'manufacturing',
#   'at',
#   'pfizer',
#   'is',
#   'an',
#   'independent',
#   'director',
#   'at',
#   'nat',
#   'ricciardi'],
#  ['may', 'be', 'the', 'safest', 'stock', 'own'],
#  ['special',
#   'limited',
#   'offer',
#   'june',
#   'th',
#   'june',
#   'th',
#   'tradenet',
#   'is',
#   'offering',
#   'discount',
#   'on',
#   'intro',
#   'program'],
#  ['below', 'buy', 'put', 'on', 'financials'],
#  ['great',
#   'summary',
#   'of',
#   'jeff',
#   'gundlach',
#   'sohn',
#   'presentation',
#   'long',
#   'thesis',
#   'for',
#   'energy',
#   'stock'],
#  ['low',
#   'peg',
#   'ratio',
#   'which',
#   'compensates',
#   'the',
#   'pe',
#   'for',
#   'growth',
#   'indicates',
#   'rather',
#   'cheap',
#   'valuation'],
#  ['great',
#   'summary',
#   'of',
#   'jeff',
#   'gundlach',
#   'sohn',
#   'pres',
#   'long',
#   'thesis',
#   'for',
#   'energy',
#   'equity'],
#  ['coming'],
#  ['seems', 'is', 'the', 'support', 'next', 'if', 'under', 'is', 'likely'],
#  ['ha', 'moved', 'on', 'check', 'out', 'the', 'movement', 'and', 'peer', 'at'],
#  ['bullshit',
#   'worthless',
#   'mean',
#   'fucking',
#   'nothing',
#   'this',
#   'is',
#   'macau',
#   'not',
#   'fucking',
#   'usa'],
#  ['take',
#   'this',
#   'let',
#   'me',
#   'know',
#   'where',
#   'are',
#   'we',
#   'right',
#   'now',
#   'lol'],
#  ['the',
#   'chart',
#   'look',
#   'so',
#   'ugly',
#   'without',
#   'clear',
#   'support',
#   'level',
#   'short',
#   'term',
#   'bearish',
#   'll',
#   'buy',
#   'when',
#   'this',
#   'is',
#   'at'],
#  ['great',
#   'summary',
#   'of',
#   'jeff',
#   'gundlach',
#   'sohn',
#   'presentation',
#   'long',
#   'thesis',
#   'for',
#   'energy',
#   'stock'],
#  ['previously',
#   'there',
#   'wa',
#   'mo',
#   'run',
#   'up',
#   'followed',
#   'by',
#   'drop',
#   'we',
#   'are',
#   'at',
#   'the',
#   'end',
#   'of',
#   'month',
#   'of',
#   'another',
#   'runup',
#   'and',
#   'have',
#   'dropped',
#   'about'],
#  ['smart', 'money', 'betting', 'on', 'call', 'deal', 'update'],
#  ['although',
#   'the',
#   'technical',
#   'rating',
#   'is',
#   'bad',
#   'doe',
#   'present',
#   'nice',
#   'setup',
#   'opportunity'],
#  ['will',
#   'completely',
#   'scale',
#   'out',
#   'in',
#   'time',
#   'to',
#   'gobble',
#   'up',
#   'my',
#   'next',
#   'long',
#   'play',
#   'aka',
#   'my',
#   'favorite',
#   'gt'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'is', 'via'],
#  ['them', 'are', 'iddy', 'bitty', 'kiddy', 'hand'],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['then',
#   'awesome',
#   'it',
#   'is',
#   'now',
#   'be',
#   'concerned',
#   'if',
#   'not',
#   'over',
#   'by',
#   'eow',
#   'might',
#   'get',
#   'under',
#   'next',
#   'wk',
#   'or',
#   'soon'],
#  ['throwback'],
#  ['staanalystalert',
#   'for',
#   'capital',
#   'advisor',
#   'upgrade',
#   'with',
#   'rating',
#   'of',
#   'hold',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['lol',
#   'all',
#   'these',
#   'shorties',
#   'are',
#   'dreaming',
#   'of',
#   'great',
#   'depression',
#   'or',
#   'somethin',
#   'loll'],
#  ['just',
#   'updated',
#   'hormel',
#   'food',
#   'dividend',
#   'king',
#   'stock',
#   'analysis',
#   'dividend',
#   'king',
#   'consumer',
#   'defensive'],
#  ['today', 'insight', 'on'],
#  ['just',
#   'updated',
#   'intel',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'technology'],
#  ['today', 'insight', 'on'],
#  ['the',
#   'long',
#   'and',
#   'short',
#   'term',
#   'trend',
#   'are',
#   'both',
#   'positive',
#   'this',
#   'is',
#   'looking',
#   'good'],
#  ['they', 'so', 'mad', 'at', 'me', 'still'],
#  ['back', 'to', 'by', 'july'],
#  ['report', 'and', 'block', 'this', 'person', 'spam'],
#  ['should', 'open', 'at', 'on', 'monday'],
#  ['my',
#   'projection',
#   'for',
#   'if',
#   'thats',
#   'true',
#   'under',
#   'is',
#   'next',
#   'week',
#   'thats',
#   'why',
#   'prefer',
#   'to',
#   'buy',
#   'from',
#   'support',
#   'level'],
#  ['what', 'turd'],
#  ['percent', 'short', 'volume', 'for', 'wa', 'on'],
#  ['wal',
#   'mart',
#   'dividend',
#   'aristocrat',
#   'dividend',
#   'aristocrat',
#   'consumer',
#   'defensive',
#   'valueinvesting',
#   'dvb',
#   'aaamp'],
#  ['looking',
#   'for',
#   'marriage',
#   'have',
#   'in',
#   'my',
#   'bank',
#   'account',
#   'with',
#   'in',
#   'stock',
#   'dm'],
#  ['short', 'ratio', 'is', 'at', 'and', 'short', 'to', 'float', 'is', 'via'],
#  ['to',
#   'that',
#   'bear',
#   'that',
#   'won',
#   'stop',
#   'posting',
#   'holding',
#   'big',
#   'short',
#   'position',
#   'over',
#   'weekend',
#   'calm',
#   'down',
#   'and',
#   'good',
#   'luck',
#   'lol'],
#  ['the',
#   'chase',
#   'continues',
#   'hopefully',
#   'they',
#   'catch',
#   'him',
#   'before',
#   'lisa',
#   'announces',
#   'the',
#   'rd',
#   'win'],
#  ['the',
#   'price',
#   'earnings',
#   'ratio',
#   'is',
#   'which',
#   'indicates',
#   'rather',
#   'cheap',
#   'valuation',
#   'of'],
#  ['permamently',
#   'turned',
#   'me',
#   'off',
#   'of',
#   'option',
#   'trading',
#   'and',
#   'maybe',
#   'stock',
#   'altogether',
#   'manipulation',
#   'by',
#   'very',
#   'rich',
#   'to',
#   'make',
#   'me',
#   'very',
#   'poor',
#   'fuk',
#   'it'],
#  ['is',
#   'down',
#   'almost',
#   'pct',
#   'from',
#   'it',
#   'week',
#   'high',
#   'it',
#   'about',
#   'time',
#   'for',
#   'buyback',
#   'got',
#   'more',
#   'share',
#   'in',
#   'my',
#   'account',
#   'though',
#   'from',
#   'drip'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  [],
#  ['dumped',
#   'call',
#   'friday',
#   'at',
#   'open',
#   'that',
#   'wa',
#   'obv',
#   'but',
#   'jeez',
#   'bit',
#   'over',
#   'done',
#   'here'],
#  ['bounce',
#   'off',
#   'support',
#   'heikin',
#   'ashi',
#   'weekly',
#   'candle',
#   'look',
#   'good',
#   'well',
#   'will',
#   'be',
#   'looking',
#   'for',
#   'confirmation'],
#  ['liking', 'this'],
#  ['look',
#   'for',
#   'wife',
#   'got',
#   'about',
#   'tree',
#   'fiddy',
#   'in',
#   'stock',
#   'and',
#   'it',
#   'sure',
#   'my',
#   'piggy',
#   'bank',
#   'ha',
#   'got',
#   'lot',
#   'of',
#   'coin',
#   'may',
#   'spend',
#   'on',
#   'candy',
#   'no',
#   'dm',
#   'though'],
#  ['short',
#   'interest',
#   'ratio',
#   'is',
#   'on',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['just',
#   'updated',
#   'microsoft',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'technology'],
#  ['bearish', 'investor', 'aren', 'happy', 'today', 'for', 'of'],
#  ['staanalystalert',
#   'for',
#   'royal',
#   'bank',
#   'of',
#   'canada',
#   'reiterates',
#   'with',
#   'rating',
#   'of',
#   'outperform',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['staanalystalert',
#   'for',
#   'loop',
#   'capital',
#   'raise',
#   'target',
#   'with',
#   'rating',
#   'of',
#   'buy',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['kid', 'never', 'been', 'wrong', 'he', 'miracle'],
#  ['what', 'is', 'period', 'bollinger', 'band', 'mean'],
#  ['you', 'dare', 'say', 'didn', 'know', 'you', 'are', 'guilty', 'fudge'],
#  ['today', 'insight', 'on'],
#  ['hardly',
#   'ever',
#   'an',
#   'informative',
#   'comment',
#   'here',
#   'and',
#   'the',
#   'page',
#   'is',
#   'broken',
#   'giving',
#   'endless',
#   'buffering',
#   'icon',
#   'give',
#   'up',
#   'stocktwits'],
#  ['viral',
#   'walk',
#   'away',
#   'video',
#   'highlight',
#   'growing',
#   'movement',
#   'of',
#   'democrat',
#   'leaving',
#   'the',
#   'party',
#   'the',
#   'epoch',
#   'time'],
#  ['staanalystalert',
#   'for',
#   'robert',
#   'baird',
#   'downgrade',
#   'with',
#   'rating',
#   'of',
#   'neutral',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['too', 'much', 'weed', 'and', 'other', 'drug', 'guess'],
#  ['with',
#   'forward',
#   'pe',
#   'of',
#   'the',
#   'valuation',
#   'of',
#   'can',
#   'be',
#   'described',
#   'very',
#   'reasonable'],
#  ['the',
#   'reason',
#   'nike',
#   'is',
#   'winning',
#   'is',
#   'because',
#   'of',
#   'their',
#   'click',
#   'booking',
#   'app',
#   'it',
#   'better',
#   'than',
#   'native',
#   'seamless',
#   'lovalized',
#   'transactable',
#   'ap'],
#  ['vitiello', 'tapped', 'acting', 'ice', 'director', 'via'],
#  ['will',
#   'reach',
#   'over',
#   'this',
#   'year',
#   'iconic',
#   'brand',
#   'global',
#   'technology',
#   'and',
#   'built',
#   'for',
#   'mobile',
#   'winning',
#   'strategy',
#   'amp',
#   'show',
#   'in',
#   'earnings'],
#  ['by', 'monday', 'morning'],
#  ['this', 'is', 'heading', 'to', 'ath', 'soon', 'maybe', 'next', 'week'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'downgrade',
#   'with',
#   'rating',
#   'of',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['staanalystalert',
#   'for',
#   'baird',
#   'downgrade',
#   'with',
#   'rating',
#   'of',
#   'neutral',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['there',
#   'have',
#   'been',
#   'acquisition',
#   'for',
#   'total',
#   'of',
#   'share',
#   'over',
#   'the',
#   'past',
#   'week',
#   'for'],
#  ['happy', 'trading', 'guy', 'looking', 'to', 'exit', 'today'],
#  ['buy', 'zone'],
#  [],
#  ['fantastic',
#   'read',
#   'oil',
#   'market',
#   'continues',
#   'to',
#   'tighten',
#   'bbl',
#   'is',
#   'getting',
#   'closer'],
#  ['one', 'of', 'the', 'greatest', 'buy'],
#  ['looking',
#   'at',
#   'the',
#   'yearly',
#   'performance',
#   'did',
#   'better',
#   'than',
#   'of',
#   'all',
#   'other',
#   'stock'],
#  ['at',
#   'amp',
#   'dividend',
#   'aristocrat',
#   'dividend',
#   'aristocrat',
#   'champion',
#   'cashflow',
#   'highyield',
#   'telecommunication',
#   'dividend'],
#  ['that',
#   'pretty',
#   'risky',
#   'gamble',
#   'no',
#   'the',
#   'stock',
#   'can',
#   'either',
#   'plummet',
#   'or',
#   'rally'],
#  ['the',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['stronger'],
#  ['apple',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'technology',
#   'dividend'],
#  ['not', 'talking', 'about', 'wa', 'referring', 'to', 'intelsat'],
#  ['will',
#   'punish',
#   'seller',
#   'who',
#   'don',
#   'move',
#   'stock',
#   'from',
#   'it',
#   'warehouse',
#   'common',
#   'sense',
#   'old',
#   'gather',
#   'dust',
#   'new',
#   'gather',
#   'money'],
#  ['pc',
#   'gamers',
#   'crypto',
#   'miner',
#   'and',
#   'other',
#   'gpu',
#   'enthusiast',
#   'have',
#   'been',
#   'waiting',
#   'over',
#   'two',
#   'year',
#   'for',
#   'the',
#   'company',
#   'next',
#   'big'],
#  ['ha',
#   'only',
#   'medium',
#   'technical',
#   'rating',
#   'but',
#   'it',
#   'doe',
#   'show',
#   'decent',
#   'setup',
#   'pattern'],
#  ['today', 'insight', 'on'],
#  ['what', 'will', 'be', 'more', 'in', 'five', 'year', 'baba', 'or', 'apple'],
#  ['next', 'week', 'ahhhhhhhhhhhhhhhhhhhhh'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'is', 'via'],
#  ['raytheon',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'industrials',
#   'military'],
#  ['why', 'we', 'trending'],
#  ['we',
#   'will',
#   'get',
#   'riiiiiiiiiich',
#   'sooooon',
#   'buuuuls',
#   'looooove',
#   'you',
#   'all',
#   'and',
#   'fucking',
#   'drunk'],
#  ['if',
#   'this',
#   'doesn',
#   'get',
#   'through',
#   'it',
#   'going',
#   'to',
#   'make',
#   'new',
#   'low',
#   'when',
#   'it',
#   'pay',
#   'the',
#   'dividend'],
#  ['gapping', 'up', 'monday'],
#  ['short',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'maintains',
#   'with',
#   'rating',
#   'of',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['should',
#   'by',
#   'warbey',
#   'parker',
#   'for',
#   'in',
#   'prep',
#   'for',
#   'apple',
#   'glass',
#   'seen',
#   'with',
#   'watch',
#   'apple',
#   'focus',
#   'on',
#   'fashion',
#   'and',
#   'tech',
#   'wrt',
#   'wearable'],
#  ['look',
#   'like',
#   'sbux',
#   'is',
#   'paying',
#   'full',
#   'sex',
#   'change',
#   'for',
#   'employee',
#   'now',
#   'that',
#   'll',
#   'hit',
#   'the',
#   'bottom',
#   'line'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'expect',
#   'run',
#   'up',
#   'to',
#   'other',
#   'trade',
#   'included',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam'],
#  ['enterprise',
#   'value',
#   'market',
#   'cap',
#   'difference',
#   'of',
#   'actual',
#   'asset',
#   'market',
#   'value',
#   'too',
#   'big',
#   'spread',
#   'way',
#   'undervalued'],
#  ['million', 'share', 'added', 'on', 'june', 'dont', 'wait'],
#  ['who',
#   'think',
#   'amazon',
#   'will',
#   'become',
#   'such',
#   'monopoly',
#   'dipping',
#   'into',
#   'everything',
#   'that',
#   'an',
#   'amazon',
#   'airline',
#   'is',
#   'possibility',
#   'do'],
#  ['don',
#   'miss',
#   'the',
#   'breakout',
#   'on',
#   'buy',
#   'stop',
#   'stop',
#   'loss',
#   'is',
#   'suggested',
#   'by',
#   'the',
#   'chartmill',
#   'analyzer'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['weekly',
#   'recap',
#   'price',
#   'ha',
#   'moved',
#   'since',
#   'post',
#   'support',
#   'resistance',
#   'other',
#   'trade',
#   'included',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam',
#   'len'],
#  ['weekly',
#   'recap',
#   'price',
#   'ha',
#   'moved',
#   'since',
#   'post',
#   'reversal',
#   'in',
#   'progress',
#   'other',
#   'trade',
#   'included',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam',
#   'len',
#   'hsy'],
#  ['ve',
#   'recently',
#   'closed',
#   'my',
#   'position',
#   'in',
#   'for',
#   'now',
#   'is',
#   'probably',
#   'next',
#   'on',
#   'the',
#   'list',
#   'bought',
#   'both',
#   'in',
#   'the',
#   'same',
#   'week'],
#  ['nat',
#   'ricciardi',
#   'is',
#   'director',
#   'used',
#   'to',
#   'be',
#   'president',
#   'of',
#   'global',
#   'manufacturing'],
#  ['according',
#   'to',
#   'data',
#   'reported',
#   'to',
#   'finra',
#   'short',
#   'volume',
#   'percent',
#   'for',
#   'clocked',
#   'in',
#   'at',
#   'on'],
#  ['saudi',
#   'official',
#   'came',
#   'out',
#   'saying',
#   'they',
#   'didn',
#   'agree',
#   'to',
#   'this'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'uptrend',
#   'to',
#   'resume',
#   'other',
#   'trade',
#   'included',
#   'kmx',
#   'wynn',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc'],
#  ['the',
#   'one',
#   'on',
#   'the',
#   'right',
#   'cover',
#   'the',
#   'penis',
#   'or',
#   'the',
#   'putang',
#   'the',
#   'front',
#   'leg',
#   'would',
#   'be',
#   'arm'],
#  [],
#  ['some', 'of', 'the', 'stock', 'am', 'watching', 'now'],
#  ['short',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'next',
#   'stop',
#   'other',
#   'trade',
#   'included',
#   'wynn',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri'],
#  ['wonder',
#   'how',
#   'much',
#   'this',
#   'will',
#   'be',
#   'valued',
#   'at',
#   'in',
#   'year',
#   'we',
#   'are',
#   'not',
#   'even',
#   'in',
#   'the',
#   'th',
#   'inning'],
#  ['ha',
#   'bad',
#   'technical',
#   'rating',
#   'but',
#   'it',
#   'doe',
#   'show',
#   'decent',
#   'setup',
#   'pattern'],
#  ['is',
#   'going',
#   'to',
#   'make',
#   'big',
#   'move',
#   'higher',
#   'also',
#   'watching',
#   'apple',
#   'think',
#   'they',
#   'shorted',
#   'the',
#   'put',
#   'spread',
#   'for',
#   'july'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'expect',
#   'consolidation',
#   'other',
#   'trade',
#   'included',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx'],
#  ['it',
#   'good',
#   'that',
#   'even',
#   'bull',
#   'are',
#   'cautious',
#   'stunned',
#   'bearish',
#   'deeply',
#   'disappointed',
#   'too',
#   'bad',
#   'continues',
#   'it',
#   'old',
#   'way',
#   'hopefully',
#   'we',
#   'are',
#   'close'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'support',
#   'other',
#   'trade',
#   'included',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn'],
#  ['ending',
#   'june',
#   'killed',
#   'it',
#   'best',
#   'month',
#   'since',
#   'february',
#   'cl'],
#  ['funny',
#   'how',
#   'long',
#   'the',
#   'same',
#   'thing',
#   'ha',
#   'been',
#   'going',
#   'on',
#   'with',
#   'this',
#   'about',
#   'year',
#   'of',
#   'this',
#   'similar',
#   'story',
#   'different',
#   'day'],
#  ['bearish',
#   'crab',
#   'well',
#   'measured',
#   'bearish',
#   'crab',
#   'with',
#   'bearish',
#   'divergence',
#   'you',
#   'can',
#   'really',
#   'see',
#   'the',
#   'momentum',
#   'starting',
#   'to',
#   'shi'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'maintains',
#   'with',
#   'rating',
#   'of',
#   'buy',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['google', 'venture', 'company'],
#  ['tariff',
#   'increase',
#   'profit',
#   'how',
#   'can',
#   'it',
#   'be',
#   'bad',
#   'recession',
#   'if',
#   'it',
#   'come',
#   'is',
#   'year',
#   'down',
#   'the',
#   'line',
#   'keep',
#   'buying',
#   'short',
#   'pure',
#   'bull'],
#  ['beanscreen', 'for'],
#  ['the',
#   'min',
#   'chart',
#   'from',
#   'friday',
#   'indicating',
#   'some',
#   'nice',
#   'accumulation',
#   'at',
#   'eod',
#   'could',
#   'be',
#   'nice',
#   'pop',
#   'monday'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'at',
#   'is',
#   'via'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'heavy',
#   'resistance',
#   'at',
#   'other',
#   'trade',
#   'included',
#   'apog',
#   'acn',
#   'camp',
#   'gi',
#   'payx',
#   'fdx',
#   'goo'],
#  ['can', 'we', 'squeeze', 'the', 'short'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'pullback',
#   'to',
#   'before',
#   'more',
#   'upside',
#   'other',
#   'trade',
#   'included',
#   'camp',
#   'gi',
#   'payx',
#   'fdx',
#   'goo',
#   'nvda',
#   'apog'],
#  ['still', 'holding', 'call', 'for', 'next', 'week'],
#  ['is', 'safe', 'but', 'their', 'buyback', 'yield', 'is', 'div', 'yield'],
#  ['adding',
#   'at',
#   'gladly',
#   'let',
#   'irrationality',
#   'reign',
#   'long',
#   'possible',
#   'excess',
#   'gain',
#   'are',
#   'welcome',
#   'gl'],
#  ['looking',
#   'at',
#   'friday',
#   'data',
#   'seeing',
#   'different',
#   'story',
#   'on',
#   'the',
#   'chart',
#   'take',
#   'look',
#   'and',
#   'tell',
#   'me',
#   'what',
#   'you',
#   'think'],
#  ['the',
#   'short',
#   'probably',
#   'aren',
#   'jumping',
#   'for',
#   'joy',
#   'today',
#   'in',
#   'at',
#   'least',
#   'for',
#   'given',
#   'the',
#   'price',
#   'action'],
#  ['bouncing',
#   'off',
#   'support',
#   'need',
#   'continuation',
#   'next',
#   'week',
#   'make',
#   'me',
#   'feel',
#   'more',
#   'hopeful',
#   'for'],
#  ['data',
#   'science',
#   'officially',
#   'became',
#   'major',
#   'in',
#   'university',
#   'this',
#   'year',
#   'to',
#   'support',
#   'ai',
#   'industry',
#   'these',
#   'are',
#   'no',
#   'brainers',
#   'in',
#   'the',
#   'data',
#   'era'],
#  ['short',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  [],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'support',
#   'at',
#   'other',
#   'trade',
#   'included',
#   'payx',
#   'fdx',
#   'goo',
#   'nvda',
#   'apog',
#   'acn',
#   'camp'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  [],
#  ['ha',
#   'better',
#   'return',
#   'on',
#   'equity',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of'],
#  ['second', 'not', 'minute'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'rule',
#   'applies',
#   'here',
#   'other',
#   'trade',
#   'included',
#   'zbra',
#   'six',
#   'fc',
#   'gbx',
#   'fds',
#   'avav',
#   'baba'],
#  ['trump',
#   'is',
#   'killing',
#   'the',
#   'tax',
#   'cut',
#   'with',
#   'oil',
#   'price',
#   'and',
#   'tariff',
#   'no',
#   'idea',
#   'what',
#   'he',
#   'doing',
#   'right',
#   'now'],
#  ['haven',
#   'posted',
#   'on',
#   'stocktwits',
#   'in',
#   'while',
#   'these',
#   'weekly',
#   'chart',
#   'look',
#   'good'],
#  ['today', 'insight', 'on'],
#  ['omg', 'toy', 'story', 'land', 'look', 'amazing'],
#  ['stock',
#   'have',
#   'contributed',
#   'of',
#   'ytd',
#   'return',
#   'what',
#   'do',
#   'you',
#   'own'],
#  ['today', 'insight', 'on'],
#  ['my', 'rd', 'most', 'popular', 'word'],
#  ['trump',
#   'tweet',
#   'and',
#   'then',
#   'he',
#   'may',
#   'be',
#   'buyin',
#   'those',
#   'dip',
#   'haha',
#   'still',
#   'makin',
#   'it',
#   'rain',
#   'up',
#   'in',
#   'the',
#   'white',
#   'house'],
#  ['ha',
#   'poor',
#   'technical',
#   'rating',
#   'and',
#   'the',
#   'quality',
#   'of',
#   'the',
#   'setup',
#   'is',
#   'also',
#   'not',
#   'perfect',
#   'at',
#   'the',
#   'moment'],
#  ['doubt',
#   'it',
#   'go',
#   'down',
#   'monday',
#   'and',
#   'doubt',
#   'saudi',
#   'arabia',
#   'increase',
#   'production'],
#  ['measured',
#   'over',
#   'the',
#   'past',
#   'year',
#   'show',
#   'very',
#   'strong',
#   'growth',
#   'in',
#   'eps'],
#  ['constellation', 'brand'],
#  ['the',
#   'short',
#   'probably',
#   'aren',
#   'jumping',
#   'for',
#   'joy',
#   'today',
#   'in',
#   'at',
#   'least',
#   'for',
#   'given',
#   'the',
#   'price',
#   'action'],
#  ['here'],
#  ['did', 'disney', 'just', 'clinch', 'the', 'deal', 'to', 'acquire', 'fox'],
#  ['new', 'way', 'match', 'group', 'can', 'counter', 'facebook'],
#  ['aggregate',
#   'short',
#   'volume',
#   'reported',
#   'to',
#   'finra',
#   'for',
#   'wa',
#   'on'],
#  ['southwest',
#   'airline',
#   'is',
#   'adding',
#   'flight',
#   'in',
#   'dallas',
#   'delta',
#   'spat',
#   'continues'],
#  ['what', 'california'],
#  ['better', 'buy', 'netflix', 'inc', 'nflx', 'versus', 'facebook', 'fb'],
#  ['one', 'thing', 'that', 'starbucks', 'is', 'doing', 'wrong'],
#  [],
#  ['using',
#   'iex',
#   'data',
#   'we',
#   'calculate',
#   'that',
#   'shorters',
#   'have',
#   'lost',
#   'in',
#   'on'],
#  ['bull',
#   'list',
#   'after',
#   'their',
#   'emergence',
#   'from',
#   'bankruptcy',
#   'emergency'],
#  ['zwj',
#   'investment',
#   'counsel',
#   'inc',
#   'lower',
#   'stake',
#   'in',
#   'unitedhealth',
#   'group',
#   'inc',
#   'unh'],
#  ['list', 'of', 'tyzen', 'and', 'vega', 'laptop', 'of', 'june', 'th'],
#  ['investing',
#   'in',
#   'the',
#   'company',
#   'like',
#   'an',
#   'annuity',
#   'or',
#   'yr',
#   'bond',
#   'continue',
#   'to',
#   'add',
#   'share',
#   'unsure',
#   'if',
#   'the',
#   'country',
#   'is',
#   'growing',
#   'amd',
#   'is'],
#  ['list', 'of', 'ryzen', 'and', 'vega', 'laptop', 'of'],
#  ['gettin', 'blasted'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'strong',
#   'support',
#   'at',
#   'current',
#   'price',
#   'other',
#   'trade',
#   'included',
#   'cgnx',
#   'cx',
#   'aaoi',
#   'aa',
#   'amswa',
#   'yy',
#   'snx'],
#  ['bearish',
#   'shark',
#   'bearish',
#   'shark',
#   'with',
#   'bearish',
#   'divergence',
#   'am',
#   'definitely',
#   'jumping',
#   'into',
#   'the',
#   'august',
#   'put',
#   'on',
#   'monday'],
#  ['so',
#   'is',
#   'going',
#   'to',
#   'give',
#   'price',
#   'point',
#   'before',
#   'or',
#   'after',
#   'earnings'],
#  ['the',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['huge', 'volume', 'at', 'closing', 'on', 'friday'],
#  ['looking', 'for', 'scalp'],
#  ['this',
#   'is',
#   'one',
#   'giant',
#   'fermenting',
#   'turd',
#   'of',
#   'stock',
#   'when',
#   'will',
#   'it',
#   'go',
#   'back',
#   'up',
#   'to'],
#  ['buffet', 'and', 'are', 'buying', 'at', 'per', 'share'],
#  ['in', 'put', 'from', 'last', 'week', 'target', 'zone', 'marked'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['compared',
#   'to',
#   'an',
#   'average',
#   'industry',
#   'price',
#   'book',
#   'ratio',
#   'of',
#   'is',
#   'valued',
#   'rather',
#   'cheaply'],
#  ['the',
#   'eps',
#   'ha',
#   'been',
#   'growing',
#   'by',
#   'on',
#   'average',
#   'over',
#   'the',
#   'past',
#   'year',
#   'this',
#   'is',
#   'quite',
#   'good'],
#  ['mitch',
#   'did',
#   'great',
#   'job',
#   'of',
#   'getting',
#   'netflix',
#   'started',
#   'he',
#   'clearly',
#   'know',
#   'how',
#   'to',
#   'make',
#   'big',
#   'thing',
#   'happen',
#   'in',
#   'this',
#   'industry'],
#  ['cup',
#   'and',
#   'holder',
#   'inverse',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['with',
#   'debt',
#   'to',
#   'equity',
#   'ratio',
#   'of',
#   'is',
#   'doing',
#   'better',
#   'than',
#   'the',
#   'average',
#   'in',
#   'the',
#   'industry'],
#  ['sell',
#   'in',
#   'may',
#   'amp',
#   'go',
#   'away',
#   'ha',
#   'been',
#   'pattern',
#   'for',
#   'year',
#   'interesting',
#   'to',
#   'see',
#   'so',
#   'much',
#   'trading',
#   'in',
#   'this',
#   'time',
#   'frame',
#   'bank',
#   'love',
#   'you',
#   'trader'],
#  ['meanwhile', 'in', 'galaxy', 'far', 'far', 'away'],
#  ['broadening',
#   'wedge',
#   'descending',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['happy', 'trading', 'guy', 'looking', 'to', 'exit', 'today'],
#  ['large', 'put', 'spread', 'in', 'open', 'interest', 'im', 'bearish'],
#  [],
#  ['pt'],
#  ['three',
#   'falling',
#   'peak',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['happy',
#   'fourth',
#   'everyone',
#   'have',
#   'coke',
#   'and',
#   'smile',
#   'thanks',
#   'for',
#   'the',
#   'dividend',
#   'and'],
#  [],
#  ['selling', 'will', 'prove', 'to', 'be', 'terrible', 'error'],
#  ['the',
#   'end',
#   'of',
#   'the',
#   'article',
#   'just',
#   'posted',
#   'hint',
#   'at',
#   'possible',
#   'acquisition',
#   'of',
#   'sogou',
#   'finger',
#   'crossed'],
#  ['triple',
#   'top',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['bro',
#   'that',
#   'not',
#   'how',
#   'it',
#   'work',
#   'delete',
#   'the',
#   'blue',
#   'arrow',
#   'that',
#   'your',
#   'delusion'],
#  ['let',
#   'me',
#   'guess',
#   'everyone',
#   'is',
#   'still',
#   'bullish',
#   'here',
#   'even',
#   'after',
#   'it',
#   'close',
#   'under',
#   'the',
#   'ma',
#   'on',
#   'the',
#   'daily',
#   'overbought',
#   'level',
#   'trend',
#   'is',
#   'changing'],
#  ['cup',
#   'and',
#   'holder',
#   'bullish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['mr', 'hold', 'yo'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['hi',
#   'everyone',
#   'going',
#   'to',
#   'bed',
#   'good',
#   'night',
#   'everyone',
#   'happy',
#   'money',
#   'monday',
#   'soon',
#   'be',
#   'prepared'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'is', 'via'],
#  ['amazon',
#   'new',
#   'warehouse',
#   'policy',
#   'will',
#   'start',
#   'penalizing',
#   'seller',
#   'that',
#   'store',
#   'product',
#   'for',
#   'too',
#   'long'],
#  ['just',
#   'fyi',
#   'trump',
#   'era',
#   'ramp',
#   'up',
#   'tech',
#   'worker',
#   'revolt',
#   'the',
#   'hill'],
#  ['this',
#   'company',
#   'going',
#   'off',
#   'the',
#   'rail',
#   'the',
#   'people',
#   'that',
#   'work',
#   'there',
#   'and',
#   'the',
#   'store',
#   'manager',
#   'say',
#   'it',
#   'all',
#   'circuit',
#   'city',
#   'deux'],
#  ['why',
#   'did',
#   'bank',
#   'fail',
#   'to',
#   'rally',
#   'despite',
#   'huge',
#   'bb',
#   'and',
#   'div',
#   'incr',
#   'me',
#   'thinking',
#   'mm',
#   'driving',
#   'down',
#   'price',
#   'to',
#   'get',
#   'in',
#   'on',
#   'the',
#   'cheap',
#   'prior',
#   'the',
#   'rally'],
#  ['bear',
#   'using',
#   'all',
#   'argument',
#   'sound',
#   'like',
#   'short',
#   'position',
#   'are',
#   'becoming',
#   'loses',
#   'this',
#   'week'],
#  ['gameranx', 'popular', 'youtube', 'gaming', 'channel'],
#  ['facebook', 'the', 'cash', 'machine'],
#  ['and',
#   'it',
#   'will',
#   'take',
#   'all',
#   'semi',
#   'up',
#   'more',
#   'week',
#   'and',
#   'then',
#   'uptrend',
#   'continues'],
#  ['cheap',
#   'dividend',
#   'champion',
#   'with',
#   'low',
#   'forward',
#   'altria',
#   'aflac',
#   'eatonvance'],
#  ['look',
#   'at',
#   'the',
#   'graph',
#   'tripple',
#   'bottom',
#   'reached',
#   'for',
#   'heading',
#   'to',
#   'and',
#   'to',
#   'in',
#   'to',
#   'week'],
#  ['if',
#   'you',
#   'have',
#   'penis',
#   'and',
#   'want',
#   'vagina',
#   'like',
#   'alteration',
#   'go',
#   'get',
#   'job',
#   'at',
#   'sbux'],
#  ['oled',
#   'panel',
#   'post',
#   'steady',
#   'growth',
#   'amid',
#   'weak',
#   'demand',
#   'in',
#   'display',
#   'market',
#   'data'],
#  ['facebook', 'the', 'cash', 'machine'],
#  [],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['microsoft',
#   'andromeda',
#   'leak',
#   'foldable',
#   'dual',
#   'screen',
#   'surface',
#   'device',
#   'that',
#   'fit',
#   'in',
#   'your',
#   'pocket'],
#  ['the',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['ha',
#   'good',
#   'piotroski',
#   'score',
#   'of',
#   'this',
#   'indicates',
#   'good',
#   'health',
#   'and',
#   'profitability'],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['my',
#   'original',
#   'thesis',
#   'wa',
#   'predicated',
#   'on',
#   'amd',
#   'having',
#   'competitive',
#   'server',
#   'product',
#   'around',
#   'this',
#   'time',
#   'didn',
#   'think',
#   'intel',
#   'would',
#   'shit',
#   'the',
#   'bed'],
#  ['bullish', 'bat', 'bullish', 'bat', 'with', 'bullish', 'divergence'],
#  ['epyc',
#   'server',
#   'adoption',
#   'will',
#   'snow',
#   'ball',
#   'this',
#   'year',
#   'intel',
#   'security',
#   'flaw',
#   'nm',
#   'fail',
#   'fire',
#   'ceo',
#   'you',
#   'can',
#   'make',
#   'this',
#   'sh',
#   'up'],
#  ['my',
#   'original',
#   'thesis',
#   'wa',
#   'predicated',
#   'on',
#   'amd',
#   'having',
#   'competitive',
#   'server',
#   'product',
#   'around',
#   'this',
#   'time',
#   'didn',
#   'think',
#   'intel',
#   'would',
#   'sh',
#   'the',
#   'bed'],
#  ['think', 'will', 'buy', 'many', 'can', 'under'],
#  ['new', 'way', 'match', 'group', 'can', 'counter', 'facebook'],
#  ['wowza',
#   'for',
#   'if',
#   'started',
#   'one',
#   'month',
#   'ago',
#   'the',
#   'short',
#   'return',
#   'would',
#   'be',
#   'around',
#   'of',
#   'iex',
#   'data'],
#  ['is',
#   'the',
#   'real',
#   'boom',
#   'in',
#   'the',
#   'social',
#   'medium',
#   'and',
#   'it',
#   'will',
#   'get',
#   'much',
#   'bigger',
#   'it',
#   'will',
#   'be',
#   'in',
#   'before',
#   'christmas'],
#  ['the',
#   'current',
#   'ratio',
#   'of',
#   'is',
#   'much',
#   'better',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of'],
#  ['celgene',
#   'investor',
#   'breathe',
#   'sigh',
#   'of',
#   'relief',
#   'after',
#   'acceleron',
#   'success'],
#  ['bear',
#   'and',
#   'shorties',
#   'made',
#   'huge',
#   'mistake',
#   'and',
#   'they',
#   'don',
#   'have',
#   'the',
#   'money',
#   'to',
#   'buy',
#   'back',
#   'when',
#   'shorted',
#   'it',
#   'at',
#   'so',
#   'they',
#   'cry',
#   'out',
#   'here',
#   'everyday'],
#  ['today', 'insight', 'on'],
#  ['the',
#   'industry',
#   'average',
#   'roa',
#   'is',
#   'outperforms',
#   'of',
#   'it',
#   'industry',
#   'peer'],
#  ['encourage',
#   'you',
#   'to',
#   'no',
#   'longer',
#   'be',
#   'sheep',
#   'end',
#   'your',
#   'racist',
#   'and',
#   'hateful',
#   'way',
#   'buy',
#   'amd',
#   'and',
#   'walk',
#   'away',
#   'from',
#   'the',
#   'democratic',
#   'party',
#   'walkaway'],
#  ['it',
#   'happening',
#   'looking',
#   'to',
#   'ease',
#   'the',
#   'flattening',
#   'of',
#   'the',
#   'yc',
#   'starting',
#   'this',
#   'week',
#   'lot',
#   'of',
#   'trader',
#   'def',
#   'offside',
#   'now'],
#  ['daily', 'or', 'weekly', 'chart', 'all', 'look', 'horrible'],
#  ['if', 'spotify', 'add', 'more', 'video', 'content', 'look', 'out'],
#  ['market',
#   'positioning',
#   'is',
#   'very',
#   'underweight',
#   'crowdthnk',
#   'algo',
#   'forecast',
#   'chance',
#   'moving',
#   'lower'],
#  ['added',
#   'more',
#   'at',
#   'this',
#   'no',
#   'brainer',
#   'if',
#   'you',
#   're',
#   'long',
#   'there',
#   'is',
#   'no',
#   'peer',
#   'and',
#   'they',
#   'are',
#   'top',
#   'dog',
#   'amd',
#   'and',
#   'mu',
#   'notwithstanding'],
#  ['bearish',
#   'bat',
#   'bearish',
#   'bat',
#   'with',
#   'some',
#   'serious',
#   'bearish',
#   'divergence',
#   'something',
#   'is',
#   'about',
#   'to',
#   'give'],
#  ['ha',
#   'been',
#   'proposition',
#   'in',
#   'july',
#   'since',
#   'with',
#   'net',
#   'return',
#   'of'],
#  ['in',
#   'term',
#   'of',
#   'negative',
#   'for',
#   'there',
#   'are',
#   'bearish',
#   'indicator',
#   'of'],
#  ['quite', 'over', 'valued', 'in', 'my', 'opinion'],
#  ['brexit',
#   'banker',
#   'risk',
#   'life',
#   'on',
#   'the',
#   'edge',
#   'luxembourg',
#   'fill',
#   'up',
#   'via'],
#  ['market', 'history'],
#  ['so', 'amd', 'is', 'using', 'liquid', 'inside', 'of', 'the', 'gpu'],
#  ['curve',
#   'flattening',
#   'juggernaut',
#   'face',
#   'risk',
#   'from',
#   'fed',
#   'concern',
#   'on',
#   'trade',
#   'via'],
#  ['it',
#   'pertains',
#   'to',
#   'if',
#   'started',
#   'day',
#   'ago',
#   'bearish',
#   'investor',
#   'would',
#   'have',
#   'lost',
#   'around',
#   'of',
#   'according',
#   'to',
#   'iex'],
#  [],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['study',
#   'of',
#   'watchlist',
#   'trade',
#   'wisely',
#   'invest',
#   'wisely',
#   'read',
#   'the',
#   'wallstreet',
#   'runner'],
#  ['waiting', 'for', 'the', 'pull', 'back', 'slow', 'steady', 'stock'],
#  ['thought',
#   'friday',
#   'flush',
#   'wa',
#   'for',
#   'cheap',
#   'share',
#   'just',
#   'like',
#   'they',
#   'did',
#   'in',
#   'oil',
#   'before',
#   'the',
#   'opec',
#   'meeting'],
#  ['china', 'attack'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'is', 'via'],
#  ['is',
#   'rated',
#   'sell',
#   'since',
#   'june',
#   'and',
#   'is',
#   'below',
#   'it',
#   'median',
#   'level'],
#  ['dont', 'trust', 'this', 'company'],
#  ['today', 'insight', 'on'],
#  ['the',
#   'anticipation',
#   'is',
#   'rising',
#   'which',
#   'analyst',
#   'is',
#   'right',
#   'june'],
#  ['sorry',
#   'itsallaboutheoptions',
#   'stock',
#   'price',
#   'is',
#   'not',
#   'so',
#   'we',
#   'are',
#   'higher',
#   'than',
#   'you',
#   'predicted',
#   'not',
#   'lower'],
#  ['warren', 'diggered', 'they', 'exited'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'at',
#   'is',
#   'via'],
#  ['another', 'analyst', 'opinion', 'on', 'june'],
#  [],
#  ['and',
#   'are',
#   'all',
#   'down',
#   'because',
#   'of',
#   'trade',
#   'concern',
#   'will',
#   'still',
#   'be',
#   'worth',
#   'it',
#   'weight',
#   'in',
#   'faucet',
#   'and',
#   'now',
#   'little',
#   'bit',
#   'of',
#   'lighting'],
#  ['three',
#   'falling',
#   'peak',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'is', 'via'],
#  ['rectangle',
#   'top',
#   'bullish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['any', 'more', 'really', 'jetsonbs', 'design', 'they', 'announce'],
#  ['bull', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['cogsworth', 'cog', 'will', 'take', 'on', 'boeing', 'soon', 'right'],
#  ['really',
#   'baked',
#   'right',
#   'now',
#   'having',
#   'deep',
#   'thought',
#   'short',
#   'coming',
#   'back',
#   'to',
#   'look',
#   'at',
#   'this',
#   'tweet',
#   'in',
#   'year'],
#  ['this',
#   'one',
#   'will',
#   'test',
#   'if',
#   'fails',
#   'my',
#   'target',
#   'is',
#   'to',
#   'start',
#   'buying',
#   'this',
#   'again',
#   'houseofpain'],
#  ['analyst', 'opinion'],
#  ['making', 'more', 'than', 'ever', 'thanks', 'to', 'amp'],
#  [],
#  ['atl', 'fed', 'forecast', 'whew', 'baby', 'up', 'we', 'go'],
#  ['here',
#   'it',
#   'is',
#   'june',
#   'grr',
#   'date',
#   'is',
#   'came',
#   'out',
#   'early',
#   'read',
#   'away'],
#  ['bull', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['stericycle',
#   'current',
#   'chance',
#   'of',
#   'distress',
#   'is',
#   'about',
#   'below',
#   'average'],
#  ['ggr', 'is', 'out', 'for', 'june'],
#  ['today', 'insight', 'on'],
#  ['fyi'],
#  ['will', 'this', 'go', 'over', 'before', 'earnings'],
#  ['extremely',
#   'undervalued',
#   'this',
#   'will',
#   'be',
#   'within',
#   'year',
#   'great',
#   'for',
#   'midterm',
#   'investment'],
#  ['may', 'go', 'slightly', 'down', 'on', 'this', 'news', 'june', 'ggr'],
#  ['stupid', 'spammer', 'wasting', 'time'],
#  ['but',
#   'it',
#   'already',
#   'oversold',
#   'so',
#   'not',
#   'much',
#   'consolidation',
#   'and',
#   'then',
#   'up'],
#  ['this', 'is', 'just', 'the', 'start'],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['purchasing',
#   'pill',
#   'pack',
#   'last',
#   'thursday',
#   'and',
#   'breaking',
#   'into',
#   'the',
#   'pharmaceutical',
#   'field',
#   'increase',
#   'amazon',
#   'bottom',
#   'line',
#   'will',
#   'retest',
#   'quickly'],
#  ['june',
#   'ggr',
#   'up',
#   'still',
#   'after',
#   'the',
#   'soccer',
#   'world',
#   'cup',
#   'and',
#   'holiday'],
#  ['purchasing',
#   'pill',
#   'pack',
#   'last',
#   'thurs',
#   'amp',
#   'breaking',
#   'into',
#   'the',
#   'pharmaceutical',
#   'field',
#   'increase',
#   'amazon',
#   'bottom',
#   'line',
#   'will',
#   'retest',
#   'quickly'],
#  ['buy', 'back', 'they', 'want', 'cheap'],
#  ['not',
#   'too',
#   'expensive',
#   'and',
#   'growing',
#   'strongly',
#   'check',
#   'out',
#   'now',
#   'part',
#   'of',
#   'our',
#   'affordable',
#   'growth',
#   'selection'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['the',
#   'long',
#   'term',
#   'trend',
#   'is',
#   'positive',
#   'and',
#   'the',
#   'short',
#   'term',
#   'trend',
#   'is',
#   'neutral',
#   'so',
#   'the',
#   'benefit',
#   'of',
#   'the',
#   'doubt',
#   'for',
#   'now'],
#  ['lot',
#   'of',
#   'buyer',
#   'fri',
#   'when',
#   'mm',
#   'pinned',
#   'at',
#   'quot',
#   'trader',
#   'buy',
#   'amazon',
#   'com',
#   'amzn',
#   'on',
#   'weakness',
#   'quot'],
#  ['in',
#   'term',
#   'of',
#   'positive',
#   'for',
#   'there',
#   'are',
#   'bullish',
#   'indicator',
#   'of'],
#  ['know', 'what', 'hold'],
#  ['never',
#   'have',
#   'seen',
#   'right',
#   'angle',
#   'in',
#   'apple',
#   'lol',
#   'that',
#   'wa',
#   'crazy'],
#  ['wanna',
#   'hear',
#   'the',
#   'er',
#   'ok',
#   'yeah',
#   'all',
#   'got',
#   'great',
#   'product',
#   'so',
#   'what',
#   'this',
#   'is',
#   'the',
#   'stock',
#   'market',
#   'want',
#   'report',
#   'what',
#   'the',
#   'news'],
#  ['starbucks',
#   'to',
#   'become',
#   'the',
#   'pioneer',
#   'in',
#   'medical',
#   'coverage',
#   'for',
#   'sex',
#   'change',
#   'get',
#   'your',
#   'free',
#   'sex',
#   'change',
#   'here'],
#  ['today', 'insight', 'on'],
#  ['today', 'insight', 'on'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['all',
#   'in',
#   'on',
#   'august',
#   'call',
#   'either',
#   'gonna',
#   'make',
#   'fortune',
#   'or',
#   'declare',
#   'bankruptcy'],
#  ['wtf'],
#  [],
#  ['macau', 'casino', 'ggr', 'up', 'nearly', 'pct', 'in', 'june', 'govt'],
#  ['jul',
#   'casino',
#   'gross',
#   'gaming',
#   'revenue',
#   'ggr',
#   'in',
#   'macau',
#   'rose',
#   'by',
#   'percent',
#   'year',
#   'on',
#   'year',
#   'in',
#   'june',
#   'to'],
#  ['what'],
#  ['is', 'gonna', 'be', 'cheaper', 'than', 'also'],
#  ['the',
#   'monster',
#   'core',
#   'amd',
#   'ryzen',
#   'threadripper',
#   'cpu',
#   'rumored',
#   'usd'],
#  ['we',
#   'have',
#   'detected',
#   'negative',
#   'indicator',
#   'of',
#   'for',
#   'more',
#   'info',
#   'at'],
#  ['someone', 'give', 'me', 'like'],
#  ['short',
#   'interest',
#   'ratio',
#   'is',
#   'on',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  [],
#  ['valued', 'll', 'take', 'at', 'this', 'point'],
#  [],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['trump', 'will', 'cause', 'oil', 'price', 'to', 'go', 'down'],
#  ['if',
#   'were',
#   'and',
#   'need',
#   'to',
#   'buyback',
#   'bln',
#   'share',
#   'wouldn',
#   'try',
#   'to',
#   'buy',
#   'the',
#   'dip'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'is', 'via'],
#  ['gigabyte', 'amp', 'epyc', 'cpu', 'with', 'large', 'density', 'server'],
#  ['now',
#   'intel',
#   'can',
#   'produce',
#   'full',
#   'silicon',
#   'wafer',
#   'for',
#   'quantum',
#   'computing',
#   'chip'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['good',
#   'technical',
#   'but',
#   'also',
#   'nice',
#   'setup',
#   'pattern',
#   'forming',
#   'for',
#   'now',
#   'part',
#   'of',
#   'our',
#   'top',
#   'breakout',
#   'selection'],
#  ['bear', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['june',
#   'ggr',
#   'only',
#   'up',
#   'very',
#   'bad',
#   'stock',
#   'are',
#   'going',
#   'to',
#   'get',
#   'crushed'],
#  ['amazon',
#   'with',
#   'hook',
#   'pattern',
#   'set',
#   'up',
#   'on',
#   'the',
#   'monthly',
#   'looking',
#   'at',
#   'strong',
#   'move',
#   'up',
#   'on',
#   'monday',
#   'expected'],
#  ['paychex',
#   'social',
#   'hype',
#   'low',
#   'key',
#   'current',
#   'chance',
#   'of',
#   'financial',
#   'distress',
#   'is',
#   'under'],
#  ['today', 'insight', 'on'],
#  [],
#  ['bear', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['buy', 'more', 'on', 'the', 'dip', 'buying', 'opp'],
#  ['here',
#   'is',
#   'an',
#   'example',
#   'of',
#   'hook',
#   'pattern',
#   'virtually',
#   'identical',
#   'to',
#   'what',
#   'amazon',
#   'monthly',
#   'chart',
#   'look',
#   'like',
#   'now'],
#  ['the',
#   'eps',
#   'ha',
#   'been',
#   'growing',
#   'by',
#   'on',
#   'average',
#   'over',
#   'the',
#   'past',
#   'year',
#   'this',
#   'is',
#   'quite',
#   'good'],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['showing', 'up', 'in', 'our', 'top', 'breakout', 'selection'],
#  ['overbought', 'sell', 'signal'],
#  ['short', 'ratio', 'is', 'at', 'and', 'short', 'to', 'float', 'is', 'via'],
#  ['rsi', 'deathcross'],
#  ['will',
#   'be',
#   'selling',
#   'pre',
#   'market',
#   'and',
#   'trying',
#   'to',
#   'buy',
#   'in',
#   'very',
#   'bullish',
#   'but',
#   'would',
#   'like',
#   'to',
#   'take',
#   'advantage',
#   'of',
#   'dip'],
#  ['it',
#   'pertains',
#   'to',
#   'if',
#   'started',
#   'day',
#   'ago',
#   'bearish',
#   'investor',
#   'would',
#   'have',
#   'lost',
#   'around',
#   'of',
#   'according',
#   'to',
#   'iex'],
#  ['short',
#   'volume',
#   'for',
#   'on',
#   'wa',
#   'th',
#   'percentile',
#   'in',
#   'term',
#   'of',
#   'last',
#   'trading',
#   'day'],
#  ['bring',
#   'on',
#   'the',
#   'gloom',
#   'amp',
#   'doom',
#   'on',
#   'the',
#   'pull',
#   'back',
#   'ahead',
#   'of',
#   'er',
#   'happens',
#   'ever',
#   'time',
#   'after',
#   'don',
#   'fight',
#   'the',
#   'plan',
#   'buy',
#   'it',
#   'no',
#   'way',
#   'it',
#   'fall'],
#  ['overbought', 'death', 'cross', 'sell', 'signal'],
#  ['short',
#   'interest',
#   'ratio',
#   'is',
#   'on',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['bad',
#   'news',
#   'is',
#   'baked',
#   'in',
#   'to',
#   'the',
#   'sector',
#   'but',
#   'second',
#   'major',
#   'miss',
#   'in',
#   'row',
#   'like',
#   'this',
#   'is',
#   'going',
#   'to',
#   'spook',
#   'lot',
#   'of',
#   'investor'],
#  ['short', 'volume', 'percent', 'for', 'wa', 'on', 'versus', 'on'],
#  ['here',
#   'is',
#   'artcile',
#   'with',
#   'expectation',
#   'for',
#   'june',
#   'great',
#   'buying',
#   'opp',
#   'on',
#   'dip',
#   'july',
# ...
#   'this',
#   'is',
#   'looking',
#   'good'],
#  ['releasing',
#   'earnings',
#   'on',
#   'before',
#   'open',
#   'confirmed',
#   'anybody',
#   'buying',
#   'selling',
#   'in',
#   'earnings'],
#  ['ba', 'ba'],
#  ['not', 'at', 'all', 'afraid', 'to', 'hold', 'my', 'short', 'in', 'bank'],
#  ['retaliation',
#   'for',
#   'tariff',
#   'on',
#   'sun',
#   'canada',
#   'on',
#   'july',
#   'china',
#   'expected',
#   'to',
#   'impose',
#   'tariff',
#   'on',
#   'soybean',
#   'cnbc'],
#  ['short',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['wonder', 'how', 'many', 'matebook', 'are', 'selling'],
#  ['bac', 'bac'],
#  ['good', 'plan', 'right', 'here', 'close', 'to', 'mine'],
#  ['very', 'optimistic', 'melikey'],
#  ['high',
#   'oi',
#   'range',
#   'is',
#   'to',
#   'for',
#   'option',
#   'expiration',
#   'maxpain',
#   'option'],
#  ['oversold', 'with', 'sign', 'of', 'possible', 'reversal'],
#  ['would',
#   'not',
#   'want',
#   'to',
#   'be',
#   'in',
#   'this',
#   'for',
#   'the',
#   'next',
#   'er'],
#  ['don', 'tell', 'me', 'you', 'are', 'still', 'holding'],
#  ['ok',
#   'you',
#   'keep',
#   'telling',
#   'telling',
#   'yourself',
#   'that',
#   'he',
#   'bked',
#   'casino',
#   'casino',
#   'now',
#   'and',
#   'soon'],
#  ['this',
#   'is',
#   'the',
#   'only',
#   'table',
#   'service',
#   'can',
#   'afford',
#   'right',
#   'now',
#   'can',
#   'even',
#   'afford',
#   'the',
#   'mcdouble',
#   'anymore',
#   'after',
#   'the',
#   'price',
#   'hike'],
#  ['can',
#   'someone',
#   'explain',
#   'what',
#   'happens',
#   'with',
#   'the',
#   'div',
#   'payout',
#   'if',
#   'buy',
#   'in',
#   'here'],
#  ['economy',
#   'that',
#   'time',
#   'sending',
#   'job',
#   'overseas',
#   'after',
#   'supporting',
#   'them',
#   'gut',
#   'of',
#   'trump',
#   'calling',
#   'them',
#   'out'],
#  ['yeah', 'sleep', 'with', 'elon', 'musk'],
#  ['compared',
#   'to',
#   'an',
#   'average',
#   'industry',
#   'price',
#   'book',
#   'ratio',
#   'of',
#   'is',
#   'valued',
#   'rather',
#   'cheaply'],
#  ['since',
#   'last',
#   'er',
#   'stock',
#   'dropped',
#   'reporting',
#   'earnings',
#   'on',
#   'before',
#   'open',
#   'confirmed'],
#  ['if',
#   'all',
#   'be',
#   'nice',
#   'to',
#   'me',
#   'can',
#   'give',
#   'you',
#   'an',
#   'accurate',
#   'direction',
#   'of',
#   'which',
#   'way',
#   'this',
#   'will',
#   'go'],
#  ['below',
#   'all',
#   'sma',
#   'in',
#   'falling',
#   'wedge',
#   'bearish',
#   'until',
#   'breakout'],
#  ['think',
#   'most',
#   'of',
#   'the',
#   'peep',
#   'on',
#   'here',
#   'have',
#   'blocked',
#   'bro',
#   'time',
#   'to',
#   'use',
#   'an',
#   'alternate',
#   'account',
#   'are',
#   'taken'],
#  ['you',
#   'bet',
#   'how',
#   'about',
#   'show',
#   'some',
#   'fact',
#   'sport',
#   'now',
#   'ha',
#   'control',
#   'of',
#   'nfl',
#   'mlb',
#   'march',
#   'madness',
#   'etc',
#   'roku',
#   'suck',
#   'donkey',
#   'dks'],
#  ['alibaba',
#   'buy',
#   'stake',
#   'in',
#   'turkey',
#   'trendyol',
#   'alibaba',
#   'is',
#   'proceeding',
#   'it',
#   'international',
#   'expansion'],
#  ['think',
#   'the',
#   'whole',
#   'dump',
#   'for',
#   'the',
#   'past',
#   'few',
#   'year',
#   'wa',
#   'absolutely',
#   'necessary',
#   'their',
#   'sht',
#   'wa',
#   'getting',
#   'way',
#   'too',
#   'expensive',
#   'they',
#   'can',
#   'grow',
#   'bter',
#   'now'],
#  ['if', 'feel', 'good', 'to', 'be', 'right', 'with', 'this', 'stock'],
#  ['remember',
#   'even',
#   'the',
#   'capital',
#   'investment',
#   'will',
#   'only',
#   'be',
#   'in',
#   'dividend',
#   'payout'],
#  ['since',
#   'last',
#   'er',
#   'stock',
#   'dropped',
#   'reporting',
#   'earnings',
#   'on',
#   'before',
#   'open',
#   'confirmed'],
#  ['whats',
#   'up',
#   'bro',
#   'you',
#   'still',
#   'trade',
#   'this',
#   'stock',
#   'or',
#   'did',
#   'you',
#   'give',
#   'up'],
#  ['short', 'volume', 'percent', 'for', 'wa', 'on'],
#  ['bull', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['talking',
#   'about',
#   'gravity',
#   'in',
#   'stock',
#   'market',
#   'is',
#   'fool',
#   'errond',
#   'take',
#   'look',
#   'at'],
#  ['read',
#   'your',
#   'comment',
#   'on',
#   'on',
#   'seeking',
#   'alpha',
#   'you',
#   'know',
#   'lot',
#   'about',
#   'casino',
#   'stock',
#   'will',
#   'this',
#   'ggr',
#   'hurt',
#   'the',
#   'price',
#   'more',
#   'or',
#   'ok',
#   'here'],
#  ['open', 'tomorrow'],
#  ['is',
#   'more',
#   'then',
#   'enough',
#   'we',
#   'should',
#   'be',
#   'at',
#   'and',
#   'earning',
#   'are',
#   'coming',
#   'up'],
#  ['should', 'be', 'loading', 'on', 'on', 'this', 'stock', 'here'],
#  ['wall',
#   'street',
#   'is',
#   'full',
#   'of',
#   'idiot',
#   'who',
#   'gamble',
#   'until',
#   'they',
#   'lose'],
#  ['hope',
#   'citibank',
#   'go',
#   'bankrupt',
#   'stealing',
#   'money',
#   'by',
#   'nickel',
#   'and',
#   'dimming',
#   'costumer',
#   'with',
#   'stupid',
#   'little',
#   'fee'],
#  [],
#  ['don',
#   'worry',
#   'scumbags',
#   'at',
#   'citibank',
#   'll',
#   'make',
#   'more',
#   'money',
#   'shorting',
#   'your',
#   'stock',
#   'to',
#   'the',
#   'ground',
#   'than',
#   'you',
#   'will',
#   'make',
#   'from',
#   'fee'],
#  ['choppy',
#   'head',
#   'amp',
#   'shoulder',
#   'watch',
#   'for',
#   'the',
#   'breakdown',
#   'watch',
#   'for',
#   'the',
#   'breakdown'],
#  ['releasing',
#   'earnings',
#   'on',
#   'before',
#   'open',
#   'confirmed',
#   'anybody',
#   'buying',
#   'selling',
#   'in',
#   'earnings'],
#  [],
#  ['it', 'is', 'now', 'time', 'for', 'the', 'trumpy', 'bear', 'market'],
#  ['gravity',
#   'applies',
#   'to',
#   'overbot',
#   'condition',
#   'and',
#   'applied',
#   'to',
#   'in',
#   'past',
#   'well'],
#  ['highlight', 'in', 'cancer', 'from', 'the', 'week'],
#  ['jcp', 'jcpenney', 'ha', 'rev', 'per', 'employee', 'of'],
#  ['vrsk',
#   'beta',
#   'of',
#   'veriskanalytics',
#   'is',
#   'making',
#   'it',
#   'le',
#   'volatile',
#   'than',
#   'the',
#   'market'],
#  ['viavisolutions', 'dipped', 'by', 'in', 'the', 'last', 'year', 'viav'],
#  ['it', 'gartner', 'ha', 'very', 'low', 'roce', 'of'],
#  ['etn', 'the', 'rpe', 'revenue', 'per', 'employee', 'of', 'eatonplc', 'is'],
#  ['rrdonnelleysons',
#   'is',
#   'oversold',
#   'according',
#   'to',
#   'it',
#   'stoch',
#   'rsi',
#   'of',
#   'rrd'],
#  ['ba', 'the', 'payout', 'ratio', 'of', 'boeing', 'is'],
#  ['releasing',
#   'earnings',
#   'on',
#   'before',
#   'open',
#   'confirmed',
#   'anybody',
#   'buying',
#   'selling',
#   'in',
#   'earnings'],
#  ['psx', 'fcf', 'of', 'phillips', 'is'],
#  ['citigroup', 'ha', 'recommendation', 'mean', 'of'],
#  ['mco',
#   'sma',
#   'of',
#   'moody',
#   'is',
#   'now',
#   'down',
#   'by',
#   'and',
#   'sma',
#   'is',
#   'now',
#   'up',
#   'by'],
#  ['fslr',
#   'the',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of',
#   'firstsolar',
#   'is'],
#  ['aonplc',
#   'ha',
#   'beta',
#   'of',
#   'making',
#   'it',
#   'le',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'aon'],
#  ['microsoft', 'ha', 'adx', 'of', 'hinting', 'it', 'weak', 'trend', 'msft'],
#  ['apa',
#   'apache',
#   'ha',
#   'sma',
#   'of',
#   'now',
#   'up',
#   'by',
#   'and',
#   'sma',
#   'of',
#   'now',
#   'up',
#   'by'],
#  ['yte', 'ha', 'ppo', 'of', 'incy'],
#  ['jmsmucker', 'ha', 'recommendation', 'mean', 'of', 'sjm'],
#  ['tel', 'teconnectivity', 'ha', 'ppo', 'of'],
#  ['operating', 'margin', 'of', 'internationalbusinessmachines', 'is', 'ibm'],
#  ['northerntrust', 'ha', 'recommendation', 'mean', 'of', 'ntrs'],
#  ['bankofnewyorkmellon', 'ha', 'short', 'of', 'float', 'of', 'bk'],
#  ['nowhere',
#   'to',
#   'go',
#   'but',
#   'up',
#   'focus',
#   'on',
#   'fundamental',
#   'epyc',
#   'xeon',
#   'tam',
#   'all',
#   'revenue',
#   'and',
#   'profit',
#   'coming',
#   'now',
#   'revenue',
#   'ramp',
#   'year',
#   'pt'],
#  ['etfc', 'insider', 'ownership', 'of', 'etrade', 'is'],
#  ['envisionhealthcare', 'ha', 'short', 'of', 'float', 'of', 'evhc'],
#  ['baxterinternational',
#   'is',
#   'overbought',
#   'with',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of',
#   'bax'],
#  ['profit', 'margin', 'of', 'att', 'is'],
#  ['eogresources',
#   'is',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'with',
#   'beta',
#   'of',
#   'eog'],
#  ['diamondoffshoredrilling',
#   'ha',
#   'adx',
#   'of',
#   'signifying',
#   'it',
#   'weak',
#   'trend',
#   'do'],
#  ['the', 'dividend', 'yield', 'of', 'averydennison', 'is', 'avy'],
#  ['southern',
#   'ha',
#   'very',
#   'high',
#   'return',
#   'on',
#   'capital',
#   'employed',
#   'of',
#   'so'],
#  ['insider', 'ownership', 'of', 'davita', 'is', 'dva'],
#  ['western',
#   'ma',
#   'berkshire',
#   'cty',
#   'today',
#   'already',
#   'deg',
#   'today',
#   'the',
#   'cool',
#   'end',
#   'of',
#   'the',
#   'state'],
#  ['citizen', 'ha', 'stoch', 'of', 'making', 'it', 'oversold', 'cfg'],
#  ['bear',
#   'have',
#   'lost',
#   'on',
#   'alone',
#   'in',
#   'according',
#   'to',
#   'iex',
#   'data'],
#  ['cimarexco', 'ha', 'adx', 'of', 'signifying', 'it', 'weak', 'trend', 'xec'],
#  ['all', 'allstate', 'ha', 'very', 'high', 'return', 'on', 'equity', 'of'],
#  ['cxo', 'conchoresources', 'went', 'up', 'by', 'in', 'the', 'last', 'year'],
#  ['compared',
#   'to',
#   'an',
#   'average',
#   'enterprise',
#   'value',
#   'to',
#   'ebitda',
#   'ratio',
#   'of',
#   'is',
#   'valued',
#   'rather',
#   'cheaply'],
#  ['bull', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['qepresources',
#   'ha',
#   'very',
#   'high',
#   'revenue',
#   'per',
#   'employee',
#   'of',
#   'qep'],
#  ['ans', 'fcf', 'of', 'ansys', 'is'],
#  ['coty', 'the', 'recommendation', 'mean', 'of', 'coty', 'is'],
#  ['mtd', 'profit', 'margin', 'of', 'mettler', 'toledointernational', 'is'],
#  ['anyone', 'know', 'what', 'this', 'is', 'referring', 'to'],
#  ['gross', 'margin', 'of', 'motorolasolutions', 'is', 'msi'],
#  ['operating', 'margin', 'of', 'michaelkors', 'is', 'kor'],
#  ['allegionplc',
#   'is',
#   'overbought',
#   'according',
#   'to',
#   'it',
#   'stochastic',
#   'rsi',
#   'indicator',
#   'of',
#   'alle'],
#  ['nlsn',
#   'the',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of',
#   'nielsennv',
#   'is'],
#  ['wpx', 'wpx', 'ha', 'rev', 'per', 'employee', 'of'],
#  ['whr', 'whirlpool', 'ha', 'dividend', 'yield', 'of'],
#  ['chrw', 'chrobinsonworldwide', 'ha', 'short', 'of', 'float', 'of'],
#  ['the', 'recommendation', 'mean', 'of', 'wellsfargo', 'is', 'wfc'],
#  ['ccl', 'carnival', 'ha', 'operating', 'margin', 'of'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['sma',
#   'of',
#   'pepsico',
#   'is',
#   'now',
#   'up',
#   'by',
#   'and',
#   'sma',
#   'is',
#   'now',
#   'down',
#   'by',
#   'pep'],
#  ['pfe', 'pfizer', 'ha', 'very', 'high', 'return', 'on', 'equity', 'of'],
#  ['so',
#   'funny',
#   'how',
#   'bear',
#   'disappear',
#   'from',
#   'to',
#   'but',
#   'it',
#   'pull',
#   'back',
#   'to',
#   'and',
#   'the',
#   'sky',
#   'is',
#   'falling',
#   'lollll',
#   'the',
#   'nature',
#   'of',
#   'stock',
#   'is',
#   'up',
#   'and',
#   'down'],
#  ['deltaairlines',
#   'ha',
#   'adx',
#   'of',
#   'signifying',
#   'it',
#   'weak',
#   'trend',
#   'dal'],
#  ['adtalemglobaleducation', 'ha', 'operating', 'margin', 'of', 'atge'],
#  ['bsx', 'bostonscientific', 'ha', 'institutional', 'ownership', 'of'],
#  ['mck', 'mckesson', 'went', 'down', 'by', 'in', 'the', 'last', 'year'],
#  ['pbct',
#   'peoplesunited',
#   'is',
#   'overbought',
#   'with',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of'],
#  ['insider',
#   'ownership',
#   'of',
#   'vertexpharmaceuticalsorporated',
#   'is',
#   'vrtx'],
#  ['bkng', 'volatility', 'of', 'booking', 'is'],
#  ['dis', 'waltdisney', 'ha', 'ppo', 'of'],
#  ['abbottlaboratories', 'ha', 'insider', 'ownership', 'of', 'abt'],
#  ['arthurjgallagherco',
#   'ha',
#   'adx',
#   'of',
#   'signifying',
#   'it',
#   'strong',
#   'trend',
#   'ajg'],
#  ['disca', 'discoverycommunications', 'ha', 'gross', 'margin', 'of'],
#  ['lyondellbasellindustriesnv',
#   'ha',
#   'weak',
#   'trend',
#   'according',
#   'to',
#   'it',
#   'adx',
#   'of',
#   'lyb'],
#  ['so',
#   'basically',
#   'the',
#   'vip',
#   'and',
#   'premium',
#   'mass',
#   'aren',
#   'spending',
#   'much',
#   'analyst',
#   'fooled',
#   'by',
#   'the',
#   'appearance',
#   'given',
#   'by',
#   'lower',
#   'quality',
#   'mass'],
#  ['skyworkssolutions', 'ha', 'institutional', 'ownership', 'of', 'swks'],
#  ['edisoninternational',
#   'ha',
#   'adx',
#   'of',
#   'signifying',
#   'it',
#   'weak',
#   'trend',
#   'eix'],
#  ['wmb', 'williamscompanies', 'ha', 'volatility', 'of'],
#  ['is',
#   'the',
#   'competition',
#   'profitable',
#   'yes',
#   'are',
#   'they',
#   'collaboration',
#   'with',
#   'waymo',
#   'yes',
#   'do',
#   'they',
#   'have',
#   'cash',
#   'yes'],
#  ['releasing',
#   'earnings',
#   'on',
#   'before',
#   'open',
#   'confirmed',
#   'anybody',
#   'buying',
#   'selling',
#   'in',
#   'earnings'],
#  ['kroger', 'ha', 'very', 'high', 'roce', 'of', 'kr'],
#  ['pcar', 'institutional', 'ownership', 'of', 'paccar', 'is'],
#  ['fcf', 'of', 'citrixsystems', 'is', 'ctxs'],
#  ['profit', 'margin', 'of', 'verisign', 'is', 'vrsn'],
#  ['honeywellinternational',
#   'ha',
#   'beta',
#   'of',
#   'making',
#   'it',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'hon'],
#  ['the', 'dividend', 'yield', 'of', 'lincolnnational', 'is', 'lnc'],
#  ['txn',
#   'texasinstrumentsorporated',
#   'ha',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of'],
#  ['tdc', 'short', 'percent', 'of', 'float', 'of', 'teradata', 'is'],
#  ['sma',
#   'of',
#   'smithao',
#   'is',
#   'now',
#   'down',
#   'by',
#   'and',
#   'sma',
#   'is',
#   'now',
#   'down',
#   'by',
#   'aos'],
#  ['idexxlaboratories', 'ha', 'operating', 'margin', 'of', 'idxx'],
#  ['bby', 'bestbuyco', 'ha', 'revenue', 'per', 'employee', 'of'],
#  ['masco', 'ha', 'gross', 'margin', 'of', 'ma'],
#  ['the', 'payout', 'ratio', 'of', 'nike', 'is', 'nke'],
#  ['len', 'lennar', 'rose', 'by', 'in', 'the', 'last', 'month'],
#  ['clf', 'the', 'roce', 'of', 'cliffsnaturalresources', 'is'],
#  ['totalsystemservices',
#   'ha',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of',
#   'tss'],
#  ['symantec', 'dipped', 'by', 'in', 'the', 'last', 'year', 'symc'],
#  ['rrc', 'rangeresources', 'went', 'down', 'by', 'in', 'the', 'last', 'month'],
#  ['nsc', 'norfolksouther', 'ha', 'revenue', 'per', 'employee', 'of'],
#  ['the',
#   'return',
#   'on',
#   'capital',
#   'employed',
#   'of',
#   'accentureplc',
#   'is',
#   'acn'],
#  ['willistowerswatsonpublic',
#   'is',
#   'le',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'with',
#   'beta',
#   'of',
#   'wltw'],
#  ['genworth', 'ha', 'institutional', 'ownership', 'of', 'gnw'],
#  ['martinmariettamaterials',
#   'ha',
#   'adx',
#   'of',
#   'signifying',
#   'it',
#   'strong',
#   'trend',
#   'mlm'],
#  ['intc', 'operating', 'margin', 'of', 'intel', 'is'],
#  ['operating', 'margin', 'of', 'affiliatedmanagers', 'is', 'amg'],
#  ['spgi', 'spglobal', 'ha', 'volatility', 'of'],
#  ['fbhs',
#   'beta',
#   'of',
#   'fortunebrandshomesecurity',
#   'is',
#   'making',
#   'it',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market'],
#  ['nwl', 'newellbrands', 'dipped', 'by', 'in', 'the', 'last', 'year'],
#  ['coopercompanies', 'ha', 'operating', 'margin', 'of', 'coo'],
#  ['brighthouse',
#   'is',
#   'oversold',
#   'according',
#   'to',
#   'it',
#   'stoch',
#   'rsi',
#   'of',
#   'bhf'],
#  ['ebay', 'the', 'revenue', 'per', 'employee', 'of', 'ebay', 'is'],
#  ['slg', 'operating', 'margin', 'of', 'slgreenrealty', 'is'],
#  ['the', 'recommendation', 'mean', 'of', 'ppgindustries', 'is', 'ppg'],
#  ['tegna', 'dipped', 'by', 'in', 'the', 'last', 'month', 'tgna'],
#  ['dollargeneral', 'ha', 'gross', 'margin', 'of', 'dg'],
#  ['beta',
#   'of',
#   'hess',
#   'make',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'he'],
#  ['insider', 'ownership', 'of', 'vulcanmaterials', 'is', 'vmc'],
#  ['jpm',
#   'of',
#   'floating',
#   'share',
#   'of',
#   'jpmorganchaseco',
#   'are',
#   'being',
#   'shorted'],
#  ['beta',
#   'of',
#   'perrigo',
#   'is',
#   'making',
#   'it',
#   'le',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'prgo'],
#  ['mmc',
#   'marshmclennancompanies',
#   'ha',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of'],
#  ['tsn',
#   'tysonfoods',
#   'ha',
#   'price',
#   'to',
#   'free',
#   'cash',
#   'flow',
#   'ratio',
#   'of'],
#  ['the',
#   'rpe',
#   'revenue',
#   'per',
#   'employee',
#   'of',
#   'intercontinentalexchange',
#   'is',
#   'ice'],
#  ['bectondickinsonand',
#   'ha',
#   'adx',
#   'of',
#   'hinting',
#   'it',
#   'weak',
#   'trend',
#   'bdx'],
#  ['the',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of',
#   'fluor',
#   'is',
#   'flr'],
#  ['pdco',
#   'pattersoncompanies',
#   'ha',
#   'price',
#   'to',
#   'free',
#   'cash',
#   'flow',
#   'ratio',
#   'of'],
#  ['footlocker', 'rose', 'by', 'in', 'the', 'last', 'year', 'fl'],
#  ['we',
#   'have',
#   'detected',
#   'negative',
#   'indicator',
#   'of',
#   'for',
#   'more',
#   'info',
#   'at'],
#  ['aph', 'amphenol', 'ha', 'fcf', 'of'],
#  ...]

# %% [markdown]
# ### Bag of Words
# Now with all of our messages tokenized, we want to create a vocabulary and count up how often each word appears in our entire corpus. Use the [`Counter`](https://docs.python.org/3.1/library/collections.html#collections.Counter) function to count up all the tokens.

# %%
from collections import Counter
import itertools

"""
Create a vocabulary by using Bag of words
"""

# TODO: Implement 
tokenized_flattened = []
for message in messages:
    tokenized_flattened.extend(preprocess(message))

bow = Counter(tokenized_flattened)
bow
# Out:
# Counter({'great': 17570,
#          'buy': 76326,
#          'at': 138459,
#          'ill': 883,
#          'wait': 11370,
#          'staanalystalert': 4072,
#          'for': 273547,
#          'jefferies': 1056,
#          'maintains': 903,
#          'with': 68861,
#          'rating': 15436,
#          'of': 211336,
#          'hold': 22152,
#          'setting': 3889,
#          'target': 16580,
#          'price': 37083,
#          'usd': 2958,
#          'our': 12209,
#          'own': 8970,
#          'verdict': 3736,
#          'is': 284888,
#          'heard': 1357,
#          'there': 25944,
#          'guy': 13425,
#          'who': 17884,
#          'know': 19935,
#          'someone': 5192,
#          'think': 24284,
#          'somebody': 1100,
#          'something': 6010,
#          'on': 241667,
#          'stocktwits': 1439,
#          'reveal': 196,
#          'yourself': 1207,
#          'why': 21707,
#          'the': 398810,
#          'drop': 17792,
#          'warren': 1015,
#          'buffet': 1301,
#          'taking': 6418,
#          'out': 56703,
#          'his': 6256,
#          'position': 11753,
#          'bear': 33541,
#          'have': 52965,
#          'reason': 7777,
#          'to': 379512,
#          'pay': 7609,
#          'more': 55368,
#          'attention': 3531,
#          'ok': 4567,
#          'good': 44206,
#          'we': 64757,
#          're': 13190,
#          'not': 68309,
#          'dropping': 2269,
#          'in': 205324,
#          'over': 32685,
#          'weekend': 3561,
#          'lol': 30941,
#          'daily': 14035,
#          'chart': 15996,
#          'need': 21657,
#          'get': 46704,
#          'back': 43061,
#          'above': 17856,
#          'per': 16565,
#          'week': 44055,
#          'after': 34397,
#          'spike': 2204,
#          'if': 59001,
#          'no': 40432,
#          'news': 19727,
#          'month': 16913,
#          'bo': 610,
#          'then': 20975,
#          'bingo': 181,
#          'what': 79141,
#          'odds': 392,
#          'strong': 17202,
#          'short': 86671,
#          'ratio': 7664,
#          'and': 208510,
#          'float': 4654,
#          'via': 23490,
#          'squeezing': 228,
#          'perfect': 1988,
#          'place': 2849,
#          'an': 22501,
#          'option': 20515,
#          'straddle': 2232,
#          'near': 5825,
#          'supporting': 276,
#          'trend': 8087,
#          'start': 8861,
#          'new': 46415,
#          'monday': 7383,
#          'expect': 10359,
#          'volume': 43709,
#          'across': 781,
#          'key': 8464,
#          'company': 22151,
#          'various': 84,
#          'sector': 5047,
#          'breakout': 6677,
#          'strategy': 1608,
#          'current': 6187,
#          'portfolio': 2469,
#          'bull': 27167,
#          'catalyst': 1284,
#          'continuing': 351,
#          'this': 203573,
#          'uptrend': 1688,
#          'pill': 196,
#          'pack': 191,
#          'amazon': 10934,
#          'prime': 1825,
#          'day': 67487,
#          'earnings': 52932,
#          'test': 4027,
#          'break': 17101,
#          'soon': 16164,
#          'ha': 44265,
#          'moved': 3368,
#          'check': 5455,
#          'movement': 2866,
#          'peer': 3180,
#          'mkm': 164,
#          'partner': 1166,
#          'set': 5841,
#          'it': 193537,
#          'too': 18991,
#          'early': 4770,
#          'tell': 4651,
#          'going': 48017,
#          'happen': 4281,
#          'even': 15815,
#          'about': 27608,
#          'raisinf': 1,
#          'output': 109,
#          'still': 35231,
#          'so': 45890,
#          'many': 9461,
#          'financially': 570,
#          'healthy': 1808,
#          'problem': 2754,
#          'meeting': 1002,
#          'obligation': 670,
#          'bullish': 25205,
#          'stock': 75434,
#          'watch': 14696,
#          'setup': 8108,
#          'timeframes': 39,
#          'blog': 539,
#          'by': 53988,
#          'just': 73196,
#          'high': 28326,
#          'alert': 12213,
#          'next': 46982,
#          'gt': 9390,
#          'breakdown': 1104,
#          'much': 16601,
#          'better': 13772,
#          'than': 29130,
#          'industry': 7782,
#          'average': 9331,
#          'miss': 6974,
#          'these': 14131,
#          'confirms': 411,
#          'you': 94325,
#          'will': 128207,
#          'see': 44343,
#          'violent': 147,
#          'move': 22530,
#          'downward': 831,
#          'my': 51356,
#          'base': 1468,
#          'gap': 9765,
#          'ma': 5054,
#          'cabot': 106,
#          'weekly': 7172,
#          'video': 2816,
#          'quot': 40091,
#          'resilient': 137,
#          'growth': 36093,
#          'when': 30042,
#          'wa': 55257,
#          'kid': 1696,
#          'froend': 1,
#          'told': 3842,
#          'me': 25902,
#          'moon': 2177,
#          'made': 7819,
#          'cheese': 116,
#          'percent': 6303,
#          'rank': 5337,
#          'th': 6570,
#          'percentile': 1399,
#          'thank': 4123,
#          'don': 25444,
#          'feel': 5989,
#          'or': 37471,
#          'do': 24611,
#          'well': 16550,
#          'they': 56358,
#          'already': 9658,
#          'during': 2561,
#          'youtube': 598,
#          'interview': 623,
#          'mitch': 62,
#          'couldn': 1252,
#          'remember': 4819,
#          'single': 2166,
#          'movie': 881,
#          'he': 11569,
#          'watched': 394,
#          'all': 59896,
#          'year': 34383,
#          'except': 1131,
#          'star': 2384,
#          'war': 4958,
#          'black': 1214,
#          'panther': 25,
#          'clothes': 115,
#          'downgrade': 4255,
#          'sale': 27059,
#          'interest': 11781,
#          'return': 7074,
#          'equity': 3267,
#          'although': 1869,
#          'market': 53671,
#          'up': 121579,
#          'doing': 5537,
#          'advanced': 992,
#          'info': 3817,
#          'july': 3147,
#          'be': 89281,
#          'most': 8235,
#          'normal': 1624,
#          'friday': 11161,
#          'contract': 14254,
#          'call': 67782,
#          'put': 36961,
#          'third': 1593,
#          'design': 609,
#          'win': 5867,
#          'timing': 658,
#          'match': 409,
#          'probably': 5059,
#          'arm': 307,
#          'alcohol': 72,
#          'tobacco': 149,
#          'firearm': 3,
#          'president': 2847,
#          'trump': 11800,
#          'tweet': 1397,
#          'spoke': 172,
#          'king': 1307,
#          'salman': 4,
#          'saudi': 757,
#          'arabia': 150,
#          'explained': 115,
#          'him': 2091,
#          'that': 89677,
#          'because': 7871,
#          'turmoil': 129,
#          'amp': 35686,
#          'today': 76251,
#          'insight': 8187,
#          'intc': 1984,
#          'mama': 154,
#          'said': 9402,
#          'ice': 375,
#          'cream': 115,
#          'finish': 1167,
#          'due': 3700,
#          'dil': 3,
#          'noticed': 365,
#          'last': 38611,
#          'jedi': 176,
#          'stream': 605,
#          'love': 10349,
#          'here': 74957,
#          'go': 52761,
#          'leave': 1353,
#          'view': 5128,
#          'look': 31200,
#          'ema': 1388,
#          'held': 2811,
#          'stochastics': 73,
#          'turning': 1167,
#          'spy': 2137,
#          'qqq': 655,
#          'opposite': 876,
#          'forward': 3415,
#          'pe': 4546,
#          'valuation': 4518,
#          'can': 44221,
#          'described': 346,
#          'cheap': 7837,
#          'saber': 13,
#          'capital': 2886,
#          'presentation': 626,
#          'common': 1432,
#          'denominator': 9,
#          'tencent': 164,
#          'facebook': 8707,
#          'google': 3214,
#          'how': 24453,
#          'one': 27505,
#          'performing': 859,
#          'crude': 489,
#          'petroleum': 249,
#          'natural': 517,
#          'gas': 1494,
#          'pu': 49,
#          'simply': 636,
#          'havent': 214,
#          'lost': 4552,
#          'any': 14394,
#          'brown': 254,
#          'run': 15786,
#          'tech': 9891,
#          'mf': 308,
#          'are': 101427,
#          'educated': 114,
#          'their': 24227,
#          'shit': 6413,
#          'every': 8941,
#          'former': 435,
#          'global': 2508,
#          'manufacturing': 363,
#          'pfizer': 452,
#          'independent': 150,
#          'director': 5452,
#          'nat': 136,
#          'ricciardi': 4,
#          'may': 10952,
#          'safest': 153,
#          'special': 627,
#          'limited': 553,
#          'offer': 1526,
#          'june': 1300,
#          'tradenet': 4,
#          'offering': 643,
#          'discount': 1455,
#          'intro': 49,
#          'program': 1011,
#          'below': 11233,
#          'financials': 989,
#          'summary': 464,
#          'jeff': 687,
#          'gundlach': 41,
#          'sohn': 23,
#          'long': 32557,
#          'thesis': 1005,
#          'energy': 2789,
#          'low': 23159,
#          'peg': 547,
#          'which': 8193,
#          'compensates': 296,
#          'indicates': 1981,
#          'rather': 2368,
#          'pres': 352,
#          'coming': 18934,
#          'seems': 5392,
#          'support': 16991,
#          'under': 8997,
#          'likely': 3646,
#          'bullshit': 875,
#          'worthless': 1025,
#          'mean': 6164,
#          'fucking': 2385,
#          'nothing': 7014,
#          'macau': 279,
#          'usa': 1071,
#          'take': 17635,
#          'let': 26918,
#          'where': 12422,
#          'right': 19051,
#          'now': 57534,
#          'ugly': 1841,
#          'without': 2339,
#          'clear': 2622,
#          'level': 9589,
#          'term': 17568,
#          'bearish': 11440,
#          'll': 13146,
#          'previously': 2035,
#          'mo': 893,
#          'followed': 973,
#          'end': 15778,
#          'another': 14004,
#          'runup': 188,
#          'dropped': 2955,
#          'smart': 3332,
#          'money': 24860,
#          'betting': 856,
#          'deal': 6722,
#          'update': 20555,
#          'technical': 11303,
#          'bad': 13240,
#          'doe': 11174,
#          'present': 2424,
#          'nice': 17344,
#          'opportunity': 5874,
#          'completely': 1017,
#          'scale': 382,
#          'time': 39415,
#          'gobble': 106,
#          'play': 9231,
#          'aka': 336,
#          'favorite': 870,
#          'them': 11059,
#          'iddy': 1,
#          'bitty': 10,
#          'kiddy': 33,
#          'hand': 3733,
#          'awesome': 1846,
#          'concerned': 541,
#          'eow': 2111,
#          'might': 8907,
#          'wk': 1305,
#          'throwback': 59,
#          'advisor': 220,
#          'upgrade': 6839,
#          'shorties': 808,
#          'dreaming': 232,
#          'depression': 139,
#          'somethin': 27,
#          'loll': 48,
#          'updated': 814,
#          'hormel': 115,
#          'food': 1482,
#          'dividend': 8423,
#          'analysis': 3390,
#          'consumer': 1989,
#          'defensive': 282,
#          'intel': 7968,
#          'profitability': 1887,
#          'safety': 1126,
#          'score': 2652,
#          'technology': 3125,
#          'both': 6238,
#          'positive': 9034,
#          'looking': 17934,
#          'mad': 1240,
#          'report': 55267,
#          'block': 9925,
#          'person': 698,
#          'spam': 272,
#          'should': 24027,
#          'open': 20695,
#          'projection': 280,
#          'thats': 2258,
#          'true': 2132,
#          'prefer': 361,
#          'from': 62388,
#          'turd': 1080,
#          'wal': 125,
#          'mart': 147,
#          'aristocrat': 302,
#          'valueinvesting': 53,
#          'dvb': 22,
#          'aaamp': 28,
#          'marriage': 38,
#          'bank': 7542,
#          'account': 2801,
#          'dm': 57,
#          'won': 5420,
#          'stop': 12796,
#          'posting': 1290,
#          'holding': 14809,
#          'big': 27628,
#          'calm': 907,
#          'down': 69368,
#          'luck': 3427,
#          'chase': 1362,
#          'continues': 2442,
#          'hopefully': 2618,
#          'catch': 1750,
#          'before': 25834,
#          'lisa': 3075,
#          'announces': 3374,
#          'rd': 1374,
#          'permamently': 1,
#          'turned': 1356,
#          'off': 21258,
#          'trading': 21177,
#          'maybe': 7823,
#          'altogether': 26,
#          'manipulation': 2484,
#          'very': 20009,
#          'rich': 1601,
#          'make': 19934,
#          'poor': 1889,
#          'fuk': 226,
#          'almost': 5592,
#          'pct': 747,
#          'buyback': 5102,
#          'got': 16215,
#          'share': 48702,
#          'though': 4117,
#          'drip': 324,
#          'dumped': 1063,
#          'obv': 181,
#          'but': 53512,
#          'jeez': 339,
#          'bit': 4450,
#          'done': 5480,
#          'bounce': 11618,
#          'heikin': 10,
#          'ashi': 12,
#          'candle': 3264,
#          'confirmation': 739,
#          'liking': 419,
#          'wife': 650,
#          'tree': 514,
#          'fiddy': 32,
#          'sure': 8301,
#          'piggy': 270,
#          'lot': 10025,
#          'coin': 405,
#          'spend': 805,
#          'candy': 113,
#          'microsoft': 1969,
#          'investor': 8403,
#          'aren': 1687,
#          'happy': 4356,
#          'royal': 433,
#          'canada': 1345,
#          'reiterates': 1333,
#          'outperform': 1850,
#          'loop': 286,
#          'raise': 5772,
#          'never': 9018,
#          'been': 19825,
#          'wrong': 5608,
#          'miracle': 311,
#          'period': 1162,
#          'bollinger': 1347,
#          'band': 1516,
#          'dare': 353,
#          'say': 16287,
#          'didn': 5922,
#          'guilty': 97,
#          'fudge': 65,
#          'hardly': 255,
#          'ever': 5632,
#          'informative': 33,
#          'comment': 2098,
#          'page': 564,
#          'broken': 1592,
#          'giving': 1778,
#          'endless': 233,
#          'buffering': 4,
#          'icon': 95,
#          'give': 7675,
#          'viral': 18,
#          'walk': 1117,
#          'away': 4801,
#          'highlight': 249,
#          'growing': 2233,
#          'democrat': 278,
#          'leaving': 872,
#          'party': 1707,
#          'epoch': 2,
#          'robert': 973,
#          'baird': 650,
#          'neutral': 3513,
#          'weed': 717,
#          'other': 8473,
#          'drug': 1313,
#          'guess': 5927,
#          'reasonable': 610,
#          'nike': 4005,
#          'winning': 2108,
#          'click': 886,
#          'booking': 824,
#          'app': 5948,
#          'native': 20,
#          'seamless': 10,
#          'lovalized': 1,
#          'transactable': 1,
#          'ap': 80,
#          'vitiello': 1,
#          'tapped': 126,
#          'acting': 770,
#          'reach': 1962,
#          'iconic': 63,
#          'brand': 1969,
#          'built': 445,
#          'mobile': 965,
#          'show': 9569,
#          'morning': 11342,
#          'heading': 2783,
#          'ath': 3145,
#          'acquisition': 1769,
#          'total': 6061,
#          'past': 8306,
#          'exit': 1473,
#          'zone': 1588,
#          'fantastic': 574,
#          'read': 3822,
#          'oil': 4761,
#          'tighten': 205,
#          'bbl': 151,
#          'getting': 12184,
#          'closer': 977,
#          'greatest': 421,
#          'yearly': 1241,
#          'performance': 2094,
#          'did': 12610,
#          'champion': 159,
#          'cashflow': 75,
#          'highyield': 23,
#          'telecommunication': 7,
#          'pretty': 4504,
#          'risky': 713,
#          'gamble': 832,
#          'either': 3236,
#          'plummet': 326,
#          'rally': 6210,
#          'stronger': 867,
#          'apple': 12830,
#          'talking': 2745,
#          'referring': 107,
#          'intelsat': 6,
#          'punish': 128,
#          'seller': 3017,
#          'warehouse': 88,
#          'sense': 2205,
#          'old': 3815,
#          'gather': 129,
#          'dust': 433,
#          'pc': 615,
#          'gamers': 213,
#          'crypto': 1741,
#          'miner': 169,
#          'gpu': 1306,
#          'enthusiast': 27,
#          'waiting': 7246,
#          'two': 5514,
#          'only': 19012,
#          'medium': 3271,
#          'decent': 2928,
#          'pattern': 6528,
#          'five': 740,
#          'baba': 546,
#          'ahhhhhhhhhhhhhhhhhhhhh': 1,
#          'raytheon': 176,
#          'industrials': 309,
#          'military': 308,
#          'trending': 1957,
#          'riiiiiiiiiich': 1,
#          'sooooon': 11,
#          'buuuuls': 1,
#          'looooove': 4,
#          'drunk': 207,
#          'doesn': 6277,
#          'through': 6157,
#          'gapping': 285,
#          'warbey': 1,
#          'parker': 204,
#          'prep': 102,
#          'glass': 296,
#          'seen': 3833,
#          'focus': 1057,
#          'fashion': 212,
#          'wrt': 16,
#          'wearable': 106,
#          'like': 51921,
#          'sbux': 227,
#          'paying': 1526,
#          'full': 2984,
#          'sex': 171,
#          'change': 5184,
#          'employee': 1101,
#          'hit': 12524,
#          'bottom': 9698,
#          'line': 7061,
#          'recap': 1344,
#          'since': 22612,
#          'post': 7910,
#          'trade': 49477,
#          'included': 375,
#          'hsy': 25,
#          'uri': 46,
#          'sonc': 11,
#          'dri': 41,
#          'kmx': 32,
#          'wynn': 506,
#          'akam': 48,
#          'enterprise': 1330,
#          'value': 5684,
#          'cap': 4044,
#          'difference': 602,
#          'actual': 649,
#          'asset': 1897,
#          'spread': 2455,
#          'way': 16482,
#          'undervalued': 2519,
#          'million': 6394,
#          'added': 5564,
#          'dont': 6263,
#          'become': 1583,
#          'such': 2917,
#          'monopoly': 326,
#          'dipping': 306,
#          'into': 17281,
#          'everything': 4297,
#          'airline': 944,
#          'possibility': 469,
#          'loss': 7745,
#          'suggested': 321,
#          'chartmill': 199,
#          'analyzer': 520,
#          'resistance': 7073,
#          'len': 58,
#          'reversal': 4918,
#          'progress': 565,
#          've': 6742,
#          'recently': 828,
#          'closed': 3355,
#          'list': 3255,
#          'bought': 19135,
#          'same': 12092,
#          'used': 1744,
#          'according': 2034,
#          'data': 9734,
#          'reported': 14152,
#          'finra': 2763,
#          'clocked': 707,
#          'official': 472,
#          'came': 1631,
#          'saying': 4024,
#          'agree': 1544,
#          'resume': 516,
#          'cover': 5879,
#          'penis': 47,
#          'putang': 1,
#          'front': 570,
#          'leg': 2239,
#          'would': 22411,
#          'some': 30472,
#          'am': 14395,
#          'watching': 5571,
#          'wonder': 2999,
#          'valued': 1624,
#          'inning': 69,
#          'higher': 25481,
#          'also': 7917,
#          'shorted': 2973,
#          'consolidation': 2030,
#          'cautious': 516,
#          'stunned': 42,
#          'deeply': 92,
#          'disappointed': 457,
#          'close': 29517,
#          'ending': 1214,
#          'killed': 1221,
#          'best': 9982,
#          'february': 375,
#          'cl': 563,
#          'funny': 2522,
#          'thing': 12606,
#          'similar': 1136,
#          'story': 2651,
#          'different': 1559,
#          'crab': 39,
#          'measured': 489,
#          'divergence': 774,
#          'really': 11288,
#          'momentum': 3392,
#          'starting': 3250,
#          'shi': 59,
#          'venture': 299,
#          'tariff': 8068,
#          'increase': 3983,
#          'profit': 16092,
#          'recession': 1042,
#          'come': 18482,
#          'keep': 14977,
#          'buying': 23827,
#          'pure': 933,
#          'beanscreen': 2,
#          'min': 5729,
#          'indicating': 431,
#          'accumulation': 732,
#          'eod': 5177,
#          'could': 16217,
#          'pop': 7581,
#          'heavy': 1715,
#          'apog': 7,
#          'acn': 46,
#          'camp': 62,
#          'gi': 61,
#          'payx': 23,
#          'fdx': 113,
#          'goo': 179,
#          'squeeze': 5672,
#          'pullback': 4543,
#          'upside': 5176,
#          'nvda': 3197,
#          'safe': 1991,
#          'yield': 2523,
#          'div': 2205,
#          'adding': 2957,
#          'gladly': 91,
#          'irrationality': 24,
#          'reign': 40,
#          'possible': 4173,
#          'excess': 66,
#          'gain': 11675,
#          'welcome': 1341,
#          'gl': 3047,
#          'seeing': 2562,
#          'jumping': 707,
#          'joy': 272,
#          'least': 5507,
#          'given': 2986,
#          'action': 6832,
#          'bouncing': 948,
#          'continuation': 584,
#          'hopeful': 168,
#          'science': 320,
#          'officially': 540,
#          'became': 318,
#          'major': 3733,
#          'university': 70,
#          'ai': 1731,
#          'brainers': 5,
#          'era': 292,
#          'second': 3447,
#          'minute': 5133,
#          'rule': 2004,
#          'applies': 83,
#          'zbra': 6,
#          'six': 557,
#          'fc': 23,
#          'gbx': 4,
#          'fds': 31,
#          'avav': 9,
#          'killing': 1666,
#          'tax': 2252,
#          'cut': 4888,
#          'idea': 3827,
#          'haven': 1829,
#          'posted': 4218,
#          'while': 7227,
#          'omg': 1698,
#          'toy': 360,
#          'land': 607,
#          'amazing': 3002,
#          'contributed': 38,
#          'ytd': 1173,
#          'popular': 406,
#          'word': 2041,
#          'buyin': 130,
#          'those': 9851,
#          'dip': 17730,
#          'haha': 2082,
#          'makin': 55,
#          'rain': 217,
#          'white': 924,
#          'house': 1699,
#          'quality': 1462,
#          'moment': 2631,
#          'doubt': 1738,
#          'production': 937,
#          'eps': 33298,
#          'constellation': 327,
#          'disney': 1297,
#          'clinch': 9,
#          'acquire': 712,
#          'fox': 767,
#          'group': 4422,
#          'counter': 250,
#          'aggregate': 761,
#          'southwest': 152,
#          'flight': 328,
#          'dallas': 44,
#          'delta': 421,
#          'spat': 52,
#          'california': 290,
#          'netflix': 5120,
#          'inc': 7010,
#          'nflx': 3252,
#          'versus': 926,
#          'fb': 7815,
#          'starbucks': 593,
#          'using': 2148,
#          'iex': 2187,
#          'calculate': 207,
#          'shorters': 271,
#          'emergence': 1,
#          'bankruptcy': 1423,
#          'emergency': 85,
#          'zwj': 6,
#          'investment': 4288,
#          'counsel': 371,
#          'lower': 16060,
#          'stake': 1025,
#          'unitedhealth': 172,
#          'unh': 107,
#          'tyzen': 1,
#          'vega': 682,
#          'laptop': 368,
#          'investing': 1676,
#          'annuity': 17,
#          'yr': 2894,
#          'bond': 1263,
#          'continue': 3691,
#          'add': 6076,
#          'unsure': 70,
#          'country': 1033,
#          'amd': 22535,
#          'ryzen': 1003,
#          'gettin': 151,
#          'blasted': 70,
#          'cgnx': 6,
#          'cx': 40,
#          'aaoi': 53,
#          'aa': 76,
#          'amswa': 1,
#          'yy': 20,
#          'snx': 8,
#          'shark': 214,
#          'definitely': 1899,
#          'august': 2665,
#          'point': 8711,
#          'huge': 9307,
#          'closing': 3857,
#          'scalp': 1291,
#          'giant': 1404,
#          'fermenting': 1,
#          'marked': 88,
#          'compared': 2780,
#          'book': 1963,
#          'cheaply': 737,
#          'quite': 3393,
#          'job': 3568,
#          'started': 5092,
#          'clearly': 1056,
#          'cup': 1974,
#          'holder': 2398,
#          'inverse': 505,
#          'confidence': 771,
#          'debt': 3076,
#          'sell': 35150,
#          'interesting': 3532,
#          'frame': 436,
#          'trader': 4621,
#          'meanwhile': 505,
#          'galaxy': 121,
#          'far': 5527,
#          'broadening': 29,
#          'wedge': 1253,
#          'descending': 312,
#          'large': 6258,
#          'im': 5083,
#          'pt': 16287,
#          'three': 1642,
#          'falling': 3279,
#          'peak': 1897,
#          'fourth': 250,
#          'everyone': 8409,
#          'coke': 281,
#          'smile': 213,
#          'thanks': 5687,
#          'selling': 17609,
#          'prove': 454,
#          'terrible': 937,
#          'error': 161,
#          'article': 2513,
#          'hint': 345,
#          'sogou': 11,
#          'finger': 680,
#          'crossed': 1344,
#          'triple': 1168,
#          'top': 14099,
#          'bro': 615,
#          'work': 5147,
#          'delete': 293,
#          'blue': 1663,
#          'arrow': 118,
#          'your': 25510,
#          'delusion': 82,
#          'overbought': 1692,
#          'changing': 490,
#          'mr': 1179,
#          'yo': 895,
#          'hi': 795,
#          'bed': 715,
#          'night': 2769,
#          'prepared': 346,
#          'policy': 364,
#          'penalizing': 2,
#          'store': 8265,
#          'product': 4594,
#          ...})

# %% [markdown]
# ### Frequency of Words Appearing in Message
# With our vocabulary, now we'll remove some of the most common words such as 'the', 'and', 'it', etc. These words don't contribute to identifying sentiment and are really common, resulting in a lot of noise in our input. If we can filter these out, then our network should have an easier time learning.
#
# We also want to remove really rare words that show up in a only a few twits. Here you'll want to divide the count of each word by the **number of messages** calculated in the code block above (i.e. `len(messages))`. Then remove words that only appear in some small fraction of the messages.
#
# >Note: There is not an exact number for low and high-frequency cut-offs, however there is a correct optimal range.
# You should ideally set up low-frequency cut-off from 0.0000002 to 0.000007 (inclusive) and high-frequency from 5 to 20 (inclusive). If the number is too big, we lose lots of important words that we can use in our data.

# %%
"""
Set the following variables:
    freqs
    low_cutoff
    high_cutoff
    K_most_common
"""

# TODO Implement 

# Dictionart that contains the Frequency of words appearing in messages.
# The key is the token and the value is the frequency of that word in the corpus.
freqs_total = sum(bow.values())
freqs = {word: count / freqs_total for word, count in bow.items()}
freqs = {word: value for word, value in sorted(freqs.items(), key=lambda item: item[1], reverse=True)}

# Float that is the frequency cutoff. Drop words with a frequency that is lower or equal to this number.
low_cutoff = 0.0000007

# Integer that is the cut off for most common words. Drop words that are the `high_cutoff` most common words.
high_cutoff = 14

# The k most common words in the corpus. Use `high_cutoff` as the k.
K_most_common = list(freqs.keys())[:high_cutoff]


filtered_words = [word for word in freqs if (freqs[word] > low_cutoff and word not in K_most_common)]
print(K_most_common)
len(filtered_words)
# Out:
# ['the', 'to', 'is', 'for', 'on', 'of', 'and', 'in', 'this', 'it', 'at', 'will', 'up', 'are']
# 18120

# %% [markdown]
# ### Updating Vocabulary by Removing Filtered Words
# Let's creat three variables that will help with our vocabulary.

# %%
"""
Set the following variables:
    vocab
    id2vocab
    filtered
"""

#TODO Implement

# A dictionary for the `fialtered_words`. The key is the word and value is an id that represents the word. 
vocab = {word: ii for ii, word in enumerate(filtered_words, 1)}
# Reverse of the `vocab` dictionary. The key is word id and value is the word. 
id2vocab = {ii: word for word, ii in vocab.items()}
# tokenized with the words not in `filtered_words` removed.
filtered = []
for tokenizedItem in tokenized:
    filtered.append([word for word in tokenizedItem if word in vocab])

assert set(vocab.keys()) == set(id2vocab.values()), 'Check vocab and id2vocab dictionaries'
filtered
# Out:
# [['great', 'buy', 'ill', 'wait'],
#  [],
#  ['staanalystalert',
#   'jefferies',
#   'maintains',
#   'with',
#   'rating',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'buy'],
#  ['heard',
#   'there',
#   'guy',
#   'who',
#   'know',
#   'someone',
#   'who',
#   'think',
#   'somebody',
#   'know',
#   'something',
#   'stocktwits'],
#  ['reveal', 'yourself'],
#  ['why', 'drop', 'warren', 'buffet', 'taking', 'out', 'his', 'position'],
#  ['bear', 'have', 'reason', 'pay', 'more', 'attention'],
#  ['ok',
#   'good',
#   'we',
#   're',
#   'not',
#   'dropping',
#   'price',
#   'over',
#   'weekend',
#   'lol'],
#  ['daily', 'chart', 'we', 'need', 'get', 'back', 'above'],
#  ['drop',
#   'per',
#   'week',
#   'after',
#   'spike',
#   'if',
#   'no',
#   'news',
#   'month',
#   'back',
#   'if',
#   'bo',
#   'then',
#   'bingo',
#   'what',
#   'odds'],
#  ['strong', 'buy'],
#  ['short', 'ratio', 'short', 'float', 'via'],
#  ['price',
#   'squeezing',
#   'perfect',
#   'place',
#   'an',
#   'option',
#   'straddle',
#   'near',
#   'supporting',
#   'trend'],
#  ['start',
#   'new',
#   'monday',
#   'expect',
#   'strong',
#   'buy',
#   'volume',
#   'across',
#   'key',
#   'company',
#   'various',
#   'sector'],
#  ['breakout', 'strategy', 'current', 'portfolio'],
#  ['bull', 'have', 'reason', 'pay', 'more', 'attention'],
#  ['catalyst',
#   'continuing',
#   'new',
#   'uptrend',
#   'pill',
#   'pack',
#   'buy',
#   'out',
#   'amazon',
#   'prime',
#   'day',
#   'earnings',
#   'test',
#   'break',
#   'soon'],
#  ['ha', 'moved', 'check', 'out', 'movement', 'peer'],
#  ['staanalystalert',
#   'mkm',
#   'partner',
#   'set',
#   'price',
#   'target',
#   'with',
#   'rating',
#   'buy',
#   'setting',
#   'target',
#   'price',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'buy'],
#  ['think',
#   'too',
#   'early',
#   'tell',
#   'what',
#   'going',
#   'happen',
#   'monday',
#   'even',
#   'with',
#   'current',
#   'news',
#   'about',
#   'output',
#   'there',
#   'still',
#   'so',
#   'many'],
#  ['ha',
#   'current',
#   'ratio',
#   'so',
#   'financially',
#   'healthy',
#   'ha',
#   'no',
#   'problem',
#   'meeting',
#   'obligation'],
#  ['bullish', 'stock', 'watch', 'setup', 'timeframes', 'blog', 'by'],
#  ['just', 'short'],
#  ['high', 'alert', 'next', 'week', 'gt', 'breakdown'],
#  ['current', 'ratio', 'much', 'better', 'than', 'industry', 'average'],
#  ['miss', 'these', 'day'],
#  ['if',
#   'break',
#   'confirms',
#   'next',
#   'week',
#   'you',
#   'see',
#   'violent',
#   'move',
#   'downward',
#   'my',
#   'buy',
#   'price'],
#  ['bear', 'have', 'reason', 'pay', 'more', 'attention'],
#  ['breakout', 'base', 'gap', 'day', 'ma', 'gap', 'gap', 'gap', 'day', 'ma'],
#  ['cabot',
#   'weekly',
#   'video',
#   'quot',
#   'resilient',
#   'growth',
#   'stock',
#   'watch',
#   'quot'],
#  ['when',
#   'wa',
#   'kid',
#   'my',
#   'told',
#   'me',
#   'moon',
#   'wa',
#   'made',
#   'out',
#   'cheese'],
#  ['short', 'volume', 'percent', 'wa', 'day', 'rank', 'wa', 'th', 'percentile'],
#  ['thank',
#   'you',
#   'don',
#   'feel',
#   'need',
#   'tell',
#   'or',
#   'do',
#   'well',
#   'me',
#   'they',
#   'already',
#   'have'],
#  ['during',
#   'youtube',
#   'interview',
#   'mitch',
#   'couldn',
#   'remember',
#   'single',
#   'movie',
#   'he',
#   'watched',
#   'all',
#   'year',
#   'except',
#   'star',
#   'war',
#   'black',
#   'panther',
#   'clothes'],
#  ['staanalystalert',
#   'jefferies',
#   'downgrade',
#   'with',
#   'rating',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'hold'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['ha', 'better', 'return', 'equity', 'than', 'industry', 'average'],
#  ['although',
#   'market',
#   'doing',
#   'even',
#   'better',
#   'ha',
#   'advanced',
#   'more',
#   'info',
#   'peer'],
#  ['july', 'be', 'most', 'bullish', 'day', 'year', 'stock'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'put',
#   'volume',
#   'wa'],
#  ['third', 'design', 'win', 'timing', 'match', 'probably', 'arm'],
#  ['alcohol', 'stock', 'tobacco', 'stock', 'stock', 'buy'],
#  ['president',
#   'trump',
#   'tweet',
#   'just',
#   'spoke',
#   'king',
#   'saudi',
#   'arabia',
#   'explained',
#   'him',
#   'that',
#   'because',
#   'turmoil',
#   'amp'],
#  ['today', 'insight'],
#  ['intc', 'mama', 'said', 'get', 'ice', 'cream', 'if', 'finish', 'my', 'due'],
#  ['just',
#   'noticed',
#   'they',
#   'have',
#   'last',
#   'jedi',
#   'stream',
#   'love',
#   'stock'],
#  ['here', 'you', 'go', 'just', 'leave', 'here'],
#  ['good',
#   'view',
#   'daily',
#   'still',
#   'look',
#   'good',
#   'ema',
#   'held',
#   'above',
#   'ema',
#   'stochastics',
#   'turning',
#   'healthy',
#   'spy',
#   'qqq',
#   'opposite'],
#  ['with', 'forward', 'pe', 'valuation', 'can', 'be', 'described', 'cheap'],
#  ['saber',
#   'capital',
#   'presentation',
#   'common',
#   'tencent',
#   'facebook',
#   'google'],
#  ['how', 'expect', 'earnings'],
#  ['one',
#   'better',
#   'performing',
#   'stock',
#   'crude',
#   'petroleum',
#   'natural',
#   'gas',
#   'industry'],
#  ['pu',
#   'simply',
#   'havent',
#   'lost',
#   'any',
#   'brown',
#   'guy',
#   'run',
#   'tech',
#   'company',
#   'mf',
#   'well',
#   'educated',
#   'know',
#   'their',
#   'shit',
#   'more',
#   'more',
#   'every',
#   'year'],
#  ['former',
#   'president',
#   'global',
#   'manufacturing',
#   'pfizer',
#   'an',
#   'independent',
#   'director',
#   'nat'],
#  ['may', 'be', 'safest', 'stock', 'own'],
#  ['special',
#   'limited',
#   'offer',
#   'june',
#   'th',
#   'june',
#   'th',
#   'offering',
#   'discount',
#   'intro',
#   'program'],
#  ['below', 'buy', 'put', 'financials'],
#  ['great',
#   'summary',
#   'jeff',
#   'gundlach',
#   'sohn',
#   'presentation',
#   'long',
#   'thesis',
#   'energy',
#   'stock'],
#  ['low',
#   'peg',
#   'ratio',
#   'which',
#   'compensates',
#   'pe',
#   'growth',
#   'indicates',
#   'rather',
#   'cheap',
#   'valuation'],
#  ['great',
#   'summary',
#   'jeff',
#   'gundlach',
#   'sohn',
#   'pres',
#   'long',
#   'thesis',
#   'energy',
#   'equity'],
#  ['coming'],
#  ['seems', 'support', 'next', 'if', 'under', 'likely'],
#  ['ha', 'moved', 'check', 'out', 'movement', 'peer'],
#  ['bullshit',
#   'worthless',
#   'mean',
#   'fucking',
#   'nothing',
#   'macau',
#   'not',
#   'fucking',
#   'usa'],
#  ['take', 'let', 'me', 'know', 'where', 'we', 'right', 'now', 'lol'],
#  ['chart',
#   'look',
#   'so',
#   'ugly',
#   'without',
#   'clear',
#   'support',
#   'level',
#   'short',
#   'term',
#   'bearish',
#   'll',
#   'buy',
#   'when'],
#  ['great',
#   'summary',
#   'jeff',
#   'gundlach',
#   'sohn',
#   'presentation',
#   'long',
#   'thesis',
#   'energy',
#   'stock'],
#  ['previously',
#   'there',
#   'wa',
#   'mo',
#   'run',
#   'followed',
#   'by',
#   'drop',
#   'we',
#   'end',
#   'month',
#   'another',
#   'runup',
#   'have',
#   'dropped',
#   'about'],
#  ['smart', 'money', 'betting', 'call', 'deal', 'update'],
#  ['although',
#   'technical',
#   'rating',
#   'bad',
#   'doe',
#   'present',
#   'nice',
#   'setup',
#   'opportunity'],
#  ['completely',
#   'scale',
#   'out',
#   'time',
#   'gobble',
#   'my',
#   'next',
#   'long',
#   'play',
#   'aka',
#   'my',
#   'favorite',
#   'gt'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['them', 'kiddy', 'hand'],
#  ['short', 'interest', 'ratio', 'short', 'float', 'via'],
#  ['then',
#   'awesome',
#   'now',
#   'be',
#   'concerned',
#   'if',
#   'not',
#   'over',
#   'by',
#   'eow',
#   'might',
#   'get',
#   'under',
#   'next',
#   'wk',
#   'or',
#   'soon'],
#  ['throwback'],
#  ['staanalystalert',
#   'capital',
#   'advisor',
#   'upgrade',
#   'with',
#   'rating',
#   'hold',
#   'our',
#   'own',
#   'verdict',
#   'buy'],
#  ['lol',
#   'all',
#   'these',
#   'shorties',
#   'dreaming',
#   'great',
#   'depression',
#   'or',
#   'somethin',
#   'loll'],
#  ['just',
#   'updated',
#   'hormel',
#   'food',
#   'dividend',
#   'king',
#   'stock',
#   'analysis',
#   'dividend',
#   'king',
#   'consumer',
#   'defensive'],
#  ['today', 'insight'],
#  ['just',
#   'updated',
#   'intel',
#   'valuation',
#   'profitability',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'technology'],
#  ['today', 'insight'],
#  ['long', 'short', 'term', 'trend', 'both', 'positive', 'looking', 'good'],
#  ['they', 'so', 'mad', 'me', 'still'],
#  ['back', 'by', 'july'],
#  ['report', 'block', 'person', 'spam'],
#  ['should', 'open', 'monday'],
#  ['my',
#   'projection',
#   'if',
#   'thats',
#   'true',
#   'under',
#   'next',
#   'week',
#   'thats',
#   'why',
#   'prefer',
#   'buy',
#   'from',
#   'support',
#   'level'],
#  ['what', 'turd'],
#  ['percent', 'short', 'volume', 'wa'],
#  ['wal',
#   'mart',
#   'dividend',
#   'aristocrat',
#   'dividend',
#   'aristocrat',
#   'consumer',
#   'defensive',
#   'valueinvesting',
#   'dvb',
#   'aaamp'],
#  ['looking',
#   'marriage',
#   'have',
#   'my',
#   'bank',
#   'account',
#   'with',
#   'stock',
#   'dm'],
#  ['short', 'ratio', 'short', 'float', 'via'],
#  ['that',
#   'bear',
#   'that',
#   'won',
#   'stop',
#   'posting',
#   'holding',
#   'big',
#   'short',
#   'position',
#   'over',
#   'weekend',
#   'calm',
#   'down',
#   'good',
#   'luck',
#   'lol'],
#  ['chase',
#   'continues',
#   'hopefully',
#   'they',
#   'catch',
#   'him',
#   'before',
#   'lisa',
#   'announces',
#   'rd',
#   'win'],
#  ['price',
#   'earnings',
#   'ratio',
#   'which',
#   'indicates',
#   'rather',
#   'cheap',
#   'valuation'],
#  ['turned',
#   'me',
#   'off',
#   'option',
#   'trading',
#   'maybe',
#   'stock',
#   'altogether',
#   'manipulation',
#   'by',
#   'very',
#   'rich',
#   'make',
#   'me',
#   'very',
#   'poor',
#   'fuk'],
#  ['down',
#   'almost',
#   'pct',
#   'from',
#   'week',
#   'high',
#   'about',
#   'time',
#   'buyback',
#   'got',
#   'more',
#   'share',
#   'my',
#   'account',
#   'though',
#   'from',
#   'drip'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'put',
#   'volume',
#   'wa'],
#  [],
#  ['dumped',
#   'call',
#   'friday',
#   'open',
#   'that',
#   'wa',
#   'obv',
#   'but',
#   'jeez',
#   'bit',
#   'over',
#   'done',
#   'here'],
#  ['bounce',
#   'off',
#   'support',
#   'ashi',
#   'weekly',
#   'candle',
#   'look',
#   'good',
#   'well',
#   'be',
#   'looking',
#   'confirmation'],
#  ['liking'],
#  ['look',
#   'wife',
#   'got',
#   'about',
#   'tree',
#   'fiddy',
#   'stock',
#   'sure',
#   'my',
#   'piggy',
#   'bank',
#   'ha',
#   'got',
#   'lot',
#   'coin',
#   'may',
#   'spend',
#   'candy',
#   'no',
#   'dm',
#   'though'],
#  ['short', 'interest', 'ratio', 'short', 'float', 'via'],
#  ['just',
#   'updated',
#   'microsoft',
#   'valuation',
#   'profitability',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'technology'],
#  ['bearish', 'investor', 'aren', 'happy', 'today'],
#  ['staanalystalert',
#   'royal',
#   'bank',
#   'canada',
#   'reiterates',
#   'with',
#   'rating',
#   'outperform',
#   'our',
#   'own',
#   'verdict',
#   'buy'],
#  ['staanalystalert',
#   'loop',
#   'capital',
#   'raise',
#   'target',
#   'with',
#   'rating',
#   'buy',
#   'setting',
#   'target',
#   'price',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'buy'],
#  ['kid', 'never', 'been', 'wrong', 'he', 'miracle'],
#  ['what', 'period', 'bollinger', 'band', 'mean'],
#  ['you', 'dare', 'say', 'didn', 'know', 'you', 'guilty', 'fudge'],
#  ['today', 'insight'],
#  ['hardly',
#   'ever',
#   'an',
#   'informative',
#   'comment',
#   'here',
#   'page',
#   'broken',
#   'giving',
#   'endless',
#   'icon',
#   'give',
#   'stocktwits'],
#  ['viral',
#   'walk',
#   'away',
#   'video',
#   'highlight',
#   'growing',
#   'movement',
#   'democrat',
#   'leaving',
#   'party',
#   'time'],
#  ['staanalystalert',
#   'robert',
#   'baird',
#   'downgrade',
#   'with',
#   'rating',
#   'neutral',
#   'setting',
#   'target',
#   'price',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'buy'],
#  ['too', 'much', 'weed', 'other', 'drug', 'guess'],
#  ['with',
#   'forward',
#   'pe',
#   'valuation',
#   'can',
#   'be',
#   'described',
#   'very',
#   'reasonable'],
#  ['reason',
#   'nike',
#   'winning',
#   'because',
#   'their',
#   'click',
#   'booking',
#   'app',
#   'better',
#   'than',
#   'native',
#   'ap'],
#  ['tapped', 'acting', 'ice', 'director', 'via'],
#  ['reach',
#   'over',
#   'year',
#   'iconic',
#   'brand',
#   'global',
#   'technology',
#   'built',
#   'mobile',
#   'winning',
#   'strategy',
#   'amp',
#   'show',
#   'earnings'],
#  ['by', 'monday', 'morning'],
#  ['heading', 'ath', 'soon', 'maybe', 'next', 'week'],
#  ['staanalystalert',
#   'jefferies',
#   'downgrade',
#   'with',
#   'rating',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'buy'],
#  ['staanalystalert',
#   'baird',
#   'downgrade',
#   'with',
#   'rating',
#   'neutral',
#   'our',
#   'own',
#   'verdict',
#   'buy'],
#  ['there',
#   'have',
#   'been',
#   'acquisition',
#   'total',
#   'share',
#   'over',
#   'past',
#   'week'],
#  ['happy', 'trading', 'guy', 'looking', 'exit', 'today'],
#  ['buy', 'zone'],
#  [],
#  ['fantastic',
#   'read',
#   'oil',
#   'market',
#   'continues',
#   'tighten',
#   'bbl',
#   'getting',
#   'closer'],
#  ['one', 'greatest', 'buy'],
#  ['looking',
#   'yearly',
#   'performance',
#   'did',
#   'better',
#   'than',
#   'all',
#   'other',
#   'stock'],
#  ['amp',
#   'dividend',
#   'aristocrat',
#   'dividend',
#   'aristocrat',
#   'champion',
#   'cashflow',
#   'highyield',
#   'dividend'],
#  ['that',
#   'pretty',
#   'risky',
#   'gamble',
#   'no',
#   'stock',
#   'can',
#   'either',
#   'plummet',
#   'or',
#   'rally'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['stronger'],
#  ['apple',
#   'valuation',
#   'profitability',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'technology',
#   'dividend'],
#  ['not', 'talking', 'about', 'wa', 'referring'],
#  ['punish',
#   'seller',
#   'who',
#   'don',
#   'move',
#   'stock',
#   'from',
#   'warehouse',
#   'common',
#   'sense',
#   'old',
#   'gather',
#   'dust',
#   'new',
#   'gather',
#   'money'],
#  ['pc',
#   'gamers',
#   'crypto',
#   'miner',
#   'other',
#   'gpu',
#   'enthusiast',
#   'have',
#   'been',
#   'waiting',
#   'over',
#   'two',
#   'year',
#   'company',
#   'next',
#   'big'],
#  ['ha',
#   'only',
#   'medium',
#   'technical',
#   'rating',
#   'but',
#   'doe',
#   'show',
#   'decent',
#   'setup',
#   'pattern'],
#  ['today', 'insight'],
#  ['what', 'be', 'more', 'five', 'year', 'baba', 'or', 'apple'],
#  ['next', 'week'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['raytheon',
#   'valuation',
#   'profitability',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'industrials',
#   'military'],
#  ['why', 'we', 'trending'],
#  ['we', 'get', 'sooooon', 'you', 'all', 'fucking', 'drunk'],
#  ['if',
#   'doesn',
#   'get',
#   'through',
#   'going',
#   'make',
#   'new',
#   'low',
#   'when',
#   'pay',
#   'dividend'],
#  ['gapping', 'monday'],
#  ['short', 'ratio', 'short', 'float', 'via'],
#  ['staanalystalert',
#   'jefferies',
#   'maintains',
#   'with',
#   'rating',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'buy'],
#  ['should',
#   'by',
#   'parker',
#   'prep',
#   'apple',
#   'glass',
#   'seen',
#   'with',
#   'watch',
#   'apple',
#   'focus',
#   'fashion',
#   'tech',
#   'wrt',
#   'wearable'],
#  ['look',
#   'like',
#   'sbux',
#   'paying',
#   'full',
#   'sex',
#   'change',
#   'employee',
#   'now',
#   'that',
#   'll',
#   'hit',
#   'bottom',
#   'line'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'expect',
#   'run',
#   'other',
#   'trade',
#   'included',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam'],
#  ['enterprise',
#   'value',
#   'market',
#   'cap',
#   'difference',
#   'actual',
#   'asset',
#   'market',
#   'value',
#   'too',
#   'big',
#   'spread',
#   'way',
#   'undervalued'],
#  ['million', 'share', 'added', 'june', 'dont', 'wait'],
#  ['who',
#   'think',
#   'amazon',
#   'become',
#   'such',
#   'monopoly',
#   'dipping',
#   'into',
#   'everything',
#   'that',
#   'an',
#   'amazon',
#   'airline',
#   'possibility',
#   'do'],
#  ['don',
#   'miss',
#   'breakout',
#   'buy',
#   'stop',
#   'stop',
#   'loss',
#   'suggested',
#   'by',
#   'chartmill',
#   'analyzer'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['weekly',
#   'recap',
#   'price',
#   'ha',
#   'moved',
#   'since',
#   'post',
#   'support',
#   'resistance',
#   'other',
#   'trade',
#   'included',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam',
#   'len'],
#  ['weekly',
#   'recap',
#   'price',
#   'ha',
#   'moved',
#   'since',
#   'post',
#   'reversal',
#   'progress',
#   'other',
#   'trade',
#   'included',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam',
#   'len',
#   'hsy'],
#  ['ve',
#   'recently',
#   'closed',
#   'my',
#   'position',
#   'now',
#   'probably',
#   'next',
#   'list',
#   'bought',
#   'both',
#   'same',
#   'week'],
#  ['nat', 'director', 'used', 'be', 'president', 'global', 'manufacturing'],
#  ['according',
#   'data',
#   'reported',
#   'finra',
#   'short',
#   'volume',
#   'percent',
#   'clocked'],
#  ['saudi', 'official', 'came', 'out', 'saying', 'they', 'didn', 'agree'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'uptrend',
#   'resume',
#   'other',
#   'trade',
#   'included',
#   'kmx',
#   'wynn',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc'],
#  ['one',
#   'right',
#   'cover',
#   'penis',
#   'or',
#   'front',
#   'leg',
#   'would',
#   'be',
#   'arm'],
#  [],
#  ['some', 'stock', 'am', 'watching', 'now'],
#  ['short', 'ratio', 'short', 'float', 'via'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'next',
#   'stop',
#   'other',
#   'trade',
#   'included',
#   'wynn',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri'],
#  ['wonder',
#   'how',
#   'much',
#   'be',
#   'valued',
#   'year',
#   'we',
#   'not',
#   'even',
#   'th',
#   'inning'],
#  ['ha',
#   'bad',
#   'technical',
#   'rating',
#   'but',
#   'doe',
#   'show',
#   'decent',
#   'setup',
#   'pattern'],
#  ['going',
#   'make',
#   'big',
#   'move',
#   'higher',
#   'also',
#   'watching',
#   'apple',
#   'think',
#   'they',
#   'shorted',
#   'put',
#   'spread',
#   'july'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'expect',
#   'consolidation',
#   'other',
#   'trade',
#   'included',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx'],
#  ['good',
#   'that',
#   'even',
#   'bull',
#   'cautious',
#   'stunned',
#   'bearish',
#   'deeply',
#   'disappointed',
#   'too',
#   'bad',
#   'continues',
#   'old',
#   'way',
#   'hopefully',
#   'we',
#   'close'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'support',
#   'other',
#   'trade',
#   'included',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn'],
#  ['ending', 'june', 'killed', 'best', 'month', 'since', 'february', 'cl'],
#  ['funny',
#   'how',
#   'long',
#   'same',
#   'thing',
#   'ha',
#   'been',
#   'going',
#   'with',
#   'about',
#   'year',
#   'similar',
#   'story',
#   'different',
#   'day'],
#  ['bearish',
#   'crab',
#   'well',
#   'measured',
#   'bearish',
#   'crab',
#   'with',
#   'bearish',
#   'divergence',
#   'you',
#   'can',
#   'really',
#   'see',
#   'momentum',
#   'starting',
#   'shi'],
#  ['staanalystalert',
#   'jefferies',
#   'maintains',
#   'with',
#   'rating',
#   'buy',
#   'setting',
#   'target',
#   'price',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'buy'],
#  ['google', 'venture', 'company'],
#  ['tariff',
#   'increase',
#   'profit',
#   'how',
#   'can',
#   'be',
#   'bad',
#   'recession',
#   'if',
#   'come',
#   'year',
#   'down',
#   'line',
#   'keep',
#   'buying',
#   'short',
#   'pure',
#   'bull'],
#  [],
#  ['min',
#   'chart',
#   'from',
#   'friday',
#   'indicating',
#   'some',
#   'nice',
#   'accumulation',
#   'eod',
#   'could',
#   'be',
#   'nice',
#   'pop',
#   'monday'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'heavy',
#   'resistance',
#   'other',
#   'trade',
#   'included',
#   'acn',
#   'camp',
#   'gi',
#   'payx',
#   'fdx',
#   'goo'],
#  ['can', 'we', 'squeeze', 'short'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'pullback',
#   'before',
#   'more',
#   'upside',
#   'other',
#   'trade',
#   'included',
#   'camp',
#   'gi',
#   'payx',
#   'fdx',
#   'goo',
#   'nvda'],
#  ['still', 'holding', 'call', 'next', 'week'],
#  ['safe', 'but', 'their', 'buyback', 'yield', 'div', 'yield'],
#  ['adding',
#   'gladly',
#   'let',
#   'irrationality',
#   'reign',
#   'long',
#   'possible',
#   'excess',
#   'gain',
#   'welcome',
#   'gl'],
#  ['looking',
#   'friday',
#   'data',
#   'seeing',
#   'different',
#   'story',
#   'chart',
#   'take',
#   'look',
#   'tell',
#   'me',
#   'what',
#   'you',
#   'think'],
#  ['short',
#   'probably',
#   'aren',
#   'jumping',
#   'joy',
#   'today',
#   'least',
#   'given',
#   'price',
#   'action'],
#  ['bouncing',
#   'off',
#   'support',
#   'need',
#   'continuation',
#   'next',
#   'week',
#   'make',
#   'me',
#   'feel',
#   'more',
#   'hopeful'],
#  ['data',
#   'science',
#   'officially',
#   'became',
#   'major',
#   'university',
#   'year',
#   'support',
#   'ai',
#   'industry',
#   'these',
#   'no',
#   'data',
#   'era'],
#  ['short', 'ratio', 'short', 'float', 'via'],
#  [],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'support',
#   'other',
#   'trade',
#   'included',
#   'payx',
#   'fdx',
#   'goo',
#   'nvda',
#   'acn',
#   'camp'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  [],
#  ['ha', 'better', 'return', 'equity', 'than', 'industry', 'average'],
#  ['second', 'not', 'minute'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'rule',
#   'applies',
#   'here',
#   'other',
#   'trade',
#   'included',
#   'six',
#   'fc',
#   'fds',
#   'baba'],
#  ['trump',
#   'killing',
#   'tax',
#   'cut',
#   'with',
#   'oil',
#   'price',
#   'tariff',
#   'no',
#   'idea',
#   'what',
#   'he',
#   'doing',
#   'right',
#   'now'],
#  ['haven',
#   'posted',
#   'stocktwits',
#   'while',
#   'these',
#   'weekly',
#   'chart',
#   'look',
#   'good'],
#  ['today', 'insight'],
#  ['omg', 'toy', 'story', 'land', 'look', 'amazing'],
#  ['stock', 'have', 'contributed', 'ytd', 'return', 'what', 'do', 'you', 'own'],
#  ['today', 'insight'],
#  ['my', 'rd', 'most', 'popular', 'word'],
#  ['trump',
#   'tweet',
#   'then',
#   'he',
#   'may',
#   'be',
#   'buyin',
#   'those',
#   'dip',
#   'haha',
#   'still',
#   'makin',
#   'rain',
#   'white',
#   'house'],
#  ['ha',
#   'poor',
#   'technical',
#   'rating',
#   'quality',
#   'setup',
#   'also',
#   'not',
#   'perfect',
#   'moment'],
#  ['doubt',
#   'go',
#   'down',
#   'monday',
#   'doubt',
#   'saudi',
#   'arabia',
#   'increase',
#   'production'],
#  ['measured',
#   'over',
#   'past',
#   'year',
#   'show',
#   'very',
#   'strong',
#   'growth',
#   'eps'],
#  ['constellation', 'brand'],
#  ['short',
#   'probably',
#   'aren',
#   'jumping',
#   'joy',
#   'today',
#   'least',
#   'given',
#   'price',
#   'action'],
#  ['here'],
#  ['did', 'disney', 'just', 'deal', 'acquire', 'fox'],
#  ['new', 'way', 'match', 'group', 'can', 'counter', 'facebook'],
#  ['aggregate', 'short', 'volume', 'reported', 'finra', 'wa'],
#  ['southwest',
#   'airline',
#   'adding',
#   'flight',
#   'dallas',
#   'delta',
#   'spat',
#   'continues'],
#  ['what', 'california'],
#  ['better', 'buy', 'netflix', 'inc', 'nflx', 'versus', 'facebook', 'fb'],
#  ['one', 'thing', 'that', 'starbucks', 'doing', 'wrong'],
#  [],
#  ['using',
#   'iex',
#   'data',
#   'we',
#   'calculate',
#   'that',
#   'shorters',
#   'have',
#   'lost'],
#  ['bull', 'list', 'after', 'their', 'from', 'bankruptcy', 'emergency'],
#  ['investment',
#   'counsel',
#   'inc',
#   'lower',
#   'stake',
#   'unitedhealth',
#   'group',
#   'inc',
#   'unh'],
#  ['list', 'vega', 'laptop', 'june', 'th'],
#  ['investing',
#   'company',
#   'like',
#   'an',
#   'annuity',
#   'or',
#   'yr',
#   'bond',
#   'continue',
#   'add',
#   'share',
#   'unsure',
#   'if',
#   'country',
#   'growing',
#   'amd'],
#  ['list', 'ryzen', 'vega', 'laptop'],
#  ['gettin', 'blasted'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'strong',
#   'support',
#   'current',
#   'price',
#   'other',
#   'trade',
#   'included',
#   'cx',
#   'aaoi',
#   'aa',
#   'yy'],
#  ['bearish',
#   'shark',
#   'bearish',
#   'shark',
#   'with',
#   'bearish',
#   'divergence',
#   'am',
#   'definitely',
#   'jumping',
#   'into',
#   'august',
#   'put',
#   'monday'],
#  ['so',
#   'going',
#   'give',
#   'price',
#   'point',
#   'before',
#   'or',
#   'after',
#   'earnings'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['huge', 'volume', 'closing', 'friday'],
#  ['looking', 'scalp'],
#  ['one', 'giant', 'turd', 'stock', 'when', 'go', 'back'],
#  ['buffet', 'buying', 'per', 'share'],
#  ['put', 'from', 'last', 'week', 'target', 'zone', 'marked'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'put',
#   'volume',
#   'wa'],
#  ['compared',
#   'an',
#   'average',
#   'industry',
#   'price',
#   'book',
#   'ratio',
#   'valued',
#   'rather',
#   'cheaply'],
#  ['eps',
#   'ha',
#   'been',
#   'growing',
#   'by',
#   'average',
#   'over',
#   'past',
#   'year',
#   'quite',
#   'good'],
#  ['mitch',
#   'did',
#   'great',
#   'job',
#   'getting',
#   'netflix',
#   'started',
#   'he',
#   'clearly',
#   'know',
#   'how',
#   'make',
#   'big',
#   'thing',
#   'happen',
#   'industry'],
#  ['cup',
#   'holder',
#   'inverse',
#   'bearish',
#   'with',
#   'confidence',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['with',
#   'debt',
#   'equity',
#   'ratio',
#   'doing',
#   'better',
#   'than',
#   'average',
#   'industry'],
#  ['sell',
#   'may',
#   'amp',
#   'go',
#   'away',
#   'ha',
#   'been',
#   'pattern',
#   'year',
#   'interesting',
#   'see',
#   'so',
#   'much',
#   'trading',
#   'time',
#   'frame',
#   'bank',
#   'love',
#   'you',
#   'trader'],
#  ['meanwhile', 'galaxy', 'far', 'far', 'away'],
#  ['broadening',
#   'wedge',
#   'descending',
#   'bearish',
#   'with',
#   'confidence',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['happy', 'trading', 'guy', 'looking', 'exit', 'today'],
#  ['large', 'put', 'spread', 'open', 'interest', 'im', 'bearish'],
#  [],
#  ['pt'],
#  ['three',
#   'falling',
#   'peak',
#   'bearish',
#   'with',
#   'confidence',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['happy',
#   'fourth',
#   'everyone',
#   'have',
#   'coke',
#   'smile',
#   'thanks',
#   'dividend'],
#  [],
#  ['selling', 'prove', 'be', 'terrible', 'error'],
#  ['end',
#   'article',
#   'just',
#   'posted',
#   'hint',
#   'possible',
#   'acquisition',
#   'sogou',
#   'finger',
#   'crossed'],
#  ['triple',
#   'top',
#   'bearish',
#   'with',
#   'confidence',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['bro',
#   'that',
#   'not',
#   'how',
#   'work',
#   'delete',
#   'blue',
#   'arrow',
#   'that',
#   'your',
#   'delusion'],
#  ['let',
#   'me',
#   'guess',
#   'everyone',
#   'still',
#   'bullish',
#   'here',
#   'even',
#   'after',
#   'close',
#   'under',
#   'ma',
#   'daily',
#   'overbought',
#   'level',
#   'trend',
#   'changing'],
#  ['cup',
#   'holder',
#   'bullish',
#   'with',
#   'confidence',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['mr', 'hold', 'yo'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'put',
#   'volume',
#   'wa'],
#  ['hi',
#   'everyone',
#   'going',
#   'bed',
#   'good',
#   'night',
#   'everyone',
#   'happy',
#   'money',
#   'monday',
#   'soon',
#   'be',
#   'prepared'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['amazon',
#   'new',
#   'warehouse',
#   'policy',
#   'start',
#   'seller',
#   'that',
#   'store',
#   'product',
#   'too',
#   'long'],
#  ['just', 'fyi', 'trump', 'era', 'ramp', 'tech', 'worker', 'revolt', 'hill'],
#  ['company',
#   'going',
#   'off',
#   'rail',
#   'people',
#   'that',
#   'work',
#   'there',
#   'store',
#   'manager',
#   'say',
#   'all',
#   'circuit',
#   'city'],
#  ['why',
#   'did',
#   'bank',
#   'fail',
#   'rally',
#   'despite',
#   'huge',
#   'bb',
#   'div',
#   'incr',
#   'me',
#   'thinking',
#   'mm',
#   'driving',
#   'down',
#   'price',
#   'get',
#   'cheap',
#   'prior',
#   'rally'],
#  ['bear',
#   'using',
#   'all',
#   'argument',
#   'sound',
#   'like',
#   'short',
#   'position',
#   'becoming',
#   'loses',
#   'week'],
#  ['popular', 'youtube', 'gaming', 'channel'],
#  ['facebook', 'cash', 'machine'],
#  ['take', 'all', 'semi', 'more', 'week', 'then', 'uptrend', 'continues'],
#  ['cheap',
#   'dividend',
#   'champion',
#   'with',
#   'low',
#   'forward',
#   'altria',
#   'aflac'],
#  ['look', 'graph', 'tripple', 'bottom', 'reached', 'heading', 'week'],
#  ['if',
#   'you',
#   'have',
#   'penis',
#   'want',
#   'vagina',
#   'like',
#   'go',
#   'get',
#   'job',
#   'sbux'],
#  ['oled',
#   'panel',
#   'post',
#   'steady',
#   'growth',
#   'amid',
#   'weak',
#   'demand',
#   'display',
#   'market',
#   'data'],
#  ['facebook', 'cash', 'machine'],
#  [],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'put',
#   'volume',
#   'wa'],
#  ['microsoft',
#   'leak',
#   'foldable',
#   'dual',
#   'screen',
#   'surface',
#   'device',
#   'that',
#   'fit',
#   'your',
#   'pocket'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['ha',
#   'good',
#   'piotroski',
#   'score',
#   'indicates',
#   'good',
#   'health',
#   'profitability'],
#  ['short', 'interest', 'ratio', 'short', 'float', 'via'],
#  ['my',
#   'original',
#   'thesis',
#   'wa',
#   'amd',
#   'having',
#   'competitive',
#   'server',
#   'product',
#   'around',
#   'time',
#   'didn',
#   'think',
#   'intel',
#   'would',
#   'shit',
#   'bed'],
#  ['bullish', 'bat', 'bullish', 'bat', 'with', 'bullish', 'divergence'],
#  ['epyc',
#   'server',
#   'adoption',
#   'snow',
#   'ball',
#   'year',
#   'intel',
#   'security',
#   'flaw',
#   'nm',
#   'fail',
#   'fire',
#   'ceo',
#   'you',
#   'can',
#   'make',
#   'sh'],
#  ['my',
#   'original',
#   'thesis',
#   'wa',
#   'amd',
#   'having',
#   'competitive',
#   'server',
#   'product',
#   'around',
#   'time',
#   'didn',
#   'think',
#   'intel',
#   'would',
#   'sh',
#   'bed'],
#  ['think', 'buy', 'many', 'can', 'under'],
#  ['new', 'way', 'match', 'group', 'can', 'counter', 'facebook'],
#  ['wowza',
#   'if',
#   'started',
#   'one',
#   'month',
#   'ago',
#   'short',
#   'return',
#   'would',
#   'be',
#   'around',
#   'iex',
#   'data'],
#  ['real',
#   'boom',
#   'social',
#   'medium',
#   'get',
#   'much',
#   'bigger',
#   'be',
#   'before',
#   'christmas'],
#  ['current', 'ratio', 'much', 'better', 'than', 'industry', 'average'],
#  ['celgene',
#   'investor',
#   'breathe',
#   'sigh',
#   'relief',
#   'after',
#   'acceleron',
#   'success'],
#  ['bear',
#   'shorties',
#   'made',
#   'huge',
#   'mistake',
#   'they',
#   'don',
#   'have',
#   'money',
#   'buy',
#   'back',
#   'when',
#   'shorted',
#   'so',
#   'they',
#   'cry',
#   'out',
#   'here',
#   'everyday'],
#  ['today', 'insight'],
#  ['industry', 'average', 'roa', 'outperforms', 'industry', 'peer'],
#  ['encourage',
#   'you',
#   'no',
#   'longer',
#   'be',
#   'sheep',
#   'end',
#   'your',
#   'racist',
#   'hateful',
#   'way',
#   'buy',
#   'amd',
#   'walk',
#   'away',
#   'from',
#   'democratic',
#   'party'],
#  ['happening',
#   'looking',
#   'ease',
#   'flattening',
#   'yc',
#   'starting',
#   'week',
#   'lot',
#   'trader',
#   'def',
#   'offside',
#   'now'],
#  ['daily', 'or', 'weekly', 'chart', 'all', 'look', 'horrible'],
#  ['if', 'spotify', 'add', 'more', 'video', 'content', 'look', 'out'],
#  ['market',
#   'positioning',
#   'very',
#   'underweight',
#   'crowdthnk',
#   'algo',
#   'forecast',
#   'chance',
#   'moving',
#   'lower'],
#  ['added',
#   'more',
#   'no',
#   'brainer',
#   'if',
#   'you',
#   're',
#   'long',
#   'there',
#   'no',
#   'peer',
#   'they',
#   'top',
#   'dog',
#   'amd',
#   'mu'],
#  ['bearish',
#   'bat',
#   'bearish',
#   'bat',
#   'with',
#   'some',
#   'serious',
#   'bearish',
#   'divergence',
#   'something',
#   'about',
#   'give'],
#  ['ha', 'been', 'proposition', 'july', 'since', 'with', 'net', 'return'],
#  ['term', 'negative', 'there', 'bearish', 'indicator'],
#  ['quite', 'over', 'valued', 'my', 'opinion'],
#  ['brexit', 'banker', 'risk', 'life', 'edge', 'luxembourg', 'fill', 'via'],
#  ['market', 'history'],
#  ['so', 'amd', 'using', 'liquid', 'inside', 'gpu'],
#  ['curve',
#   'flattening',
#   'juggernaut',
#   'face',
#   'risk',
#   'from',
#   'fed',
#   'concern',
#   'trade',
#   'via'],
#  ['pertains',
#   'if',
#   'started',
#   'day',
#   'ago',
#   'bearish',
#   'investor',
#   'would',
#   'have',
#   'lost',
#   'around',
#   'according',
#   'iex'],
#  [],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['study',
#   'watchlist',
#   'trade',
#   'wisely',
#   'invest',
#   'wisely',
#   'read',
#   'wallstreet',
#   'runner'],
#  ['waiting', 'pull', 'back', 'slow', 'steady', 'stock'],
#  ['thought',
#   'friday',
#   'flush',
#   'wa',
#   'cheap',
#   'share',
#   'just',
#   'like',
#   'they',
#   'did',
#   'oil',
#   'before',
#   'opec',
#   'meeting'],
#  ['china', 'attack'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['rated', 'sell', 'since', 'june', 'below', 'median', 'level'],
#  ['dont', 'trust', 'company'],
#  ['today', 'insight'],
#  ['anticipation', 'rising', 'which', 'analyst', 'right', 'june'],
#  ['sorry',
#   'stock',
#   'price',
#   'not',
#   'so',
#   'we',
#   'higher',
#   'than',
#   'you',
#   'predicted',
#   'not',
#   'lower'],
#  ['warren', 'they', 'exited'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['another', 'analyst', 'opinion', 'june'],
#  [],
#  ['all',
#   'down',
#   'because',
#   'trade',
#   'concern',
#   'still',
#   'be',
#   'worth',
#   'weight',
#   'now',
#   'little',
#   'bit',
#   'lighting'],
#  ['three',
#   'falling',
#   'peak',
#   'bearish',
#   'with',
#   'confidence',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['rectangle',
#   'top',
#   'bullish',
#   'with',
#   'confidence',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['any', 'more', 'really', 'design', 'they', 'announce'],
#  ['bull', 'have', 'reason', 'pay', 'more', 'attention'],
#  ['cog', 'take', 'boeing', 'soon', 'right'],
#  ['really',
#   'baked',
#   'right',
#   'now',
#   'having',
#   'deep',
#   'thought',
#   'short',
#   'coming',
#   'back',
#   'look',
#   'tweet',
#   'year'],
#  ['one', 'test', 'if', 'fails', 'my', 'target', 'start', 'buying', 'again'],
#  ['analyst', 'opinion'],
#  ['making', 'more', 'than', 'ever', 'thanks', 'amp'],
#  [],
#  ['atl', 'fed', 'forecast', 'whew', 'baby', 'we', 'go'],
#  ['here', 'june', 'grr', 'date', 'came', 'out', 'early', 'read', 'away'],
#  ['bull', 'have', 'reason', 'pay', 'more', 'attention'],
#  ['stericycle', 'current', 'chance', 'distress', 'about', 'below', 'average'],
#  ['ggr', 'out', 'june'],
#  ['today', 'insight'],
#  ['fyi'],
#  ['go', 'over', 'before', 'earnings'],
#  ['extremely',
#   'undervalued',
#   'be',
#   'within',
#   'year',
#   'great',
#   'midterm',
#   'investment'],
#  ['may', 'go', 'slightly', 'down', 'news', 'june', 'ggr'],
#  ['stupid', 'spammer', 'wasting', 'time'],
#  ['but', 'already', 'oversold', 'so', 'not', 'much', 'consolidation', 'then'],
#  ['just', 'start'],
#  ['short', 'interest', 'ratio', 'short', 'float', 'via'],
#  ['purchasing',
#   'pill',
#   'pack',
#   'last',
#   'thursday',
#   'breaking',
#   'into',
#   'pharmaceutical',
#   'field',
#   'increase',
#   'amazon',
#   'bottom',
#   'line',
#   'retest',
#   'quickly'],
#  ['june', 'ggr', 'still', 'after', 'soccer', 'world', 'cup', 'holiday'],
#  ['purchasing',
#   'pill',
#   'pack',
#   'last',
#   'thurs',
#   'amp',
#   'breaking',
#   'into',
#   'pharmaceutical',
#   'field',
#   'increase',
#   'amazon',
#   'bottom',
#   'line',
#   'retest',
#   'quickly'],
#  ['buy', 'back', 'they', 'want', 'cheap'],
#  ['not',
#   'too',
#   'expensive',
#   'growing',
#   'strongly',
#   'check',
#   'out',
#   'now',
#   'part',
#   'our',
#   'affordable',
#   'growth',
#   'selection'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'put',
#   'volume',
#   'wa'],
#  ['long',
#   'term',
#   'trend',
#   'positive',
#   'short',
#   'term',
#   'trend',
#   'neutral',
#   'so',
#   'benefit',
#   'doubt',
#   'now'],
#  ['lot',
#   'buyer',
#   'fri',
#   'when',
#   'mm',
#   'pinned',
#   'quot',
#   'trader',
#   'buy',
#   'amazon',
#   'com',
#   'amzn',
#   'weakness',
#   'quot'],
#  ['term', 'positive', 'there', 'bullish', 'indicator'],
#  ['know', 'what', 'hold'],
#  ['never',
#   'have',
#   'seen',
#   'right',
#   'angle',
#   'apple',
#   'lol',
#   'that',
#   'wa',
#   'crazy'],
#  ['wanna',
#   'hear',
#   'er',
#   'ok',
#   'yeah',
#   'all',
#   'got',
#   'great',
#   'product',
#   'so',
#   'what',
#   'stock',
#   'market',
#   'want',
#   'report',
#   'what',
#   'news'],
#  ['starbucks',
#   'become',
#   'pioneer',
#   'medical',
#   'coverage',
#   'sex',
#   'change',
#   'get',
#   'your',
#   'free',
#   'sex',
#   'change',
#   'here'],
#  ['today', 'insight'],
#  ['today', 'insight'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['all',
#   'august',
#   'call',
#   'either',
#   'gonna',
#   'make',
#   'fortune',
#   'or',
#   'declare',
#   'bankruptcy'],
#  ['wtf'],
#  [],
#  ['macau', 'casino', 'ggr', 'nearly', 'pct', 'june', 'govt'],
#  ['jul',
#   'casino',
#   'gross',
#   'gaming',
#   'revenue',
#   'ggr',
#   'macau',
#   'rose',
#   'by',
#   'percent',
#   'year',
#   'year',
#   'june'],
#  ['what'],
#  ['gonna', 'be', 'cheaper', 'than', 'also'],
#  ['monster', 'core', 'amd', 'ryzen', 'threadripper', 'cpu', 'rumored', 'usd'],
#  ['we', 'have', 'detected', 'negative', 'indicator', 'more', 'info'],
#  ['someone', 'give', 'me', 'like'],
#  ['short', 'interest', 'ratio', 'short', 'float', 'via'],
#  [],
#  ['valued', 'll', 'take', 'point'],
#  [],
#  ['short', 'interest', 'ratio', 'short', 'float', 'via'],
#  ['trump', 'cause', 'oil', 'price', 'go', 'down'],
#  ['if',
#   'were',
#   'need',
#   'buyback',
#   'bln',
#   'share',
#   'wouldn',
#   'try',
#   'buy',
#   'dip'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'put',
#   'volume',
#   'wa'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['gigabyte', 'amp', 'epyc', 'cpu', 'with', 'large', 'density', 'server'],
#  ['now',
#   'intel',
#   'can',
#   'produce',
#   'full',
#   'silicon',
#   'wafer',
#   'quantum',
#   'computing',
#   'chip'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['good',
#   'technical',
#   'but',
#   'also',
#   'nice',
#   'setup',
#   'pattern',
#   'forming',
#   'now',
#   'part',
#   'our',
#   'top',
#   'breakout',
#   'selection'],
#  ['bear', 'have', 'reason', 'pay', 'more', 'attention'],
#  ['june', 'ggr', 'only', 'very', 'bad', 'stock', 'going', 'get', 'crushed'],
#  ['amazon',
#   'with',
#   'hook',
#   'pattern',
#   'set',
#   'monthly',
#   'looking',
#   'strong',
#   'move',
#   'monday',
#   'expected'],
#  ['paychex',
#   'social',
#   'hype',
#   'low',
#   'key',
#   'current',
#   'chance',
#   'financial',
#   'distress',
#   'under'],
#  ['today', 'insight'],
#  [],
#  ['bear', 'have', 'reason', 'pay', 'more', 'attention'],
#  ['buy', 'more', 'dip', 'buying', 'opp'],
#  ['here',
#   'an',
#   'example',
#   'hook',
#   'pattern',
#   'virtually',
#   'identical',
#   'what',
#   'amazon',
#   'monthly',
#   'chart',
#   'look',
#   'like',
#   'now'],
#  ['eps',
#   'ha',
#   'been',
#   'growing',
#   'by',
#   'average',
#   'over',
#   'past',
#   'year',
#   'quite',
#   'good'],
#  ['short', 'interest', 'ratio', 'short', 'float', 'via'],
#  ['showing', 'our', 'top', 'breakout', 'selection'],
#  ['overbought', 'sell', 'signal'],
#  ['short', 'ratio', 'short', 'float', 'via'],
#  ['rsi', 'deathcross'],
#  ['be',
#   'selling',
#   'pre',
#   'market',
#   'trying',
#   'buy',
#   'very',
#   'bullish',
#   'but',
#   'would',
#   'like',
#   'take',
#   'advantage',
#   'dip'],
#  ['pertains',
#   'if',
#   'started',
#   'day',
#   'ago',
#   'bearish',
#   'investor',
#   'would',
#   'have',
#   'lost',
#   'around',
#   'according',
#   'iex'],
#  ['short',
#   'volume',
#   'wa',
#   'th',
#   'percentile',
#   'term',
#   'last',
#   'trading',
#   'day'],
#  ['bring',
#   'gloom',
#   'amp',
#   'doom',
#   'pull',
#   'back',
#   'ahead',
#   'er',
#   'happens',
#   'ever',
#   'time',
#   'after',
#   'don',
#   'fight',
#   'plan',
#   'buy',
#   'no',
#   'way',
#   'fall'],
#  ['overbought', 'death', 'cross', 'sell', 'signal'],
#  ['short', 'interest', 'ratio', 'short', 'float', 'via'],
#  ['bad',
#   'news',
#   'baked',
#   'sector',
#   'but',
#   'second',
#   'major',
#   'miss',
#   'row',
#   'like',
#   'going',
#   'spook',
#   'lot',
#   'investor'],
#  ['short', 'volume', 'percent', 'wa', 'versus'],
#  ['here',
#   'with',
#   'expectation',
#   'june',
#   'great',
#   'buying',
#   'opp',
#   'dip',
#   'july',
#   'august'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['we', 'have', 'detected', 'positive', 'indicator', 'more', 'info'],
#  ['short', 'ratio', 'short', 'float', 'via'],
#  ['well',
#   'if',
#   'can',
#   'sell',
#   'premarket',
#   'then',
#   'buy',
#   'back',
#   'summer',
#   'july',
#   'tariff',
#   'coming',
#   'lower',
#   'price',
#   'why',
#   'not',
#   'ggr'],
#  ['term', 'positive', 'there', 'bullish', 'indicator'],
#  ['currently',
#   'trading',
#   'upper',
#   'part',
#   'week',
#   'range',
#   'outperforming',
#   'market'],
#  ['today', 'insight'],
#  ['huge',
#   'miss',
#   'june',
#   'ggr',
#   'right',
#   'before',
#   'july',
#   'tariff',
#   'oh',
#   'shit',
#   'selling',
#   'premarket',
#   'buying',
#   'back'],
#  ['aos', 'stk', 'highest', 'vol', 'accum'],
#  ['quot',
#   'amazon',
#   'online',
#   'pharmacy',
#   'acquisition',
#   'prof',
#   'serious',
#   'about',
#   'disrupting',
#   'healthcare',
#   'quot'],
#  ['according',
#   'data',
#   'reported',
#   'finra',
#   'short',
#   'volume',
#   'percent',
#   'clocked'],
#  ['bull', 'have', 'reason', 'pay', 'more', 'attention'],
#  ['short', 'ratio', 'short', 'float', 'via'],
#  ['based',
#   'iex',
#   'data',
#   'bearish',
#   'investor',
#   'have',
#   'taken',
#   'some',
#   'punishment',
#   'if',
#   'started',
#   'month',
#   'ago',
#   'their',
#   'return',
#   'around'],
#  ['guess',
#   'we',
#   'wait',
#   'see',
#   'how',
#   'trade',
#   'tomorrow',
#   'night',
#   'when',
#   'hong',
#   'kong',
#   'market',
#   'open'],
#  ['why', 'did', 'even', 'start', 'trading'],
#  ['because', 'ha', 'better', 'valuation', 'than', 'read', 'news'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['ha',
#   'good',
#   'piotroski',
#   'score',
#   'indicates',
#   'good',
#   'health',
#   'profitability'],
#  ['we', 'have', 'detected', 'positive', 'indicator', 'more', 'info'],
#  ['think',
#   'my',
#   'opinion',
#   'most',
#   'consolidated',
#   'amp',
#   'with',
#   'greatest',
#   'business',
#   'support',
#   'different',
#   'area',
#   'strategy'],
#  ['anyone', 'have', 'any', 'idea', 'what', 'coming', 'next'],
#  ['happened', 'last', 'june', 'too', 'miss', 'june', 'ggr'],
#  ['happened', 'last', 'june', 'too'],
#  ['based',
#   'iex',
#   'data',
#   'bearish',
#   'investor',
#   'have',
#   'taken',
#   'some',
#   'punishment',
#   'if',
#   'started',
#   'month',
#   'ago',
#   'their',
#   'return',
#   'around'],
#  ['bull', 'have', 'reason', 'pay', 'more', 'attention'],
#  ['wow',
#   'if',
#   'started',
#   'one',
#   'month',
#   'ago',
#   'bear',
#   'return',
#   'would',
#   'be',
#   'around',
#   'iex',
#   'data'],
#  ['today', 'insight'],
#  ['according',
#   'data',
#   'reported',
#   'finra',
#   'short',
#   'volume',
#   'percent',
#   'clocked'],
#  ['today', 'insight'],
#  ['new', 'hotel', 'with', 'casino', 'coming', 'macau'],
#  ['vol'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['vol', 'accum'],
#  ['what', 'your', 'thought', 'bank'],
#  ['short', 'interest', 'ratio', 'short', 'float', 'via'],
#  ['long', 'short', 'term', 'trend', 'both', 'positive', 'looking', 'good'],
#  ['weekly',
#   'bullflag',
#   'great',
#   'condition',
#   'major',
#   'support',
#   'breakout',
#   'pt',
#   'amp',
#   'indicator',
#   'look',
#   'good'],
#  ['adoredtv'],
#  ['per',
#   'data',
#   'reported',
#   'finra',
#   'short',
#   'volume',
#   'divided',
#   'by',
#   'total',
#   'volume',
#   'wa'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['chart', 'day', 'buy'],
#  [],
#  ['we', 'have', 'detected', 'positive', 'indicator', 'more', 'info'],
#  ['ha',
#   'bad',
#   'technical',
#   'rating',
#   'but',
#   'doe',
#   'show',
#   'decent',
#   'setup',
#   'pattern'],
#  ['old', 'vol', 'accum'],
#  ['percent', 'short', 'volume', 'wa'],
#  ['term', 'positive', 'there', 'bullish', 'indicator'],
#  ['confidently',
#   'can',
#   'invest',
#   'forget',
#   'generation',
#   'yr',
#   'enjoy',
#   'fruit',
#   'my',
#   'labor',
#   'extending',
#   'future'],
#  ['rated', 'buy', 'since', 'may', 'above', 'median', 'level'],
#  ['financials',
#   'broke',
#   'wedge',
#   'weekly',
#   'chart',
#   'all',
#   'indicator',
#   'bearish',
#   'price',
#   'target',
#   'dma'],
#  ['ha', 'profit', 'margin', 'amongst', 'best', 'return', 'industry'],
#  ['today', 'insight'],
#  ['short', 'volume', 'reported', 'finra'],
#  ['today', 'insight'],
#  ['today', 'insight'],
#  ['weekly',
#   'bf',
#   'look',
#   'great',
#   'dma',
#   'crossing',
#   'dma',
#   'bullish',
#   'sign',
#   'buying',
#   'volume',
#   'gt',
#   'selling',
#   'volume',
#   'make',
#   'very',
#   'attractive'],
#  ['today', 'insight'],
#  ['short', 'ratio', 'short', 'float', 'via'],
#  ['bull', 'have', 'reason', 'pay', 'more', 'attention'],
#  ['maybe', 'or', 'buy', 'out', 'moviepass', 'superb', 'income', 'generator'],
#  ['we', 'have', 'detected', 'positive', 'indicator', 'more', 'info'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['one', 'better', 'performing', 'stock', 'metal', 'mining', 'industry'],
#  ['conservative',
#   'believe',
#   'social',
#   'network',
#   'censor',
#   'political',
#   'speech',
#   'according',
#   'pew',
#   'study'],
#  ['ouch',
#   'if',
#   'started',
#   'trading',
#   'day',
#   'ago',
#   'shorter',
#   'return',
#   'would',
#   'be',
#   'around',
#   'iex',
#   'data'],
#  ['short', 'volume', 'percent', 'wa', 'an', 'increase', 'from'],
#  ['ha', 'profit', 'margin', 'better', 'than', 'industry', 'average'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['today', 'insight'],
#  ['today', 'insight'],
#  ['bull', 'have', 'reason', 'pay', 'more', 'attention'],
#  ['short', 'interest', 'ratio', 'short', 'float', 'via'],
#  ['bigger',
#   'news',
#   'when',
#   'doj',
#   'give',
#   'clearance',
#   'with',
#   'condition',
#   'then',
#   'we',
#   'see',
#   'very',
#   'huge',
#   'counter',
#   'offer'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['per',
#   'data',
#   'reported',
#   'finra',
#   'short',
#   'volume',
#   'divided',
#   'by',
#   'total',
#   'volume',
#   'wa'],
#  ['short', 'volume', 'reported', 'finra'],
#  ['bull', 'have', 'reason', 'pay', 'more', 'attention'],
#  ['fund',
#   'follow',
#   'added',
#   'micron',
#   'another',
#   'fund',
#   'manager',
#   'ha',
#   'had',
#   'since',
#   'still',
#   'holding',
#   'both',
#   'targeting',
#   'higher',
#   'high'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['bull', 'have', 'reason', 'pay', 'more', 'attention'],
#  [],
#  ['today', 'insight'],
#  ['aggregate', 'short', 'volume', 'reported', 'finra', 'wa'],
#  ['today', 'insight'],
#  ['today', 'insight'],
#  ['today', 'insight'],
#  ['eps',
#   'ha',
#   'been',
#   'growing',
#   'by',
#   'average',
#   'over',
#   'past',
#   'year',
#   'very',
#   'strong',
#   'growth'],
#  ['short',
#   'have',
#   'sure',
#   'felt',
#   'some',
#   'pain',
#   'if',
#   'shorted',
#   'first',
#   'their',
#   'ytd',
#   'return',
#   'around'],
#  ['short', 'volume', 'reported', 'finra'],
#  ['we', 'have', 'detected', 'negative', 'indicator', 'more', 'info'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['that', 'would', 'make', 'me', 'very', 'happy', 'camper'],
#  ['rt',
#   'show',
#   'quite',
#   'strong',
#   'growth',
#   'eps',
#   'over',
#   'last',
#   'year',
#   'eps',
#   'ha',
#   'been',
#   'growing',
#   'by',
#   'yearly'],
#  ['bear', 'have', 'reason', 'pay', 'more', 'attention'],
#  ['sorry',
#   'bull',
#   'but',
#   'after',
#   'trump',
#   'attack',
#   'great',
#   'american',
#   'brand'],
#  ['anyone', 'have', 'thought', 'price', 'target'],
#  ['short',
#   'volume',
#   'wa',
#   'th',
#   'percentile',
#   'term',
#   'last',
#   'trading',
#   'day'],
#  ['absolutely',
#   'true',
#   'throwing',
#   'more',
#   'body',
#   'issue',
#   'often',
#   'creates',
#   'new',
#   'one',
#   'stay',
#   'course'],
#  ['agree', 'with', 'these', 'guy'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['term', 'positive', 'there', 'bullish', 'indicator'],
#  ['if',
#   'ran',
#   'looked',
#   'like',
#   'folding',
#   'device',
#   'westworld',
#   'even',
#   'apple',
#   'fan',
#   'would',
#   'buy',
#   'one'],
#  ['fed', 'also'],
#  ['soon',
#   'they',
#   'did',
#   'that',
#   'they',
#   'tip',
#   'their',
#   'hand',
#   'competition',
#   'approve',
#   'that',
#   'purchase',
#   'all',
#   'same'],
#  ['short', 'volume', 'percent', 'wa', 'decrease', 'from'],
#  ['space',
#   'grey',
#   'macbook',
#   'pro',
#   'with',
#   'touch',
#   'bar',
#   'running',
#   'mojave',
#   'dark',
#   'mode'],
#  ['short', 'ratio', 'short', 'float', 'via'],
#  ['today', 'insight'],
#  ['aggregate', 'short', 'volume', 'reported', 'finra', 'wa'],
#  ['today', 'insight'],
#  ['ha',
#   'an',
#   'altman',
#   'score',
#   'meaning',
#   'financially',
#   'healthy',
#   'with',
#   'little',
#   'risk',
#   'bankruptcy'],
#  ['special', 'sale', 'one', 'day', 'only', 'only', 'each'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['bear', 'have', 'reason', 'pay', 'more', 'attention'],
#  ['just',
#   'rant',
#   'no',
#   'position',
#   'trip',
#   'advisor',
#   'search',
#   'algo',
#   'horrible',
#   'have',
#   'search',
#   'google',
#   'find',
#   'anything',
#   'trip',
#   'fire',
#   'developer'],
#  ['aggregate', 'short', 'volume', 'reported', 'finra', 'wa'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['move',
#   'down',
#   'monday',
#   'signaled',
#   'major',
#   'reversal',
#   'could',
#   'rally',
#   'anticipation',
#   'earnings',
#   'but',
#   'that',
#   'be',
#   'end'],
#  ['smart',
#   'money',
#   'getting',
#   'out',
#   'faangs',
#   'especially',
#   'amzn',
#   'fb',
#   'nflx',
#   'bubble',
#   'deflating',
#   'cash',
#   'becomes',
#   'more',
#   'attractive',
#   'with',
#   'higher',
#   'rate'],
#  ['short', 'volume', 'percent', 'wa'],
#  ['bull', 'have', 'reason', 'pay', 'more', 'attention'],
#  ['piotroski', 'score', 'indicating', 'great', 'health'],
#  ['term', 'negative', 'there', 'bearish', 'indicator'],
#  [],
#  [],
#  ['buy',
#   'opportunity',
#   'intel',
#   'intc',
#   'monthly',
#   'demand',
#   'level',
#   'intel',
#   'intc',
#   'ha',
#   'clear',
#   'long',
#   'term',
#   'long',
#   'bias',
#   'buy'],
#  ['lot',
#   'people',
#   'short',
#   'been',
#   'saying',
#   'all',
#   'year',
#   'but',
#   'selling',
#   'into',
#   'strength',
#   'since',
# ...
#  ['starting',
#   'get',
#   'some',
#   'momentum',
#   'if',
#   'pick',
#   'below',
#   'favor',
#   'see',
#   'strong',
#   'breakdown',
#   'towards',
#   'measured',
#   'move',
#   'target',
#   'ish'],
#  ['recent',
#   'technical',
#   'alert',
#   'jack',
#   'box',
#   'bearish',
#   'plus',
#   'more',
#   'alert'],
#  ['max', 'pain', 'maturity', 'maxpain', 'option'],
#  ['lot',
#   'ta',
#   'short',
#   'financials',
#   'right',
#   'now',
#   'but',
#   'let',
#   'ask',
#   'guy',
#   'who',
#   'made',
#   'most',
#   'bank',
#   'how',
#   'he',
#   'us',
#   'chart'],
#  ['no',
#   'chance',
#   'get',
#   'approval',
#   'before',
#   'play',
#   'out',
#   'took',
#   'six',
#   'month',
#   'that',
#   'wa',
#   'clearly',
#   'fast',
#   'tracked',
#   'rupert'],
#  ['cool',
#   'world',
#   'cup',
#   'experience',
#   'world',
#   'cup',
#   'virtual',
#   'reality',
#   'bbc',
#   'sport'],
#  ['july', 'stock', 'picking', 'contest', 'now', 'open'],
#  ['barron',
#   'pick',
#   'pan',
#   'apple',
#   'mastercard',
#   'sirius',
#   'xm',
#   'verizon',
#   'more'],
#  ['er', 'game', 'or', 'low'],
#  ['read',
#   'couple',
#   'brokerage',
#   'report',
#   'pt',
#   'value',
#   'forward',
#   'pe',
#   'prem',
#   'above',
#   'avg',
#   'semi',
#   'overpriced'],
#  ['what',
#   'damn',
#   'third',
#   'design',
#   'win',
#   'that',
#   'supposed',
#   'be',
#   'ramping',
#   'nd',
#   'half',
#   'who',
#   'making',
#   'odds',
#   'customer',
#   've',
#   'got',
#   'apple'],
#  ['apple',
#   'other',
#   'product',
#   'expanding',
#   'airpods',
#   'could',
#   'hit',
#   'iphone',
#   'unit',
#   'sale',
#   'rbc'],
#  ['careful',
#   'where',
#   'you',
#   'get',
#   'your',
#   'news',
#   'system',
#   'doesn',
#   'exist'],
#  ['bank',
#   'america',
#   'increase',
#   'quarterly',
#   'common',
#   'stock',
#   'dividend',
#   'repurchase',
#   'billion'],
#  [],
#  ['mizuho', 'security', 'upgrade', 'scana', 'corp', 'buy'],
#  ['netapp',
#   'pt',
#   'raised',
#   'bofa',
#   'merrill',
#   'lynch',
#   'benefit',
#   'from',
#   'ai'],
#  ['manipulation'],
#  ['undervalue', 'but', 'go', 'lower'],
#  ['video',
#   'game',
#   'stock',
#   'seen',
#   'potential',
#   'medium',
#   'company',
#   'acquisition',
#   'target'],
#  ['got',
#   'pullback',
#   'if',
#   'bull',
#   'want',
#   'new',
#   'high',
#   'here',
#   'where',
#   'you',
#   'need',
#   'step',
#   'get',
#   'above',
#   'suggest',
#   'new',
#   'high',
#   'wave'],
#  ['folk',
#   'sunday',
#   'go',
#   'church',
#   'volunteer',
#   'get',
#   'outside',
#   'go',
#   'talk',
#   'friend',
#   'or',
#   'make',
#   'new',
#   'one',
#   'let',
#   'go',
#   'till',
#   'monday',
#   'glta'],
#  ['my', 'top', 'growth', 'stock', 'next', 'decade'],
#  ['credit', 'suisse', 'set', 'pt'],
#  ['soccer',
#   'season',
#   'with',
#   'would',
#   'say',
#   'beat',
#   'huge',
#   'upside',
#   'from',
#   'here'],
#  ['why',
#   'cv',
#   'may',
#   'be',
#   'le',
#   'vulnerable',
#   'amazon',
#   'healthcare',
#   'attack',
#   'than',
#   'walgreens'],
#  ['credit', 'suisse', 'set', 'pt'],
#  ['credit', 'suisse', 'set', 'pt'],
#  ['cantor', 'fitzgerald', 'set', 'pt'],
#  ['stephen', 'set', 'pt'],
#  ['pivotal', 'research', 'set', 'pt'],
#  ['mkm', 'partner', 'set', 'pt'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'put',
#   'volume',
#   'wa'],
#  ['mizuho', 'security', 'set', 'pt'],
#  ['top', 'stock', 'buy', 'ahead', 'most', 'bullish', 'day', 'year'],
#  ['doubting', 'nvidia', 'future', 'dumb'],
#  ['short', 'volume', 'percent', 'wa', 'day', 'rank', 'wa', 'th', 'percentile'],
#  ['facebook',
#   'snapchat',
#   'story',
#   'clone',
#   'mostly',
#   'untapped',
#   'gold',
#   'mine'],
#  ['crap', 'can', 'reach', 'again'],
#  ['gm',
#   'say',
#   'import',
#   'tariff',
#   'could',
#   'lead',
#   'smaller',
#   'company',
#   'fewer',
#   'job'],
#  ['ha', 'netflix', 'finally', 'peaked'],
#  ['lead', 'ad', 'costco', 'com', 'under', 'computer', 'back', 'school'],
#  ['long', 'short', 'term', 'trend', 'both', 'positive', 'looking', 'good'],
#  ['we',
#   'all',
#   'know',
#   'go',
#   'back',
#   'coming',
#   'day',
#   'chat',
#   'room',
#   'waste',
#   'time'],
#  ['vertex',
#   'pharma',
#   'jump',
#   'after',
#   'rival',
#   'release',
#   'poor',
#   'cystic',
#   'fibrosis',
#   'drug',
#   'result'],
#  ['world',
#   'cup',
#   'drag',
#   'june',
#   'ggr',
#   'from',
#   'may',
#   'june',
#   'from',
#   'may',
#   'year',
#   'without',
#   'wc',
#   'effect',
#   'ggr',
#   'would',
#   've',
#   'been',
#   'yoy'],
#  ['all',
#   'eye',
#   'be',
#   'oil',
#   'when',
#   'market',
#   'open',
#   'week',
#   'after',
#   'trump',
#   'tweet',
#   'forex',
#   'live'],
#  ['amazon', 'latest', 'disruption', 'prime', 'rx', 'delivery'],
#  ['percent', 'short', 'volume', 'wa'],
#  ['we', 'have', 'detected', 'negative', 'indicator', 'more', 'info'],
#  ['how',
#   'visa',
#   'mastercard',
#   'could',
#   'benefit',
#   'from',
#   'settlement',
#   'over',
#   'card',
#   'swipe',
#   'fee'],
#  [],
#  ['watchlist'],
#  ['price',
#   'have',
#   'been',
#   'consolidating',
#   'recently',
#   'may',
#   'present',
#   'good',
#   'entry',
#   'opportunity'],
#  ['maria',
#   'ha',
#   'always',
#   'been',
#   'shill',
#   'never',
#   'forget',
#   'amp',
#   'her',
#   'defending',
#   'lehman',
#   'disgusting'],
#  ['cruise',
#   'line',
#   'stock',
#   'buy',
#   'royal',
#   'caribbean',
#   'carnival',
#   'or',
#   'norwegian'],
#  ['long',
#   'term',
#   'estimate',
#   'per',
#   'barrel',
#   'crude',
#   'could',
#   'be',
#   'card',
#   'rbc'],
#  ['long', 'short', 'term', 'trend', 'both', 'positive', 'looking', 'good'],
#  ['releasing',
#   'earnings',
#   'before',
#   'open',
#   'confirmed',
#   'anybody',
#   'buying',
#   'selling',
#   'earnings'],
#  ['ba', 'ba'],
#  ['not', 'all', 'afraid', 'hold', 'my', 'short', 'bank'],
#  ['retaliation',
#   'tariff',
#   'sun',
#   'canada',
#   'july',
#   'china',
#   'expected',
#   'impose',
#   'tariff',
#   'soybean',
#   'cnbc'],
#  ['short', 'ratio', 'short', 'float', 'via'],
#  ['wonder', 'how', 'many', 'matebook', 'selling'],
#  ['bac', 'bac'],
#  ['good', 'plan', 'right', 'here', 'close', 'mine'],
#  ['very', 'optimistic'],
#  ['high', 'oi', 'range', 'option', 'expiration', 'maxpain', 'option'],
#  ['oversold', 'with', 'sign', 'possible', 'reversal'],
#  ['would', 'not', 'want', 'be', 'next', 'er'],
#  ['don', 'tell', 'me', 'you', 'still', 'holding'],
#  ['ok',
#   'you',
#   'keep',
#   'telling',
#   'telling',
#   'yourself',
#   'that',
#   'he',
#   'casino',
#   'casino',
#   'now',
#   'soon'],
#  ['only',
#   'table',
#   'service',
#   'can',
#   'afford',
#   'right',
#   'now',
#   'can',
#   'even',
#   'afford',
#   'anymore',
#   'after',
#   'price',
#   'hike'],
#  ['can',
#   'someone',
#   'explain',
#   'what',
#   'happens',
#   'with',
#   'div',
#   'payout',
#   'if',
#   'buy',
#   'here'],
#  ['economy',
#   'that',
#   'time',
#   'sending',
#   'job',
#   'overseas',
#   'after',
#   'supporting',
#   'them',
#   'gut',
#   'trump',
#   'calling',
#   'them',
#   'out'],
#  ['yeah', 'sleep', 'with', 'elon', 'musk'],
#  ['compared',
#   'an',
#   'average',
#   'industry',
#   'price',
#   'book',
#   'ratio',
#   'valued',
#   'rather',
#   'cheaply'],
#  ['since',
#   'last',
#   'er',
#   'stock',
#   'dropped',
#   'reporting',
#   'earnings',
#   'before',
#   'open',
#   'confirmed'],
#  ['if',
#   'all',
#   'be',
#   'nice',
#   'me',
#   'can',
#   'give',
#   'you',
#   'an',
#   'accurate',
#   'direction',
#   'which',
#   'way',
#   'go'],
#  ['below', 'all', 'sma', 'falling', 'wedge', 'bearish', 'until', 'breakout'],
#  ['think',
#   'most',
#   'peep',
#   'here',
#   'have',
#   'blocked',
#   'bro',
#   'time',
#   'use',
#   'an',
#   'alternate',
#   'account',
#   'taken'],
#  ['you',
#   'bet',
#   'how',
#   'about',
#   'show',
#   'some',
#   'fact',
#   'sport',
#   'now',
#   'ha',
#   'control',
#   'nfl',
#   'mlb',
#   'march',
#   'madness',
#   'etc',
#   'roku',
#   'suck',
#   'donkey',
#   'dks'],
#  ['alibaba',
#   'buy',
#   'stake',
#   'turkey',
#   'alibaba',
#   'proceeding',
#   'international',
#   'expansion'],
#  ['think',
#   'whole',
#   'dump',
#   'past',
#   'few',
#   'year',
#   'wa',
#   'absolutely',
#   'necessary',
#   'their',
#   'sht',
#   'wa',
#   'getting',
#   'way',
#   'too',
#   'expensive',
#   'they',
#   'can',
#   'grow',
#   'now'],
#  ['if', 'feel', 'good', 'be', 'right', 'with', 'stock'],
#  ['remember',
#   'even',
#   'capital',
#   'investment',
#   'only',
#   'be',
#   'dividend',
#   'payout'],
#  ['since',
#   'last',
#   'er',
#   'stock',
#   'dropped',
#   'reporting',
#   'earnings',
#   'before',
#   'open',
#   'confirmed'],
#  ['whats',
#   'bro',
#   'you',
#   'still',
#   'trade',
#   'stock',
#   'or',
#   'did',
#   'you',
#   'give'],
#  ['short', 'volume', 'percent', 'wa'],
#  ['bull', 'have', 'reason', 'pay', 'more', 'attention'],
#  ['talking', 'about', 'gravity', 'stock', 'market', 'fool', 'take', 'look'],
#  ['read',
#   'your',
#   'comment',
#   'seeking',
#   'alpha',
#   'you',
#   'know',
#   'lot',
#   'about',
#   'casino',
#   'stock',
#   'ggr',
#   'hurt',
#   'price',
#   'more',
#   'or',
#   'ok',
#   'here'],
#  ['open', 'tomorrow'],
#  ['more', 'then', 'enough', 'we', 'should', 'be', 'earning', 'coming'],
#  ['should', 'be', 'loading', 'stock', 'here'],
#  ['wall', 'street', 'full', 'idiot', 'who', 'gamble', 'until', 'they', 'lose'],
#  ['hope',
#   'citibank',
#   'go',
#   'bankrupt',
#   'stealing',
#   'money',
#   'by',
#   'nickel',
#   'costumer',
#   'with',
#   'stupid',
#   'little',
#   'fee'],
#  [],
#  ['don',
#   'worry',
#   'scumbags',
#   'citibank',
#   'll',
#   'make',
#   'more',
#   'money',
#   'shorting',
#   'your',
#   'stock',
#   'ground',
#   'than',
#   'you',
#   'make',
#   'from',
#   'fee'],
#  ['choppy',
#   'head',
#   'amp',
#   'shoulder',
#   'watch',
#   'breakdown',
#   'watch',
#   'breakdown'],
#  ['releasing',
#   'earnings',
#   'before',
#   'open',
#   'confirmed',
#   'anybody',
#   'buying',
#   'selling',
#   'earnings'],
#  [],
#  ['now', 'time', 'trumpy', 'bear', 'market'],
#  ['gravity', 'applies', 'overbot', 'condition', 'applied', 'past', 'well'],
#  ['highlight', 'cancer', 'from', 'week'],
#  ['jcp', 'jcpenney', 'ha', 'rev', 'per', 'employee'],
#  ['vrsk', 'beta', 'making', 'le', 'volatile', 'than', 'market'],
#  ['dipped', 'by', 'last', 'year', 'viav'],
#  ['gartner', 'ha', 'very', 'low', 'roce'],
#  ['etn', 'rpe', 'revenue', 'per', 'employee'],
#  ['oversold', 'according', 'stoch', 'rsi', 'rrd'],
#  ['ba', 'payout', 'ratio', 'boeing'],
#  ['releasing',
#   'earnings',
#   'before',
#   'open',
#   'confirmed',
#   'anybody',
#   'buying',
#   'selling',
#   'earnings'],
#  ['psx', 'fcf', 'phillips'],
#  ['citigroup', 'ha', 'recommendation', 'mean'],
#  ['mco', 'sma', 'moody', 'now', 'down', 'by', 'sma', 'now', 'by'],
#  ['fslr', 'percentage', 'price', 'oscillator', 'or', 'ppo'],
#  ['ha', 'beta', 'making', 'le', 'volatile', 'than', 'market', 'aon'],
#  ['microsoft', 'ha', 'adx', 'hinting', 'weak', 'trend', 'msft'],
#  ['apa', 'apache', 'ha', 'sma', 'now', 'by', 'sma', 'now', 'by'],
#  ['ha', 'ppo', 'incy'],
#  ['ha', 'recommendation', 'mean', 'sjm'],
#  ['tel', 'ha', 'ppo'],
#  ['operating', 'margin', 'ibm'],
#  ['ha', 'recommendation', 'mean', 'ntrs'],
#  ['ha', 'short', 'float', 'bk'],
#  ['nowhere',
#   'go',
#   'but',
#   'focus',
#   'fundamental',
#   'epyc',
#   'xeon',
#   'tam',
#   'all',
#   'revenue',
#   'profit',
#   'coming',
#   'now',
#   'revenue',
#   'ramp',
#   'year',
#   'pt'],
#  ['etfc', 'insider', 'ownership', 'etrade'],
#  ['ha', 'short', 'float'],
#  ['overbought',
#   'with',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'bax'],
#  ['profit', 'margin', 'att'],
#  ['more', 'volatile', 'than', 'market', 'with', 'beta', 'eog'],
#  ['ha', 'adx', 'signifying', 'weak', 'trend', 'do'],
#  ['dividend', 'yield', 'avy'],
#  ['southern', 'ha', 'very', 'high', 'return', 'capital', 'employed', 'so'],
#  ['insider', 'ownership', 'davita', 'dva'],
#  ['western',
#   'ma',
#   'berkshire',
#   'today',
#   'already',
#   'today',
#   'cool',
#   'end',
#   'state'],
#  ['citizen', 'ha', 'stoch', 'making', 'oversold', 'cfg'],
#  ['bear', 'have', 'lost', 'alone', 'according', 'iex', 'data'],
#  ['ha', 'adx', 'signifying', 'weak', 'trend'],
#  ['all', 'allstate', 'ha', 'very', 'high', 'return', 'equity'],
#  ['cxo', 'went', 'by', 'last', 'year'],
#  ['compared',
#   'an',
#   'average',
#   'enterprise',
#   'value',
#   'ebitda',
#   'ratio',
#   'valued',
#   'rather',
#   'cheaply'],
#  ['bull', 'have', 'reason', 'pay', 'more', 'attention'],
#  ['ha', 'very', 'high', 'revenue', 'per', 'employee', 'qep'],
#  ['fcf', 'ansys'],
#  ['coty', 'recommendation', 'mean', 'coty'],
#  ['profit', 'margin', 'mettler'],
#  ['anyone', 'know', 'what', 'referring'],
#  ['gross', 'margin', 'msi'],
#  ['operating', 'margin', 'kor'],
#  ['overbought', 'according', 'stochastic', 'rsi', 'indicator'],
#  ['nlsn', 'percentage', 'price', 'oscillator', 'or', 'ppo'],
#  ['wpx', 'wpx', 'ha', 'rev', 'per', 'employee'],
#  ['whr', 'whirlpool', 'ha', 'dividend', 'yield'],
#  ['chrw', 'ha', 'short', 'float'],
#  ['recommendation', 'mean', 'wellsfargo', 'wfc'],
#  ['ccl', 'carnival', 'ha', 'operating', 'margin'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'via'],
#  ['sma', 'pepsico', 'now', 'by', 'sma', 'now', 'down', 'by', 'pep'],
#  ['pfe', 'pfizer', 'ha', 'very', 'high', 'return', 'equity'],
#  ['so',
#   'funny',
#   'how',
#   'bear',
#   'disappear',
#   'from',
#   'but',
#   'pull',
#   'back',
#   'sky',
#   'falling',
#   'lollll',
#   'nature',
#   'stock',
#   'down'],
#  ['ha', 'adx', 'signifying', 'weak', 'trend', 'dal'],
#  ['ha', 'operating', 'margin'],
#  ['bsx', 'ha', 'institutional', 'ownership'],
#  ['mck', 'mckesson', 'went', 'down', 'by', 'last', 'year'],
#  ['pbct',
#   'overbought',
#   'with',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo'],
#  ['insider', 'ownership', 'vrtx'],
#  ['bkng', 'volatility', 'booking'],
#  ['dis', 'ha', 'ppo'],
#  ['ha', 'insider', 'ownership', 'abt'],
#  ['ha', 'adx', 'signifying', 'strong', 'trend', 'ajg'],
#  ['disca', 'ha', 'gross', 'margin'],
#  ['ha', 'weak', 'trend', 'according', 'adx', 'lyb'],
#  ['so',
#   'basically',
#   'vip',
#   'premium',
#   'mass',
#   'aren',
#   'spending',
#   'much',
#   'analyst',
#   'fooled',
#   'by',
#   'appearance',
#   'given',
#   'by',
#   'lower',
#   'quality',
#   'mass'],
#  ['ha', 'institutional', 'ownership', 'swks'],
#  ['ha', 'adx', 'signifying', 'weak', 'trend'],
#  ['wmb', 'ha', 'volatility'],
#  ['competition',
#   'profitable',
#   'yes',
#   'they',
#   'collaboration',
#   'with',
#   'waymo',
#   'yes',
#   'do',
#   'they',
#   'have',
#   'cash',
#   'yes'],
#  ['releasing',
#   'earnings',
#   'before',
#   'open',
#   'confirmed',
#   'anybody',
#   'buying',
#   'selling',
#   'earnings'],
#  ['kroger', 'ha', 'very', 'high', 'roce', 'kr'],
#  ['pcar', 'institutional', 'ownership', 'paccar'],
#  ['fcf', 'ctxs'],
#  ['profit', 'margin', 'verisign'],
#  ['ha', 'beta', 'making', 'more', 'volatile', 'than', 'market', 'hon'],
#  ['dividend', 'yield'],
#  ['txn', 'ha', 'very', 'high', 'return', 'equity'],
#  ['short', 'percent', 'float', 'teradata'],
#  ['sma', 'now', 'down', 'by', 'sma', 'now', 'down', 'by', 'aos'],
#  ['ha', 'operating', 'margin'],
#  ['bby', 'ha', 'revenue', 'per', 'employee'],
#  ['masco', 'ha', 'gross', 'margin', 'ma'],
#  ['payout', 'ratio', 'nike', 'nke'],
#  ['len', 'lennar', 'rose', 'by', 'last', 'month'],
#  ['clf', 'roce'],
#  ['ha', 'very', 'high', 'return', 'equity', 'tss'],
#  ['symantec', 'dipped', 'by', 'last', 'year', 'symc'],
#  ['rrc', 'went', 'down', 'by', 'last', 'month'],
#  ['nsc', 'ha', 'revenue', 'per', 'employee'],
#  ['return', 'capital', 'employed', 'acn'],
#  ['le', 'volatile', 'than', 'market', 'with', 'beta'],
#  ['genworth', 'ha', 'institutional', 'ownership', 'gnw'],
#  ['ha', 'adx', 'signifying', 'strong', 'trend', 'mlm'],
#  ['intc', 'operating', 'margin', 'intel'],
#  ['operating', 'margin', 'amg'],
#  ['ha', 'volatility'],
#  ['fbhs', 'beta', 'making', 'more', 'volatile', 'than', 'market'],
#  ['nwl', 'dipped', 'by', 'last', 'year'],
#  ['ha', 'operating', 'margin', 'coo'],
#  ['brighthouse', 'oversold', 'according', 'stoch', 'rsi'],
#  ['ebay', 'revenue', 'per', 'employee', 'ebay'],
#  ['operating', 'margin'],
#  ['recommendation', 'mean', 'ppg'],
#  ['tegna', 'dipped', 'by', 'last', 'month'],
#  ['ha', 'gross', 'margin', 'dg'],
#  ['beta', 'hess', 'make', 'more', 'volatile', 'than', 'market', 'he'],
#  ['insider', 'ownership', 'vmc'],
#  ['jpm', 'floating', 'share', 'being', 'shorted'],
#  ['beta', 'perrigo', 'making', 'le', 'volatile', 'than', 'market', 'prgo'],
#  ['ha', 'very', 'high', 'return', 'equity'],
#  ['tsn', 'ha', 'price', 'free', 'cash', 'flow', 'ratio'],
#  ['rpe', 'revenue', 'per', 'employee', 'intercontinentalexchange', 'ice'],
#  ['ha', 'adx', 'hinting', 'weak', 'trend', 'bdx'],
#  ['percentage', 'price', 'oscillator', 'or', 'ppo', 'fluor', 'flr'],
#  ['pdco', 'ha', 'price', 'free', 'cash', 'flow', 'ratio'],
#  ['footlocker', 'rose', 'by', 'last', 'year', 'fl'],
#  ['we', 'have', 'detected', 'negative', 'indicator', 'more', 'info'],
#  ['aph', 'amphenol', 'ha', 'fcf'],
#  ...]

# %% [markdown]
# ### Balancing the classes
# Let's do a few last pre-processing steps. If we look at how our twits are labeled, we'll find that 50% of them are neutral. This means that our network will be 50% accurate just by guessing 0 every single time. To help our network learn appropriately, we'll want to balance our classes.
# That is, make sure each of our different sentiment scores show up roughly as frequently in the data.
#
# What we can do here is go through each of our examples and randomly drop twits with neutral sentiment. What should be the probability we drop these twits if we want to get around 20% neutral twits starting at 50% neutral? We should also take this opportunity to remove messages with length 0.

# %%
balanced = {'messages': [], 'sentiments':[]}

n_neutral = sum(1 for each in sentiments if each == 2)
N_examples = len(sentiments)
keep_prob = (N_examples - n_neutral)/4/n_neutral

for idx, sentiment in enumerate(sentiments):
    message = filtered[idx]
    if len(message) == 0:
        # skip this message because it has length zero
        continue
    elif sentiment != 2 or random.random() < keep_prob:
        balanced['messages'].append(message)
        balanced['sentiments'].append(sentiment)

# %% [markdown]
# If you did it correctly, you should see the following result

# %%
n_neutral = sum(1 for each in balanced['sentiments'] if each == 2)
N_examples = len(balanced['sentiments'])
n_neutral/N_examples
# Out:
# 0.19413945044714095

# %% [markdown]
# Finally let's convert our tokens into integer ids which we can pass to the network.

# %%
token_ids = [[vocab[word] for word in message] for message in balanced['messages']]
sentiments = balanced['sentiments']

# %% [markdown]
# ## Neural Network
# Now we have our vocabulary which means we can transform our tokens into ids, which are then passed to our network. So, let's define the network now!
#
# Here is a nice diagram showing the network we'd like to build:
#
# #### Embed -> RNN -> Dense -> Softmax
# ### Implement the text classifier
# Before we build text classifier, if you remember from the other network that you built in  "Sentiment Analysis with an RNN"  exercise  - which there, the network called " SentimentRNN", here we named it "TextClassifer" - consists of three main parts: 1) init function `__init__` 2) forward pass `forward`  3) hidden state `init_hidden`.
#
# This network is pretty similar to the network you built expect in the  `forward` pass, we use softmax instead of sigmoid. The reason we are not using sigmoid is that the output of NN is not a binary. In our network, sentiment scores have 5 possible outcomes. We are looking for an outcome with the highest probability thus softmax is a better choice.

# %%
class TextClassifier(nn.Module):
    def __init__(self, vocab_size, embed_size, lstm_size, output_size, lstm_layers=1, dropout=0.1):
        """
        Initialize the model by setting up the layers.
        
        Parameters
        ----------
            vocab_size : The vocabulary size.
            embed_size : The embedding layer size.
            lstm_size : The LSTM layer size.
            output_size : The output size.
            lstm_layers : The number of LSTM layers.
            dropout : The dropout probability.
        """
        
        super().__init__()
        self.vocab_size = vocab_size
        self.embed_size = embed_size
        self.lstm_size = lstm_size
        self.output_size = output_size
        self.lstm_layers = lstm_layers
        self.dropout = dropout
        
        # TODO Implement

        # Setup embedding layer
        self.embedding = nn.Embedding(vocab_size, embed_size)
        
        # Setup additional layers
        
        # lstm
        self.lstm = nn.LSTM(embed_size, lstm_size, lstm_layers, 
                            dropout=dropout, batch_first=False)

        # dropout
        self.dropoutLayer = nn.Dropout(dropout)
        
        # linear and sigmoid layers
        self.fc = nn.Linear(lstm_size, output_size)
        
        self.log_softmax = nn.LogSoftmax(dim=1)


    def init_hidden(self, batch_size):
        """ 
        Initializes hidden state
        
        Parameters
        ----------
            batch_size : The size of batches.
        
        Returns
        -------
            hidden_state
            
        """
        #
        # TODO Implement 
        
        # Create two new tensors with sizes n_layers x batch_size x hidden_dim,
        # initialized to zero, for hidden state and cell state of LSTM
        weight = next(self.parameters()).data
        
        hidden = (weight.new(self.lstm_layers ,batch_size, self.lstm_size).zero_(), 
                  weight.new(self.lstm_layers ,batch_size, self.lstm_size).zero_())            

        return hidden


    def forward(self, nn_input, hidden_state):
        """
        Perform a forward pass of our model on nn_input.
        
        Parameters
        ----------
            nn_input : The batch of input to the NN.
            hidden_state : The LSTM hidden state.

        Returns
        -------
            logps: log softmax output
            hidden_state: The new hidden state.

        """
        # TODO Implement 
        # return last sigmoid output and hidden state
        nn_input = nn_input.long()
                
        embeddings_out = self.embedding(nn_input)
        lstm_out, hidden = self.lstm(embeddings_out, hidden_state)
        lstm_out = lstm_out[-1,:,:]
        out = self.dropoutLayer(lstm_out)
        out = self.fc(out)
        logps = self.log_softmax(out)
        
        return logps, hidden

# %% [markdown]
# ### View Model

# %%
model = TextClassifier(len(vocab), 10, 6, 5, dropout=0.1, lstm_layers=2)
model.embedding.weight.data.uniform_(-1, 1)
input = torch.randint(0, 1000, (5, 4), dtype=torch.int64)
hidden = model.init_hidden(4)

logps, _ = model.forward(input, hidden)
print(logps)
# Out:
# tensor([[-1.8556, -1.4273, -1.6382, -1.8453, -1.3808],
#         [-1.8353, -1.4293, -1.6544, -1.8494, -1.3767],
#         [-1.8651, -1.4231, -1.6309, -1.8417, -1.3869],
#         [-1.8121, -1.4316, -1.6842, -1.8496, -1.3670]])

# %% [markdown]
# ## Training
# ### DataLoaders and Batching
# Now we should build a generator that we can use to loop through our data. It'll be more efficient if we can pass our sequences in as batches. Our input tensors should look like `(sequence_length, batch_size)`. So if our sequences are 40 tokens long and we pass in 25 sequences, then we'd have an input size of `(40, 25)`.
#
# If we set our sequence length to 40, what do we do with messages that are more or less than 40 tokens? For messages with fewer than 40 tokens, we will pad the empty spots with zeros. We should be sure to **left** pad so that the RNN starts from nothing before going through the data. If the message has 20 tokens, then the first 20 spots of our 40 long sequence will be 0. If a message has more than 40 tokens, we'll just keep the first 40 tokens.

# %%
def dataloader(messages, labels, sequence_length=30, batch_size=32, shuffle=False):
    """ 
    Build a dataloader.
    """
    if shuffle:
        indices = list(range(len(messages)))
        random.shuffle(indices)
        messages = [messages[idx] for idx in indices]
        labels = [labels[idx] for idx in indices]

    total_sequences = len(messages)

    for ii in range(0, total_sequences, batch_size):
        batch_messages = messages[ii: ii+batch_size]
        
        # First initialize a tensor of all zeros
        batch = torch.zeros((sequence_length, len(batch_messages)), dtype=torch.int64)
        for batch_num, tokens in enumerate(batch_messages):
            token_tensor = torch.tensor(tokens)
            # Left pad!
            start_idx = max(sequence_length - len(token_tensor), 0)
            batch[start_idx:, batch_num] = token_tensor[:sequence_length]
        
        label_tensor = torch.tensor(labels[ii: ii+len(batch_messages)])
        
        yield batch, label_tensor

# %% [markdown]
# ### Training and  Validation
#
# With our data in nice shape, we'll split it into training and validation sets.

# %%
"""
Split data into training and validation datasets. Use an appropriate split size.
The features are the `token_ids` and the labels are the `sentiments`.
"""   

# TODO Implement 
split_frac = 0.8
train_features_length = int(len(token_ids) * split_frac)
train_features = token_ids[:train_features_length]
valid_features = token_ids[train_features_length:]
train_labels = sentiments[:train_features_length]
valid_labels = sentiments[train_features_length:]

# %%
text_batch, labels = next(iter(dataloader(train_features, train_labels, sequence_length=20, batch_size=64)))
model = TextClassifier(len(vocab)+1, 200, 128, 5, dropout=0.)
hidden = model.init_hidden(64)
logps, hidden = model.forward(text_batch, hidden)

# %% [markdown]
# ### Training
# It's time to train the neural network!

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = TextClassifier(len(vocab)+1, 1024, 512, 5, lstm_layers=2, dropout=0.2)
model.embedding.weight.data.uniform_(-1, 1)
model.to(device)
# Out:
# TextClassifier(
#   (embedding): Embedding(18121, 1024)
#   (lstm): LSTM(1024, 512, num_layers=2, dropout=0.2)
#   (dropoutLayer): Dropout(p=0.2)
#   (fc): Linear(in_features=512, out_features=5, bias=True)
#   (log_softmax): LogSoftmax()
# )

# %%
import numpy as np

"""
Train your model with dropout. Make sure to clip your gradients.
Print the training loss, validation loss, and validation accuracy for every 100 steps.
"""
#
epochs = 4 # 4 is the best
batch_size = 170
learning_rate = 0.0001
clip=5 # gradient clipping

print_every = 100
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    
model.train()

for epoch in range(epochs):
    print('Starting epoch {}'.format(epoch + 1))
    steps = 0
    for text_batch, labels in dataloader(train_features, train_labels, batch_size=batch_size, sequence_length=20, shuffle=True):
        steps += 1
        hidden = model.init_hidden(labels.shape[0])
        
        # Set Device
        text_batch, labels = text_batch.to(device), labels.to(device)
        for each in hidden:
            each.to(device)
        
        # TODO Implement: Train Model
        optimizer.zero_grad()
        
        log_ps, hidden = model(text_batch, hidden)
        loss = criterion(log_ps.squeeze(), labels.long())
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), clip) # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
        optimizer.step()
        
        if steps % print_every == 0:
            val_losses = []
            accuracy = 0
            
            model.eval()
            # TODO Implement: Print metrics
            for text_batch, labels in dataloader(valid_features, valid_labels, batch_size=batch_size, sequence_length=20, shuffle=True):
                val_h = model.init_hidden(labels.shape[0])

                text_batch, labels = text_batch.to(device), labels.to(device)

                for each in val_h:
                    each.to(device)

                output, val_h = model(text_batch, val_h)
                val_loss = criterion(output.squeeze(), labels.long())                
                val_losses.append(val_loss.item())
                
                ps = torch.exp(output)
                top_p, top_class = ps.topk(1, dim=1)
                equals = top_class == labels.view(*top_class.shape)
                accuracy += torch.sum(equals.type(torch.FloatTensor)).item()

            val_acc = accuracy/len(valid_labels)
            
            model.train()
            print("Epoch: {}/{}...".format(epoch+1, epochs),
                "Step: {}...".format(steps),
                "Loss: {:.6f}...".format(loss.item()),
                "Val Loss: {:.6f}".format(np.mean(val_losses)),
                "Val accuracy: {:.3f}".format(val_acc))
# Out:
# Starting epoch 1
# Epoch: 1/4... Step: 100... Loss: 1.376360... Val Loss: 1.355275 Val accuracy: 0.432
# Epoch: 1/4... Step: 200... Loss: 1.196299... Val Loss: 1.205055 Val accuracy: 0.509
# Epoch: 1/4... Step: 300... Loss: 1.162633... Val Loss: 1.156152 Val accuracy: 0.526
# Epoch: 1/4... Step: 400... Loss: 1.125686... Val Loss: 1.103288 Val accuracy: 0.551
# Epoch: 1/4... Step: 500... Loss: 1.041983... Val Loss: 1.071818 Val accuracy: 0.570
# Epoch: 1/4... Step: 600... Loss: 0.968384... Val Loss: 1.053671 Val accuracy: 0.569
# Epoch: 1/4... Step: 700... Loss: 0.999629... Val Loss: 1.031248 Val accuracy: 0.586
# Epoch: 1/4... Step: 800... Loss: 0.960457... Val Loss: 1.008578 Val accuracy: 0.593
# Epoch: 1/4... Step: 900... Loss: 0.949682... Val Loss: 0.999535 Val accuracy: 0.600
# Epoch: 1/4... Step: 1000... Loss: 0.938508... Val Loss: 0.980359 Val accuracy: 0.608
# Epoch: 1/4... Step: 1100... Loss: 1.009025... Val Loss: 0.976259 Val accuracy: 0.606
# Epoch: 1/4... Step: 1200... Loss: 0.899269... Val Loss: 0.956637 Val accuracy: 0.619
# Epoch: 1/4... Step: 1300... Loss: 0.849676... Val Loss: 0.951288 Val accuracy: 0.628
# Epoch: 1/4... Step: 1400... Loss: 1.014401... Val Loss: 0.941552 Val accuracy: 0.628
# Epoch: 1/4... Step: 1500... Loss: 0.820246... Val Loss: 0.932901 Val accuracy: 0.633
# Epoch: 1/4... Step: 1600... Loss: 0.810814... Val Loss: 0.923928 Val accuracy: 0.632
# Epoch: 1/4... Step: 1700... Loss: 0.887113... Val Loss: 0.913790 Val accuracy: 0.644
# Epoch: 1/4... Step: 1800... Loss: 0.912788... Val Loss: 0.906036 Val accuracy: 0.646
# Epoch: 1/4... Step: 1900... Loss: 0.790330... Val Loss: 0.903027 Val accuracy: 0.646
# Epoch: 1/4... Step: 2000... Loss: 0.757479... Val Loss: 0.900838 Val accuracy: 0.648
# Epoch: 1/4... Step: 2100... Loss: 0.848216... Val Loss: 0.891226 Val accuracy: 0.654
# Epoch: 1/4... Step: 2200... Loss: 0.880621... Val Loss: 0.885560 Val accuracy: 0.656
# Epoch: 1/4... Step: 2300... Loss: 0.877647... Val Loss: 0.880810 Val accuracy: 0.658
# Epoch: 1/4... Step: 2400... Loss: 0.898740... Val Loss: 0.879783 Val accuracy: 0.656
# Epoch: 1/4... Step: 2500... Loss: 0.828697... Val Loss: 0.868760 Val accuracy: 0.661
# Epoch: 1/4... Step: 2600... Loss: 0.820938... Val Loss: 0.871634 Val accuracy: 0.664
# Epoch: 1/4... Step: 2700... Loss: 0.767259... Val Loss: 0.863727 Val accuracy: 0.666
# Epoch: 1/4... Step: 2800... Loss: 0.784153... Val Loss: 0.860779 Val accuracy: 0.663
# Epoch: 1/4... Step: 2900... Loss: 0.800452... Val Loss: 0.858277 Val accuracy: 0.669
# Epoch: 1/4... Step: 3000... Loss: 0.724584... Val Loss: 0.854717 Val accuracy: 0.669
# Epoch: 1/4... Step: 3100... Loss: 0.921096... Val Loss: 0.848165 Val accuracy: 0.673
# Epoch: 1/4... Step: 3200... Loss: 0.767575... Val Loss: 0.851161 Val accuracy: 0.674
# Epoch: 1/4... Step: 3300... Loss: 0.787765... Val Loss: 0.844093 Val accuracy: 0.674
# Epoch: 1/4... Step: 3400... Loss: 0.864050... Val Loss: 0.851263 Val accuracy: 0.668
# Epoch: 1/4... Step: 3500... Loss: 0.865646... Val Loss: 0.843670 Val accuracy: 0.674
# Epoch: 1/4... Step: 3600... Loss: 0.781773... Val Loss: 0.833997 Val accuracy: 0.680
# Epoch: 1/4... Step: 3700... Loss: 0.900015... Val Loss: 0.834992 Val accuracy: 0.679
# Epoch: 1/4... Step: 3800... Loss: 0.839186... Val Loss: 0.828011 Val accuracy: 0.682
# Epoch: 1/4... Step: 3900... Loss: 0.894867... Val Loss: 0.826258 Val accuracy: 0.681
# Epoch: 1/4... Step: 4000... Loss: 0.738530... Val Loss: 0.822817 Val accuracy: 0.681
# Epoch: 1/4... Step: 4100... Loss: 0.768009... Val Loss: 0.819677 Val accuracy: 0.685
# Epoch: 1/4... Step: 4200... Loss: 0.726225... Val Loss: 0.821585 Val accuracy: 0.681
# Epoch: 1/4... Step: 4300... Loss: 0.799576... Val Loss: 0.815724 Val accuracy: 0.684
# Epoch: 1/4... Step: 4400... Loss: 0.922292... Val Loss: 0.814241 Val accuracy: 0.686
# Epoch: 1/4... Step: 4500... Loss: 0.795813... Val Loss: 0.820916 Val accuracy: 0.683
# Epoch: 1/4... Step: 4600... Loss: 0.845526... Val Loss: 0.809294 Val accuracy: 0.688
# Epoch: 1/4... Step: 4700... Loss: 0.743365... Val Loss: 0.815658 Val accuracy: 0.685
# Epoch: 1/4... Step: 4800... Loss: 0.809206... Val Loss: 0.807270 Val accuracy: 0.689
# Starting epoch 2
# Epoch: 2/4... Step: 100... Loss: 0.685017... Val Loss: 0.806174 Val accuracy: 0.690
# Epoch: 2/4... Step: 200... Loss: 0.660788... Val Loss: 0.808200 Val accuracy: 0.686
# Epoch: 2/4... Step: 300... Loss: 0.733032... Val Loss: 0.803301 Val accuracy: 0.690
# Epoch: 2/4... Step: 400... Loss: 0.806579... Val Loss: 0.805652 Val accuracy: 0.690
# Epoch: 2/4... Step: 500... Loss: 0.823347... Val Loss: 0.802378 Val accuracy: 0.692
# Epoch: 2/4... Step: 600... Loss: 0.850508... Val Loss: 0.807148 Val accuracy: 0.688
# Epoch: 2/4... Step: 700... Loss: 0.782370... Val Loss: 0.801754 Val accuracy: 0.690
# Epoch: 2/4... Step: 800... Loss: 0.782259... Val Loss: 0.794024 Val accuracy: 0.697
# Epoch: 2/4... Step: 900... Loss: 0.768589... Val Loss: 0.797367 Val accuracy: 0.693
# Epoch: 2/4... Step: 1000... Loss: 0.676728... Val Loss: 0.794502 Val accuracy: 0.695
# Epoch: 2/4... Step: 1100... Loss: 0.725594... Val Loss: 0.790397 Val accuracy: 0.697
# Epoch: 2/4... Step: 1200... Loss: 0.649646... Val Loss: 0.793909 Val accuracy: 0.694
# Epoch: 2/4... Step: 1300... Loss: 0.697105... Val Loss: 0.794388 Val accuracy: 0.694
# Epoch: 2/4... Step: 1400... Loss: 0.854899... Val Loss: 0.791405 Val accuracy: 0.695
# Epoch: 2/4... Step: 1500... Loss: 0.697563... Val Loss: 0.787837 Val accuracy: 0.699
# Epoch: 2/4... Step: 1600... Loss: 0.708190... Val Loss: 0.791004 Val accuracy: 0.698
# Epoch: 2/4... Step: 1700... Loss: 0.650521... Val Loss: 0.788149 Val accuracy: 0.696
# Epoch: 2/4... Step: 1800... Loss: 0.742700... Val Loss: 0.784564 Val accuracy: 0.700
# Epoch: 2/4... Step: 1900... Loss: 0.676734... Val Loss: 0.779415 Val accuracy: 0.703
# Epoch: 2/4... Step: 2000... Loss: 0.722331... Val Loss: 0.781423 Val accuracy: 0.702
# Epoch: 2/4... Step: 2100... Loss: 0.720281... Val Loss: 0.779470 Val accuracy: 0.703
# Epoch: 2/4... Step: 2200... Loss: 0.680676... Val Loss: 0.780279 Val accuracy: 0.700
# Epoch: 2/4... Step: 2300... Loss: 0.668956... Val Loss: 0.783872 Val accuracy: 0.702
# Epoch: 2/4... Step: 2400... Loss: 0.761588... Val Loss: 0.776250 Val accuracy: 0.704
# Epoch: 2/4... Step: 2500... Loss: 0.727054... Val Loss: 0.775015 Val accuracy: 0.702
# Epoch: 2/4... Step: 2600... Loss: 0.806441... Val Loss: 0.774876 Val accuracy: 0.702
# Epoch: 2/4... Step: 2700... Loss: 0.690759... Val Loss: 0.787833 Val accuracy: 0.702
# Epoch: 2/4... Step: 2800... Loss: 0.642364... Val Loss: 0.777025 Val accuracy: 0.703
# Epoch: 2/4... Step: 2900... Loss: 0.717176... Val Loss: 0.772013 Val accuracy: 0.704
# Epoch: 2/4... Step: 3000... Loss: 0.636724... Val Loss: 0.776944 Val accuracy: 0.701
# Epoch: 2/4... Step: 3100... Loss: 0.657015... Val Loss: 0.768130 Val accuracy: 0.706
# Epoch: 2/4... Step: 3200... Loss: 0.794527... Val Loss: 0.769426 Val accuracy: 0.704
# Epoch: 2/4... Step: 3300... Loss: 0.674921... Val Loss: 0.769388 Val accuracy: 0.705
# Epoch: 2/4... Step: 3400... Loss: 0.778834... Val Loss: 0.768264 Val accuracy: 0.704
# Epoch: 2/4... Step: 3500... Loss: 0.795350... Val Loss: 0.769045 Val accuracy: 0.704
# Epoch: 2/4... Step: 3600... Loss: 0.568098... Val Loss: 0.767421 Val accuracy: 0.705
# Epoch: 2/4... Step: 3700... Loss: 0.867600... Val Loss: 0.766579 Val accuracy: 0.705
# Epoch: 2/4... Step: 3800... Loss: 0.672583... Val Loss: 0.763261 Val accuracy: 0.709
# Epoch: 2/4... Step: 3900... Loss: 0.715120... Val Loss: 0.762111 Val accuracy: 0.708
# Epoch: 2/4... Step: 4000... Loss: 0.599901... Val Loss: 0.766764 Val accuracy: 0.703
# Epoch: 2/4... Step: 4100... Loss: 0.658038... Val Loss: 0.764783 Val accuracy: 0.708
# Epoch: 2/4... Step: 4200... Loss: 0.841703... Val Loss: 0.764377 Val accuracy: 0.705
# Epoch: 2/4... Step: 4300... Loss: 0.719576... Val Loss: 0.764140 Val accuracy: 0.707
# Epoch: 2/4... Step: 4400... Loss: 0.693065... Val Loss: 0.761691 Val accuracy: 0.709
# Epoch: 2/4... Step: 4500... Loss: 0.771373... Val Loss: 0.756730 Val accuracy: 0.710
# Epoch: 2/4... Step: 4600... Loss: 0.768862... Val Loss: 0.757691 Val accuracy: 0.710
# Epoch: 2/4... Step: 4700... Loss: 0.704360... Val Loss: 0.763754 Val accuracy: 0.707
# Epoch: 2/4... Step: 4800... Loss: 0.785225... Val Loss: 0.764421 Val accuracy: 0.704
# Starting epoch 3
# Epoch: 3/4... Step: 100... Loss: 0.641601... Val Loss: 0.761565 Val accuracy: 0.709
# Epoch: 3/4... Step: 200... Loss: 0.640890... Val Loss: 0.763420 Val accuracy: 0.708
# Epoch: 3/4... Step: 300... Loss: 0.673000... Val Loss: 0.764081 Val accuracy: 0.710
# Epoch: 3/4... Step: 400... Loss: 0.815382... Val Loss: 0.759920 Val accuracy: 0.709
# Epoch: 3/4... Step: 500... Loss: 0.668215... Val Loss: 0.759950 Val accuracy: 0.709
# Epoch: 3/4... Step: 600... Loss: 0.651441... Val Loss: 0.757243 Val accuracy: 0.710
# Epoch: 3/4... Step: 700... Loss: 0.719062... Val Loss: 0.759965 Val accuracy: 0.709
# Epoch: 3/4... Step: 800... Loss: 0.626204... Val Loss: 0.758143 Val accuracy: 0.709
# Epoch: 3/4... Step: 900... Loss: 0.852824... Val Loss: 0.760056 Val accuracy: 0.710
# Epoch: 3/4... Step: 1000... Loss: 0.686374... Val Loss: 0.756426 Val accuracy: 0.710
# Epoch: 3/4... Step: 1100... Loss: 0.602127... Val Loss: 0.754987 Val accuracy: 0.710
# Epoch: 3/4... Step: 1200... Loss: 0.626685... Val Loss: 0.756272 Val accuracy: 0.707
# Epoch: 3/4... Step: 1300... Loss: 0.694952... Val Loss: 0.755191 Val accuracy: 0.712
# Epoch: 3/4... Step: 1400... Loss: 0.786126... Val Loss: 0.754562 Val accuracy: 0.713
# Epoch: 3/4... Step: 1500... Loss: 0.735323... Val Loss: 0.759008 Val accuracy: 0.708
# Epoch: 3/4... Step: 1600... Loss: 0.641159... Val Loss: 0.753431 Val accuracy: 0.712
# Epoch: 3/4... Step: 1700... Loss: 0.657600... Val Loss: 0.751449 Val accuracy: 0.713
# Epoch: 3/4... Step: 1800... Loss: 0.602009... Val Loss: 0.754881 Val accuracy: 0.711
# Epoch: 3/4... Step: 1900... Loss: 0.758123... Val Loss: 0.752176 Val accuracy: 0.712
# Epoch: 3/4... Step: 2000... Loss: 0.689240... Val Loss: 0.758539 Val accuracy: 0.712
# Epoch: 3/4... Step: 2100... Loss: 0.718418... Val Loss: 0.752913 Val accuracy: 0.711
# Epoch: 3/4... Step: 2200... Loss: 0.732985... Val Loss: 0.749534 Val accuracy: 0.711
# Epoch: 3/4... Step: 2300... Loss: 0.658707... Val Loss: 0.747582 Val accuracy: 0.713
# Epoch: 3/4... Step: 2400... Loss: 0.660229... Val Loss: 0.753243 Val accuracy: 0.712
# Epoch: 3/4... Step: 2500... Loss: 0.649462... Val Loss: 0.748511 Val accuracy: 0.712
# Epoch: 3/4... Step: 2600... Loss: 0.643673... Val Loss: 0.752375 Val accuracy: 0.712
# Epoch: 3/4... Step: 2700... Loss: 0.637657... Val Loss: 0.749935 Val accuracy: 0.713
# Epoch: 3/4... Step: 2800... Loss: 0.751024... Val Loss: 0.747831 Val accuracy: 0.714
# Epoch: 3/4... Step: 2900... Loss: 0.713696... Val Loss: 0.745948 Val accuracy: 0.715
# Epoch: 3/4... Step: 3000... Loss: 0.697018... Val Loss: 0.748108 Val accuracy: 0.713
# Epoch: 3/4... Step: 3100... Loss: 0.635342... Val Loss: 0.747175 Val accuracy: 0.713
# Epoch: 3/4... Step: 3200... Loss: 0.597264... Val Loss: 0.746001 Val accuracy: 0.714
# Epoch: 3/4... Step: 3300... Loss: 0.694084... Val Loss: 0.744658 Val accuracy: 0.715
# Epoch: 3/4... Step: 3400... Loss: 0.680013... Val Loss: 0.744738 Val accuracy: 0.714
# Epoch: 3/4... Step: 3500... Loss: 0.593176... Val Loss: 0.745959 Val accuracy: 0.714
# Epoch: 3/4... Step: 3600... Loss: 0.726082... Val Loss: 0.744753 Val accuracy: 0.716
# Epoch: 3/4... Step: 3700... Loss: 0.777765... Val Loss: 0.747291 Val accuracy: 0.714
# Epoch: 3/4... Step: 3800... Loss: 0.624501... Val Loss: 0.742730 Val accuracy: 0.716
# Epoch: 3/4... Step: 3900... Loss: 0.756737... Val Loss: 0.742454 Val accuracy: 0.715
# Epoch: 3/4... Step: 4000... Loss: 0.626600... Val Loss: 0.744547 Val accuracy: 0.714
# Epoch: 3/4... Step: 4100... Loss: 0.889337... Val Loss: 0.744810 Val accuracy: 0.713
# Epoch: 3/4... Step: 4200... Loss: 0.592791... Val Loss: 0.743140 Val accuracy: 0.716
# Epoch: 3/4... Step: 4300... Loss: 0.563796... Val Loss: 0.742900 Val accuracy: 0.716
# Epoch: 3/4... Step: 4400... Loss: 0.642514... Val Loss: 0.743201 Val accuracy: 0.717
# Epoch: 3/4... Step: 4500... Loss: 0.740353... Val Loss: 0.739981 Val accuracy: 0.717
# Epoch: 3/4... Step: 4600... Loss: 0.611347... Val Loss: 0.739604 Val accuracy: 0.717
# Epoch: 3/4... Step: 4700... Loss: 0.790594... Val Loss: 0.742080 Val accuracy: 0.716
# Epoch: 3/4... Step: 4800... Loss: 0.728716... Val Loss: 0.743875 Val accuracy: 0.715
# Starting epoch 4
# Epoch: 4/4... Step: 100... Loss: 0.557660... Val Loss: 0.745233 Val accuracy: 0.713
# Epoch: 4/4... Step: 200... Loss: 0.667683... Val Loss: 0.743437 Val accuracy: 0.715
# Epoch: 4/4... Step: 300... Loss: 0.764170... Val Loss: 0.744922 Val accuracy: 0.717
# Epoch: 4/4... Step: 400... Loss: 0.726374... Val Loss: 0.746123 Val accuracy: 0.718
# Epoch: 4/4... Step: 500... Loss: 0.656813... Val Loss: 0.749111 Val accuracy: 0.714
# Epoch: 4/4... Step: 600... Loss: 0.644200... Val Loss: 0.746730 Val accuracy: 0.715
# Epoch: 4/4... Step: 700... Loss: 0.646357... Val Loss: 0.747391 Val accuracy: 0.713
# Epoch: 4/4... Step: 800... Loss: 0.605738... Val Loss: 0.745194 Val accuracy: 0.715
# Epoch: 4/4... Step: 900... Loss: 0.593396... Val Loss: 0.747424 Val accuracy: 0.715
# Epoch: 4/4... Step: 1000... Loss: 0.544022... Val Loss: 0.744792 Val accuracy: 0.716
# Epoch: 4/4... Step: 1100... Loss: 0.676208... Val Loss: 0.748826 Val accuracy: 0.713
# Epoch: 4/4... Step: 1200... Loss: 0.691332... Val Loss: 0.745365 Val accuracy: 0.717
# Epoch: 4/4... Step: 1300... Loss: 0.569862... Val Loss: 0.746297 Val accuracy: 0.718
# Epoch: 4/4... Step: 1400... Loss: 0.608610... Val Loss: 0.746212 Val accuracy: 0.716
# Epoch: 4/4... Step: 1500... Loss: 0.538866... Val Loss: 0.744947 Val accuracy: 0.717
# Epoch: 4/4... Step: 1600... Loss: 0.718971... Val Loss: 0.749296 Val accuracy: 0.714
# Epoch: 4/4... Step: 1700... Loss: 0.699852... Val Loss: 0.745152 Val accuracy: 0.717
# Epoch: 4/4... Step: 1800... Loss: 0.600735... Val Loss: 0.739691 Val accuracy: 0.717
# Epoch: 4/4... Step: 1900... Loss: 0.695404... Val Loss: 0.742453 Val accuracy: 0.715
# Epoch: 4/4... Step: 2000... Loss: 0.561623... Val Loss: 0.741553 Val accuracy: 0.715
# Epoch: 4/4... Step: 2100... Loss: 0.707953... Val Loss: 0.740993 Val accuracy: 0.714
# Epoch: 4/4... Step: 2200... Loss: 0.715724... Val Loss: 0.740106 Val accuracy: 0.717
# Epoch: 4/4... Step: 2300... Loss: 0.644831... Val Loss: 0.743120 Val accuracy: 0.716
# Epoch: 4/4... Step: 2400... Loss: 0.686735... Val Loss: 0.739455 Val accuracy: 0.718
# Epoch: 4/4... Step: 2500... Loss: 0.637925... Val Loss: 0.740874 Val accuracy: 0.717
# Epoch: 4/4... Step: 2600... Loss: 0.683711... Val Loss: 0.739040 Val accuracy: 0.717
# Epoch: 4/4... Step: 2700... Loss: 0.708175... Val Loss: 0.741530 Val accuracy: 0.720
# Epoch: 4/4... Step: 2800... Loss: 0.550684... Val Loss: 0.746138 Val accuracy: 0.716
# Epoch: 4/4... Step: 2900... Loss: 0.680566... Val Loss: 0.735961 Val accuracy: 0.719
# Epoch: 4/4... Step: 3000... Loss: 0.671500... Val Loss: 0.740186 Val accuracy: 0.716
# Epoch: 4/4... Step: 3100... Loss: 0.567967... Val Loss: 0.740078 Val accuracy: 0.718
# Epoch: 4/4... Step: 3200... Loss: 0.618954... Val Loss: 0.739301 Val accuracy: 0.715
# Epoch: 4/4... Step: 3300... Loss: 0.553263... Val Loss: 0.738984 Val accuracy: 0.717
# Epoch: 4/4... Step: 3400... Loss: 0.609071... Val Loss: 0.740253 Val accuracy: 0.716
# Epoch: 4/4... Step: 3500... Loss: 0.679313... Val Loss: 0.737397 Val accuracy: 0.715
# Epoch: 4/4... Step: 3600... Loss: 0.648487... Val Loss: 0.740040 Val accuracy: 0.717
# Epoch: 4/4... Step: 3700... Loss: 0.634639... Val Loss: 0.742778 Val accuracy: 0.715
# Epoch: 4/4... Step: 3800... Loss: 0.623802... Val Loss: 0.738373 Val accuracy: 0.716
# Epoch: 4/4... Step: 3900... Loss: 0.620896... Val Loss: 0.739122 Val accuracy: 0.717
# Epoch: 4/4... Step: 4000... Loss: 0.624935... Val Loss: 0.736985 Val accuracy: 0.717
# Epoch: 4/4... Step: 4100... Loss: 0.749771... Val Loss: 0.735596 Val accuracy: 0.718
# Epoch: 4/4... Step: 4200... Loss: 0.626908... Val Loss: 0.741401 Val accuracy: 0.716
# Epoch: 4/4... Step: 4300... Loss: 0.564136... Val Loss: 0.738092 Val accuracy: 0.716
# Epoch: 4/4... Step: 4400... Loss: 0.636445... Val Loss: 0.735643 Val accuracy: 0.719
# Epoch: 4/4... Step: 4500... Loss: 0.726536... Val Loss: 0.735618 Val accuracy: 0.718
# Epoch: 4/4... Step: 4600... Loss: 0.680549... Val Loss: 0.735724 Val accuracy: 0.720
# Epoch: 4/4... Step: 4700... Loss: 0.637464... Val Loss: 0.734811 Val accuracy: 0.716
# Epoch: 4/4... Step: 4800... Loss: 0.683076... Val Loss: 0.738953 Val accuracy: 0.719

# %% [markdown]
# ## Making Predictions
# ### Prediction
# Okay, now that you have a trained model, try it on some new twits and see if it works appropriately. Remember that for any new text, you'll need to preprocess it first before passing it to the network. Implement the `predict` function to generate the prediction vector from a message.

# %%
def predict(text, model, vocab):
    """
    Make a prediction on a single sentence.

    Parameters
    ----------
        text : The string to make a prediction on.
        model : The model to use for making the prediction.
        vocab : Dictionary for word to word ids. The key is the word and the value is the word id.

    Returns
    -------
        pred : Prediction vector
    """    

    # TODO Implement
    
    tokens = preprocess(text)
    
    # Filter non-vocab words
    tokens = [word for word in tokens if word in vocab]
    
    # Convert words to ids
    tokens = [vocab[word] for word in tokens]
        
    # Adding a batch dimension
    text_input = torch.tensor(tokens).view(-1, 1)
    # Get the NN output
    hidden = model.init_hidden(1)
    logps, _ = model(text_input, hidden)
    # Take the exponent of the NN output to get a range of 0 to 1 for each label.
    pred = logps.exp()
    
    return pred

# %%
text = "Google is working on self driving cars, I'm bullish on $goog"
model.eval()
model.to("cpu")
predict(text, model, vocab)
# Out:
# tensor([[ 0.0011,  0.0292,  0.0237,  0.6007,  0.3453]])

# %% [markdown]
# ### Questions: What is the prediction of the model? What is the uncertainty of the prediction?
# ** TODO: Answer Question**

# %% [markdown]
# Given the output tensor([[ 0.0011,  0.0292,  0.0237,  0.6007,  0.3453]]), and labels [very negative, negative, neutral, positive, very positive], we can see the prediction is 'positive'. The value of uncertainty of the prediction is 1 - probability_of_predicted_sentiment = 1 - 0.6007 = 0.3993.

# %% [markdown]
# Now we have a trained model and we can make predictions. We can use this model to track the sentiments of various stocks by predicting the sentiments of twits as they are coming in. Now we have a stream of twits. For each of those twits, pull out the stocks mentioned in them and keep track of the sentiments. Remember that in the twits, ticker symbols are encoded with a dollar sign as the first character, all caps, and 2-4 letters, like $AAPL. Ideally, you'd want to track the sentiments of the stocks in your universe and use this as a signal in your larger model(s).
#
# ## Testing
# ### Load the Data

# %%
with open(os.path.join('..', '..', 'data', 'project_6_stocktwits', 'test_twits.json'), 'r') as f:
    test_data = json.load(f)

# %% [markdown]
# ### Twit Stream

# %%
def twit_stream():
    for twit in test_data['data']:
        yield twit

next(twit_stream())
# Out:
# {'message_body': '$JWN has moved -1.69% on 10-31. Check out the movement and peers at  https://dividendbot.com?s=JWN',
#  'timestamp': '2018-11-01T00:00:05Z'}

# %% [markdown]
# Using the `prediction` function, let's apply it to a stream of twits.

# %%
def score_twits(stream, model, vocab, universe):
    """ 
    Given a stream of twits and a universe of tickers, return sentiment scores for tickers in the universe.
    """
    for twit in stream:

        # Get the message text
        text = twit['message_body']
        symbols = re.findall('\$[A-Z]{2,4}', text)
        score = predict(text, model, vocab)

        for symbol in symbols:
            if symbol in universe:
                yield {'symbol': symbol, 'score': score, 'timestamp': twit['timestamp']}

# %%
universe = {'$BBRY', '$AAPL', '$AMZN', '$BABA', '$YHOO', '$LQMT', '$FB', '$GOOG', '$BBBY', '$JNUG', '$SBUX', '$MU'}
score_stream = score_twits(twit_stream(), model, vocab, universe)

next(score_stream)
# Out:
# {'symbol': '$AAPL',
#  'score': tensor([[ 0.1228,  0.1849,  0.2372,  0.2430,  0.2122]]),
#  'timestamp': '2018-11-01T00:00:18Z'}

# %% [markdown]
# That's it. You have successfully built a model for sentiment analysis!

# %% [markdown]
# ## Submission
# Now that you're done with the project, it's time to submit it. Click the submit button in the bottom right. One of our reviewers will give you feedback on your project with a pass or not passed grade. You can continue to the next section while you wait for feedback.
